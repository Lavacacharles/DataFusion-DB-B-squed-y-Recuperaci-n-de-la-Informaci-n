# %% [markdown]
# Proyecto jiji

# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\ce mar\appdata\local\programs\python\python310\lib\site-packages (0.3.4)
# [notice] A new release of pip available: 22.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: packaging in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from kagglehub) (23.2)
# Requirement already satisfied: tqdm in c:\users\ce mar\appdata\local\programs\python\python310\lib\site-packages (from kagglehub) (4.66.1)
# Requirement already satisfied: requests in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from kagglehub) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from requests->kagglehub) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from requests->kagglehub) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from requests->kagglehub) (2.1.1)
# Requirement already satisfied: colorama in c:\users\ce mar\appdata\local\programs\python\python310\lib\site-packages (from tqdm->kagglehub) (0.4.6)

# %%
import nltk
import numpy as np
from nltk.stem.snowball import SnowballStemmer
nltk.download('punkt')
import regex as re
import os
import pandas as pd
stemmer = SnowballStemmer('english')
import os
import pickle
import sys
import math
import dbm
import time
import heapq
import json
import concurrent.futures #n Tests con concurrencia
# Out:
# c:\Users\Ce mar\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\__init__.py:177: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [nltk_data] Downloading package punkt to C:\Users\Ce
# [nltk_data]     mar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
with open("stopwords-en.txt", encoding="latin1") as file:
   stoplist = [line.rstrip().lower() for line in file]
stoplist += ['?', '-', '.', ':', ',', '!', ';']

def preprocesamiento(texto, stemming=True):
  words = []
  texto = str(texto)
  texto = texto.lower()
  texto = re.sub(r'[^a-zA-Z0-9_À-ÿ]', ' ', texto)
  # tokenizar
  words = nltk.word_tokenize(texto, language='english')
  # filtrar stopwords
  words = [word for word in words if word not in stoplist]
  # reducir palabras (stemming)
  if stemming:
      words = [stemmer.stem(word) for word in words]
  return words

# %%
# Funciones AUXILIARES para recuperar la información

def getNumberWithAtributo(dataset_head, atributo):
    if atributo in dataset_head.columns:
        return dataset_head.columns.get_loc(atributo)  # Obtiene la posición del atributo
    return -1  # Retorna -1 si no existe
 

def getResultados(result, path, disk_limit):
    res = []
    for chunk in pd.read_csv(path, chunksize=disk_limit):
        for doc, score in result:
            if doc in chunk.index:
                res.append((chunk.iloc[doc], score))
    return pd.DataFrame(res, columns=['doc_id', 'score'])  
def getResultadosDF(result, path, disk_limit):
    res = []
    for chunk_idx, chunk in enumerate(pd.read_csv(path, chunksize=disk_limit)):
        for doc, score in result:
            global_doc_idx = doc - chunk_idx * disk_limit
            if 0 <= global_doc_idx < len(chunk):
                row = chunk.iloc[global_doc_idx].copy()  
                row['score'] = score  
                res.append(row) 
    return pd.DataFrame(res) 
 # Devolver el DataFrame resultante

def get_dfTex_Cols(path, row, columnas): 
    dataset =  pd.read_csv(path)
    res = [dataset.iloc[row, i] for i in columnas]
    return ' '.join(res)  
# Pruebas con concurrencia: 

def sort_block(block_path):
    try:
        with open(block_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        
        sorted_lines = sorted(lines, key=lambda x: x.split(":", 1)[0])  
        
        with open(block_path, 'w', encoding='utf-8') as f:
            f.writelines(sorted_lines)
        
        # print(f"Bloque ordenado: {block_path}")
        return block_path
    except Exception as e:
        print(f"Error al ordenar el bloque {block_path}: {e}")
        return None

# %%
class SPIMI:
    def __init__(self, index_dataset_path="path",bloques_dir="index_blocks" , columnas = ["track_name","track_artist","lyrics", "track_album_name"], disk_limit =40000 ):
        self.bloques_dir = bloques_dir  
        self.dataset_path = index_dataset_path  
        self.block_counter = 0      
        self.doc_ids = None  
        
        self.disk_limit = disk_limit  
        
        #--Columnas:
        self.columnas = columnas 
        # ----Direciones de memoria para los files--
        self.dirIndex = self.bloques_dir + "_merge"
        
        self.term_dict_path = os.path.join(self.dirIndex, 'term_dict.pkl')
        self.postings_file_path = os.path.join(self.dirIndex, 'postings.pkl')
        self.norms_file_path = os.path.join(self.dirIndex, 'document_norms.pkl')
        #Guardar los ids
        self.doc_count_path = os.path.join(self.dirIndex, 'doc_count.txt')  

        if not os.path.exists(self.dirIndex):
            os.makedirs(self.dirIndex)
        if not os.path.exists(self.bloques_dir):
            os.makedirs(self.bloques_dir)

        if os.path.exists(self.doc_count_path): # Guardamos el total de docs en ves de usar un set
            with open(self.doc_count_path, 'r') as f:
                self.doc_ids = int(f.read().strip())

        self.load_doc_ids()   

    def load_doc_ids(self):
        if os.path.exists(self.doc_count_path):
            try:
                with open(self.doc_count_path, 'r') as f:
                    self.doc_ids = int(f.read().strip())
                    print(f"Documentos cargados: {self.doc_ids}")
            except (ValueError, FileNotFoundError):
                self.doc_ids = 0  # Si el archivo está vacío o corrupto
        else:
            self.doc_ids = 0
 
       
        
                  

    def spimi_invert(self):
        print("Creando y ordenando cada bloque")
        dictionary = {}
        time_spimiInvert_start = time.time()

        #Get columna indeces: 
        with open(self.dataset_path, mode='r', encoding='utf-8') as file:
            primera_linea = file.readline().strip()
        #Get number columns
        columnas = primera_linea.split(',')
        columnas_numbers  = [i for i in range(len(columnas)) if columnas[i] in self.columnas]

        # Creamos los diccionarios a los bloques
        for chunk in pd.read_csv(self.dataset_path,chunksize= self.disk_limit): 
            for doc_id_, row in chunk.iterrows():
                self.doc_ids +=1 # Actualizamos la cantidad de id
                preFila = [str(row.iloc[i]) for i in columnas_numbers]
                texto = ' '.join(item for item in preFila)
                words = preprocesamiento(texto)
                for text in words:
                    doc_id = doc_id_
                    token = text
                    if token not in dictionary:
                        dictionary[token] = {}  

                    if doc_id not in dictionary[token]:
                        dictionary[token][doc_id] = 1  
                    else:
                        dictionary[token][doc_id] += 1  

                    dictionary_size = sys.getsizeof(dictionary)
                    if dictionary_size >= self.disk_limit:
                        self.write_block_to_disk(dictionary)
                        dictionary.clear()

        if dictionary:
            self.write_block_to_disk(dictionary)  
        
        with open(self.doc_count_path, 'w') as f:
            f.write(str(self.doc_ids))

        time_spimiInvert = time.time()- time_spimiInvert_start


        # MERGE
        print("Iniciando con el merge")
        time_Merge_start = time.time()
        self.mergeHeap()
        time_Merge = time.time() - time_Merge_start


        print("\nResumen de tiempos:")
        print(f"Tiempo para la creación Creación  y el ordenamiento de los bloques: {time_spimiInvert:.2f} segundos")
        print(f"Tiempo para la ejecución del merge: {time_Merge:.2f} segundos")
        print(f"Tiempo total para la creación y el mergeo: {time_Merge + time_spimiInvert:.2f} segundos")
    
    def sort_blocks_concurrently(self):
        print("Iniciando ordenamiento concurrente de los bloques...")
        block_files = [os.path.join(self.bloques_dir, f) for f in os.listdir(self.bloques_dir) if f.startswith("block_")]

        with concurrent.futures.ThreadPoolExecutor() as executor:
            futures = {executor.submit(sort_block, block): block for block in block_files}

            for future in concurrent.futures.as_completed(futures):
                block = futures[future]
                try:
                    result = future.result()
                    if result:
                        print(f"Ordenamiento completado para: {result}")
                    else:
                        print(f"Ordenamiento fallido para: {block}")
                except Exception as e:
                    print(f"Error al procesar el bloque {block}: {e}")


    def write_block_to_disk(self, dictionary): # Guardo los ordenados
        # TO DO
        # Probar con guardar y luego ordenar con hilos
        sorted_terms = dict(sorted(dictionary.items())) 
        file_path = os.path.join(self.bloques_dir, f"block_{self.block_counter}.txt")
        with open(file_path, "w", encoding="utf-8") as f:
            for term, postings in dictionary.items():
                postings_str = json.dumps(postings)  
                f.write(f"{term}: {postings_str}\n")  
        self.block_counter += 1



    def load_term_dict(self):
        with open(self.term_dict_path, 'rb') as f:
            while True:
                try: #Yiel es un generador, en vez de un return yield mantienes q en piclek esta 
                    yield pickle.load(f) #Avanzamos bloque por bloque, es decir dicionario por diccionario
                except EOFError:
                    break


    def show_Block(self, index):
        print("Imprimiendo contenido del bloque: ", index)
        file_path = os.path.join(self.bloques_dir, f'block_{index}.pkl')
        if not os.path.exists(file_path):
            print(f"El bloque {index} no existe en la ruta: {file_path}")
            return
        try:
            with open(file_path, 'rb') as f:
                block_content = pickle.load(f)
            print(block_content)
        except Exception as e:
            print(f"Error al abrir el bloque {index}: {e}")



    # Ya se comprobó el correcto merge 
    # Ahora los archivo son terminos postings y salto de linea, asi se getea linea por línea 
    def mergeHeap(self):
        lista_bloques = os.listdir(self.bloques_dir)
        priority_queue = []
        idx = 0 
    
        postings_file_path = os.path.join(self.dirIndex, 'postings.bin')
        term_dict_path = os.path.join(self.dirIndex, 'term_dict.pkl')
        norms_file_path = os.path.join(self.dirIndex, 'document_norms.pkl')
    
        open_files = {}
        doc_norms_temp = {}  
    
        #Para optimizar en término s de manejo de memoria secundaria a term_dict.pkl haremos lo siguiente: 
        # en un diccionario temporal y si se supera a disk_limit se guarda
        # las el mañao del diccionario y le diccionario, de tal forma que luego se puda abrir por bloques
        # En términos prácticos es (pos, tamanio) diccionario tempora ...
        temp_term_dict = {}
        temp_term_dict_position = 0

        try:
            for bloque_path in lista_bloques:  # Referencias de bloques y pusheo de una línea (term, postings)
                bloque_full_path = os.path.join(self.bloques_dir, bloque_path)
                open_files[bloque_path] = open(bloque_full_path, "r", encoding="utf-8")
                term_postings = self.read_next_term(open_files[bloque_path])
                if term_postings:
                    term, postings = term_postings
                    heapq.heappush(priority_queue, (term, idx, postings, bloque_path))
                    idx += 1
    
            current_term = None
            current_postings = {}
            postings_file_position = 0
    
            with open(postings_file_path, 'wb') as postings_file, \
                 open(term_dict_path, 'ab') as term_dict_file:
    
                while priority_queue:
                    term, _, postings, bloque_path = heapq.heappop(priority_queue)
                    file = open_files[bloque_path]
    
                    if term == current_term:  # Caso en que el término es igual
                        for doc_id, tf in postings.items():
                            current_postings[doc_id] = current_postings.get(doc_id, 0) + tf
                    else:  # Nuevo término
                        if current_term is not None:
                            # Calcular IDF
                            idf = math.log10(self.doc_ids / (1 + len(current_postings)))
    
                            # Guardar postings (TF e IDF) en postings.bin
                            tf_idf_postings = {}
                            for doc_id, tf in current_postings.items():
                                tf_weighted = math.log10(1 + tf)
                                tfidf = tf_weighted * idf
                                tf_idf_postings[doc_id] = {"tf": tf_weighted, "idf": idf}
    
                                # Acumular el cuadrado del TF-IDF en las normas temporales
                                doc_norms_temp[doc_id] = doc_norms_temp.get(doc_id, 0) + tfidf ** 2
    
                            postings_data = pickle.dumps(tf_idf_postings)
                            postings_file.write(postings_data)
    
                            # Guardar término en term_dict_temporal: 
                            temp_term_dict[current_term] =  (postings_file_position, len(postings_data)) 
                            postings_file_position += len(postings_data)
                        
                        # Si se puera el limite ------><------
                        dictionary_size = sys.getsizeof(temp_term_dict)
                        if dictionary_size >= self.disk_limit: 
                            pickle.dump(temp_term_dict, term_dict_file) 
                            temp_term_dict.clear()
                        
                        # Actualizar current_term y current_postings
                        current_term = term
                        current_postings = postings.copy()

                    next_term_postings = self.read_next_term(file)
                    if next_term_postings:
                        next_term, next_postings = next_term_postings
                        heapq.heappush(priority_queue, (next_term, idx, next_postings, bloque_path))
                        idx += 1
    
                
                if current_term is not None:
                    idf = math.log10(self.doc_ids / (1 + len(current_postings)))
                    tf_idf_postings = {}
                    for doc_id, tf in current_postings.items():
                        tf_weighted = math.log10(1 + tf)
                        tfidf = tf_weighted * idf
                        tf_idf_postings[doc_id] = {"tf": tf_weighted, "idf": idf}
    
                        # Acumular el cuadrado del TF-IDF en las normas temporales
                        doc_norms_temp[doc_id] = doc_norms_temp.get(doc_id, 0) + tfidf ** 2

                    

                    postings_data = pickle.dumps(tf_idf_postings)
                    postings_file.write(postings_data)
                    temp_term_dict[current_term] = (postings_file_position, len(postings_data))
                    # pickle.dump({current_term: (postings_file_position, len(postings_data))}, term_dict_file)
                    postings_file_position += len(postings_data)

                    #Guardamos de frente temp_term_dict
                    pickle.dump(temp_term_dict, term_dict_file) #Guardo el diccionario
                    temp_term_dict.clear()
                    
                    temp_term_dict.clear()
    
        finally:
            for file in open_files.values():
                file.close()
    
        # Guardar las normas finales tomando la raíz cuadrada
        final_norms = {int(doc_id): math.sqrt(value) for doc_id, value in doc_norms_temp.items()}
        with open(norms_file_path, 'wb') as norms_file:
            pickle.dump(final_norms, norms_file)
    
        self.term_dict_path = term_dict_path
        self.postings_file_path = postings_file_path
        print(f"Índice fusionado guardado en {postings_file_path}")
        print(f"Diccionario de términos guardado en {term_dict_path}")
        print(f"Normas de documentos guardadas en {norms_file_path}")
            # Realiza merge de todos los bloques:
            # Manejaremos un archivo para ubicar los un indice general self.indexTerms donde se guarda la posición del termino
            # En el otro archivo se guardaran completito tanto la palabra como el posting list pero ya ordenado
    
    def read_next_term(self, file):
        line = file.readline()
        if not line:  # Si llegamos al final del archivo
            return None
        term, postings_str = line.strip().split(":", 1)
        postings = json.loads(postings_str)  
        return term, postings

    #--Funciones para testing--
    def print_all_norms(self):
        if not os.path.exists(self.norms_file_path):
            print("El archivo de normas no existe. Asegúrate de haber ejecutado 'spimi_invert' correctamente.")
            return

        try:
            with open(self.norms_file_path, 'rb') as norms_file:
                norms = pickle.load(norms_file)
                if not norms:
                    print("El archivo de normas está vacío.")
                    return

                print("Normas de los documentos:")
                for doc_id, norm in sorted(norms.items()):
                    print(f"Documento ID: {doc_id}, Norma: {norm}")
        except Exception as e:
            print(f"Error al leer o procesar las normas: {e}")


    def show_terms_and_positions(self):
        print("Términos y sus posiciones en el archivo de postings:")
        all_terms = []  
        # for term, (position, length) in term_dict.items():
        #     print(f"Término: '{term}', Posición: {position}, Longitud: {length}")

        for term_dict in self.load_term_dict():  
            terms = list(term_dict.keys())
            all_terms.extend(terms)
        if all_terms == sorted(all_terms):
            print("----->Yeeeei, Los términos están ordenados alfabéticamente en el diccionario final.")
        else:
            print("Los términos NO están ordenados alfabéticamente en el diccionario final.")


    def show_terms_with_postings(self):
        if not os.path.exists(self.postings_file_path):
            print("El archivo de postings no existe. Ejecuta 'mergeHeap' primero.")
            return

        print("Términos y sus listas de postings:")
        try:
            with open(self.postings_file_path, 'rb') as postings_file:
                for term_dict in self.load_term_dict(): 
                    for term, (position, length) in term_dict.items():
                        postings_file.seek(position)  
                        postings_data = postings_file.read(length) 
                        postings = pickle.loads(postings_data) 
                        print(f"Término: '{term}', Postings: {postings}")
        except Exception as e:
            print(f"Error al mostrar los términos y postings: {e}")


    def retrieval(self, query, k):
        # Cargamos doc_ids si no está ya cargado
        if self.doc_ids is None:
            self.load_doc_ids()
    
        if self.doc_ids == 0:  
            raise ValueError("El índice no está construido o no contiene documentos. Ejecuta 'spimi_invert' antes de realizar consultas.")
        print("Se cargó en total: ", self.doc_ids, " documentos")
    
        # Preprocesar la consulta
        terms = preprocesamiento(query)
    
        tf_query = {}
        for term in terms:
            if term in tf_query:
                tf_query[term] += 1
            else:
                tf_query[term] = 1
    
        tfidf_query = {}
        norm_query = 0
    
        scores = [0] * self.doc_ids  
    
        with open(self.postings_file_path, 'rb') as postings_file, \
             open(self.norms_file_path, 'rb') as norms_file:
    
            for term_dict_block in self.load_term_dict(): # bloque por bloque gracias a yield
                for term, tf in tf_query.items():
                    if term in term_dict_block:  # Considerar términos presentes en este bloque
                        position, length = term_dict_block[term]
    
                        postings_file.seek(position)
                        postings_data = postings_file.read(length)
                        postings = pickle.loads(postings_data)  # Diccionario {doc_id: {'tf': tf, 'idf': idf}}
                        idf = math.log10(self.doc_ids / (1 + len(postings)))
    
                        tfidf_query[term] = math.log10(1 + tf) * idf
                        norm_query += (tfidf_query[term]) ** 2
    
                        w_tq = tfidf_query[term]
                        for doc_id_str, values in postings.items():
                            doc_id = int(doc_id_str)
                            tfidf_td = values['tf'] * values['idf']
                            scores[doc_id] += tfidf_td * w_tq 
    
            norm_query = math.sqrt(norm_query)
    
            norms_file.seek(0)
            norms = pickle.load(norms_file)
    
            for doc_id in range(self.doc_ids):
                doc_norm = norms.get(doc_id, 0)
                if doc_norm != 0:
                    scores[doc_id] /= (doc_norm* norm_query)
    
        result = sorted(enumerate(scores), key=lambda x: x[1], reverse=True)
        return result[:k]

# %%
# Path

# Create table tablita from path "takataka"
# ---------Creation---------
path = "spotify_2000.csv"
#--Columnas de indexacion: 
# Select "track_name","track_artist","lyrics", "track_album_name"
columnas = ["track_name","track_artist","lyrics", "track_album_name"]

s = SPIMI(path, columnas=columnas)  
s.spimi_invert() 

# ---------End Creation---------
# Out:
# Creando y ordenando cada bloque
# Iniciando ordenamiento concurrente de los bloques...
# Bloque ordenado: index_blocks\block_10.txt
# Bloque ordenado: index_blocks\block_11.txt
# Bloque ordenado: index_blocks\block_13.txt
# Bloque ordenado: index_blocks\block_0.txt
# Bloque ordenado: index_blocks\block_1.txt
# Bloque ordenado: index_blocks\block_12.txt
# Bloque ordenado: index_blocks\block_16.txt
# Bloque ordenado: index_blocks\block_14.txt
# Ordenamiento completado para: index_blocks\block_14.txt
# Ordenamiento completado para: index_blocks\block_0.txt
# Ordenamiento completado para: index_blocks\block_16.txt
# Ordenamiento completado para: index_blocks\block_12.txt
# Ordenamiento completado para: index_blocks\block_13.txt
# Ordenamiento completado para: index_blocks\block_11.txt
# Ordenamiento completado para: index_blocks\block_10.txt
# Ordenamiento completado para: index_blocks\block_1.txt
# Bloque ordenado: index_blocks\block_19.txt
# Bloque ordenado: index_blocks\block_18.txt
# Ordenamiento completado para: index_blocks\block_19.txt
# Ordenamiento completado para: index_blocks\block_18.txt
# Bloque ordenado: index_blocks\block_15.txt
# Bloque ordenado: index_blocks\block_20.txt
# Ordenamiento completado para: index_blocks\block_15.txt
# Ordenamiento completado para: index_blocks\block_20.txt
# Bloque ordenado: index_blocks\block_17.txt
# Bloque ordenado: index_blocks\block_2.txt
# Bloque ordenado: index_blocks\block_23.txt
# Ordenamiento completado para: index_blocks\block_17.txt
# Ordenamiento completado para: index_blocks\block_2.txt
# Ordenamiento completado para: index_blocks\block_23.txt
# Bloque ordenado: index_blocks\block_22.txt
# Bloque ordenado: index_blocks\block_21.txt
# Ordenamiento completado para: index_blocks\block_22.txt
# Ordenamiento completado para: index_blocks\block_21.txt
# Bloque ordenado: index_blocks\block_24.txt
# Ordenamiento completado para: index_blocks\block_24.txt
# Bloque ordenado: index_blocks\block_27.txt
# Ordenamiento completado para: index_blocks\block_27.txt
# Bloque ordenado: index_blocks\block_29.txt
# Bloque ordenado: index_blocks\block_25.txt
# Bloque ordenado: index_blocks\block_26.txt
# Ordenamiento completado para: index_blocks\block_29.txt
# Ordenamiento completado para: index_blocks\block_25.txt
# Ordenamiento completado para: index_blocks\block_26.txt
# Bloque ordenado: index_blocks\block_31.txt
# Ordenamiento completado para: index_blocks\block_31.txt
# Bloque ordenado: index_blocks\block_3.txt
# Bloque ordenado: index_blocks\block_33.txt
# Bloque ordenado: index_blocks\block_32.txt
# Ordenamiento completado para: index_blocks\block_3.txt
# Ordenamiento completado para: index_blocks\block_33.txt
# Ordenamiento completado para: index_blocks\block_32.txt
# Bloque ordenado: index_blocks\block_28.txt
# Bloque ordenado: index_blocks\block_30.txt
# Ordenamiento completado para: index_blocks\block_28.txt
# Ordenamiento completado para: index_blocks\block_30.txt
# Bloque ordenado: index_blocks\block_35.txt
# Ordenamiento completado para: index_blocks\block_35.txt
# Bloque ordenado: index_blocks\block_36.txt
# Bloque ordenado: index_blocks\block_37.txt
# Bloque ordenado: index_blocks\block_39.txt
# Ordenamiento completado para: index_blocks\block_36.txt
# Ordenamiento completado para: index_blocks\block_37.txt
# Ordenamiento completado para: index_blocks\block_39.txt
# Bloque ordenado: index_blocks\block_34.txt
# Bloque ordenado: index_blocks\block_41.txt
# Bloque ordenado: index_blocks\block_38.txt
# Ordenamiento completado para: index_blocks\block_34.txt
# Ordenamiento completado para: index_blocks\block_41.txt
# Ordenamiento completado para: index_blocks\block_38.txt
# Bloque ordenado: index_blocks\block_40.txt
# Ordenamiento completado para: index_blocks\block_40.txt
# Bloque ordenado: index_blocks\block_46.txt
# Bloque ordenado: index_blocks\block_42.txt
# Ordenamiento completado para: index_blocks\block_46.txt
# Ordenamiento completado para: index_blocks\block_42.txt
# Bloque ordenado: index_blocks\block_4.txt
# Ordenamiento completado para: index_blocks\block_4.txtBloque ordenado: index_blocks\block_43.txt
#
# Ordenamiento completado para: index_blocks\block_43.txt
# Bloque ordenado: index_blocks\block_44.txt
# Ordenamiento completado para: index_blocks\block_44.txt
# Bloque ordenado: index_blocks\block_51.txt
# Bloque ordenado: index_blocks\block_45.txt
# Ordenamiento completado para: index_blocks\block_51.txt
# Ordenamiento completado para: index_blocks\block_45.txt
# Bloque ordenado: index_blocks\block_49.txt
# Ordenamiento completado para: index_blocks\block_49.txt
# Bloque ordenado: index_blocks\block_47.txt
# Ordenamiento completado para: index_blocks\block_47.txt
# Bloque ordenado: index_blocks\block_50.txt
# Ordenamiento completado para: index_blocks\block_50.txt
# Bloque ordenado: index_blocks\block_48.txt
# Ordenamiento completado para: index_blocks\block_48.txt
# Bloque ordenado: index_blocks\block_5.txt
# Bloque ordenado: index_blocks\block_56.txt
# Bloque ordenado: index_blocks\block_53.txt
# Ordenamiento completado para: index_blocks\block_5.txt
# Ordenamiento completado para: index_blocks\block_56.txt
# Ordenamiento completado para: index_blocks\block_53.txt
# Bloque ordenado: index_blocks\block_54.txt
# Bloque ordenado: index_blocks\block_57.txt
# Bloque ordenado: index_blocks\block_52.txt
# Bloque ordenado: index_blocks\block_60.txt
# Bloque ordenado: index_blocks\block_58.txt
# Ordenamiento completado para: index_blocks\block_54.txt
# Ordenamiento completado para: index_blocks\block_57.txt
# Ordenamiento completado para: index_blocks\block_52.txt
# Ordenamiento completado para: index_blocks\block_60.txt
# Ordenamiento completado para: index_blocks\block_58.txt
# Bloque ordenado: index_blocks\block_55.txt
# Bloque ordenado: index_blocks\block_6.txt
# Bloque ordenado: index_blocks\block_61.txt
# Ordenamiento completado para: index_blocks\block_55.txt
# Ordenamiento completado para: index_blocks\block_6.txt
# Ordenamiento completado para: index_blocks\block_61.txt
# Bloque ordenado: index_blocks\block_59.txt
# Ordenamiento completado para: index_blocks\block_59.txt
# Bloque ordenado: index_blocks\block_64.txt
# Bloque ordenado: index_blocks\block_62.txt
# Ordenamiento completado para: index_blocks\block_64.txt
# Ordenamiento completado para: index_blocks\block_62.txt
# Bloque ordenado: index_blocks\block_67.txt
# Bloque ordenado: index_blocks\block_63.txt
# Ordenamiento completado para: index_blocks\block_67.txt
# Ordenamiento completado para: index_blocks\block_63.txt
# Bloque ordenado: index_blocks\block_68.txt
# Bloque ordenado: index_blocks\block_66.txt
# Bloque ordenado: index_blocks\block_7.txt
# Ordenamiento completado para: index_blocks\block_68.txt
# Ordenamiento completado para: index_blocks\block_66.txt
# Ordenamiento completado para: index_blocks\block_7.txt
# Bloque ordenado: index_blocks\block_70.txt
# Bloque ordenado: index_blocks\block_65.txt
# Ordenamiento completado para: index_blocks\block_70.txt
# Ordenamiento completado para: index_blocks\block_65.txt
# Bloque ordenado: index_blocks\block_69.txt
# Ordenamiento completado para: index_blocks\block_69.txt
# Bloque ordenado: index_blocks\block_8.txt
# Ordenamiento completado para: index_blocks\block_8.txt
# Bloque ordenado: index_blocks\block_9.txt
# Ordenamiento completado para: index_blocks\block_9.txt
# Iniciando con el merge
# Índice fusionado guardado en index_blocks_merge\postings.bin
# Diccionario de términos guardado en index_blocks_merge\term_dict.pkl
# Normas de documentos guardadas en index_blocks_merge\document_norms.pkl
#
# Resumen de tiempos:
# Tiempo para la creación Creación  y el ordenamiento de los bloques: 30.77 segundos
# Tiempo para la ejecución del merge: 2.85 segundos
# Tiempo total para la creación y el mergeo: 33.62 segundos

# %%
## Importante a partir de aqui funciona sin el s.spimi_invert(), pq todo ya está en memoria secundaria

# ----------Set Atributo--------
query = "this is my breath" # Query en texto
query = get_dfTex_Cols(path, 2, [1,2,3,6]) # Query no eficiente q solo es para el ------[testeo]------ 
# de la similitud de coseno asi q esto no se usa, esto da 2 donde o el segundo parametro es la fila del dataset
# Si deseas checkear las demas columnas: [1,2,3,6], corresponden a los numeritos de ["track_name","track_artist","lyrics", "track_album_name"]
top_k = 20

result = s.retrieval(query, top_k)
respuesta = getResultados(result, s.dataset_path, s.disk_limit) # La respuesta es un array pd de [fila del dataframe, score]
#-----------End of query------------

getResultadosDF(result, s.dataset_path, s.disk_limit)
# Out:
# Se cargó en total:  2000  documentos
#                     track_id                     track_name      track_artist  \
# 2     00chLpzhgVjxs1zKC9UScL                         Poison    Bell Biv DeVoe
# 622   0dDifktDnbzmGwliFzI0Ld                         Poison    Bell Biv DeVoe
# 237   06yHcjr58IKJnfEK7ko3sD                         Poison    Bell Biv DeVoe
# 1705  0RnDu3eYJqbFKz6MHv2ajd                         Poison    Bell Biv DeVoe
# 1199  0kYIsBXBR8bg8JN6xuqIDK            Since You Been Gone           RAINBOW
# 703   0EkB09i9ohIUnsw45jzEyf                          Toxic         Yael Naim
# 1418  0nrWZWkJM62ftQJSI8fDc0                  Diamond Heart       Alan Walker
# 501   0bTjMx79m5NMCsHDTyAwBY                   Already Dead  Hollywood Undead
# 1875  0TiC3GtlMCskf2hIUIBcDV                      Crew Love             Drake
# 1994  0V4l4GQhgnWQGtCWpvA7va                      Crew Love             Drake
# 410   0arymh4a4YsUaps34DfA7L             When Can I See You          Babyface
# 1783  0sLrHBMJNOxEcMhcseE3I4       Rollin' With Kid 'N Play       Kid 'N Play
# 458   0bIaAG656Kq0JGmw3N1TeS              One For the Money   Escape the Fate
# 939   0hmxVkpxbcdHAXUoZ7DeCQ                    Did My Best         The Voidz
# 1142  0kFM6t9htbB53Dg8frGDGh                 Kiss Me Deadly         Lita Ford
# 1809  0STdgJGzSVSv3mhAvuT7dZ  Get It on Tonite - Remastered    Montell Jordan
# 372   0AcLrSfAEBQcUnHOTm5pXg               Get It On Tonite    Montell Jordan
# 1323  0MPegzGbqTvO2tw7BqYUU8                     Go On Girl             Ne-Yo
# 365   0AA6zq5ArZ1sSH7VIMi4NK            This Is Why I'm Hot              MiMS
# 1378  0ND36delZlYUcwNaCk9Uf5                   holy terrain         FKA twigs
#
#                                                  lyrics  track_popularity  \
# 2     NA Yeah, Spyderman and Freeze in full effect U...                 0
# 622   NA Yeah, Spyderman and Freeze in full effect U...                 0
# 237   NA Yeah, Spyderman and Freeze in full effect U...                36
# 1705  NA Yeah, Spyderman and Freeze in full effect U...                48
# 1199  I get the same old dreams, same time every nig...                 6
# 703   Baby, can't you see I'm calling A guy like you...                 4
# 1418  Hello, sweet grief I know you'll be the death ...                69
# 501   It's the year of the snake Friends are overrat...                59
# 1875  Take your nose off my keyboard What you bother...                51
# 1994  Take your nose off my keyboard What you bother...                69
# 410   When can my heart beat again? When does the pa...                13
# 1783  Ho-la, ho-la, hey Ho-la, ho-la, hey Rolling ro...                43
# 458   Are you ready? Are you ready? Are you ready? A...                 0
# 939   Let me tell you a story'Bout the hazy good old...                60
# 1142  I went to a party last Saturday night I didn't...                54
# 1809  Oh, ooh wee oh, oh When I'm lookin' at you I k...                 6
# 372   Oh, ooh wee oh, oh When I'm lookin' at you I k...                51
# 1323  I can't get it back But I don't want it back I...                 2
# 365   This is why I'm hot (hot!), this is why I'm ho...                57
# 1378  Yeah, Pluto Lemme do my dance in this bitch, g...                57
#
#               track_album_id  \
# 2     6oZ6brjB8x3GoeSYdwJdPc
# 622   5AR2bbUUDI2XEMarSbs8Cn
# 237   3ExqNzkCrQkkknQbrJFqMd
# 1705  2QC1IsQIUNdEz0zgWanPkN
# 1199  4saAsJgmmKqFWTzaTdiYzC
# 703   09Cvd1XS0KwCXfMXukpvSS
# 1418  3nzuGtN3nXARvvecier4K0
# 501   250u5qE6ny6ZYUUtlVGYre
# 1875  63WdJvk8G9hxJn8u5rswNh
# 1994  6X1x82kppWZmDzlXXK3y3q
# 410   5y4ohfVVgrOEwTM74TJbuS
# 1783  1XN7cuhq8ZIvWsUUZ9xDzR
# 458   4FeqhARxrIYBYAZphCDz2Q
# 939   5q9iV6CLu4ZEzhWKmJZxnc
# 1142  5nfd1bXqze24U3EZXP1Qlk
# 1809  5DyGKg106B5LCcjjbLzI3Z
# 372   6J9fX2iXc9W7ILQUWvEhAx
# 1323  48ben69fRtEbMTGqGYU8Qw
# 365   42c0PgLPx6qRCZCzB8d7Pk
# 1378  1hDlZBsaWOz8St9iioQF0y
#
#                                        track_album_name  \
# 2                                                  Gold
# 622           Bell Biv DeVoe Greatest Hits (Remastered)
# 237                                          RnB 1990's
# 1705  20th Century Masters: The Millennium Collectio...
# 1199                                               Rock
# 703                                           Yael Naim
# 1418                                    Different World
# 501                                        Already Dead
# 1875                                 Take Care (Deluxe)
# 1994                                 Take Care (Deluxe)
# 410                                 For The Cool In You
# 1783                                             2 Hype
# 458                                 Ungrateful (Deluxe)
# 939                                         Did My Best
# 1142                                               Lita
# 1809           New Jack Swing (The Ultimate Collection)
# 372                              Best Of Montell Jordan
# 1323                                     Because Of You
# 365                                  Music Is My Savior
# 1378                                       holy terrain
#
#      track_album_release_date  \
# 2                  2005-01-01
# 622                      2000
# 237                2019-07-19
# 1705               2002-01-01
# 1199               2003-01-01
# 703                2007-10-22
# 1418               2018-12-14
# 501                2019-10-25
# 1875               2011-11-15
# 1994               2011-11-15
# 410                1993-08-24
# 1783                     1988
# 458                2013-05-14
# 939                2019-12-13
# 1142               1988-01-02
# 1809               2005-05-02
# 372                2015-09-25
# 1323               2007-01-01
# 365                2007-01-01
# 1378               2019-09-09
#
#                                           playlist_name  \
# 2     Back in the day - R&B, New Jack Swing, Swingbe...
# 622                                      New Jack Swing
# 237                                 CSR 103:9 (GTA: SA)
# 1705           New Jack Swing - 90s R&B fused w Hip Hop
# 1199                70s Pop & Rock Hits and Deep Tracks
# 703                                    Bluegrass Covers
# 1418                                    Dance Pop Tunes
# 501                                           Rock Hard
# 1875                                 Urban Contemporary
# 1994                              PROJECT: Contemporary
# 410                                      New Jack Swing
# 1783                               Minitruckin Playlist
# 458                                       New Hard Rock
# 939   Modern Indie Rock // Alternative Rock / Garage...
# 1142                                     ’80s Hard Rock
# 1809  Swingbeat (old skool), New Jack Swing, R&B, Hi...
# 372                               90s/00s Hip Hop & RnB
# 1323                     Ultimate Throwbacks Collection
# 365                  90s-2000s Southern Hip Hop / Crunk
# 1378                                    New R&B‏‏​​   ‍
#
#                  playlist_id  ... mode speechiness  acousticness  \
# 2     3a9y4eeCJRmG9p4YKfqYIx  ...    0      0.2160      0.004320
# 622   3ykXidKLz1eYPvuGoFlD1e  ...    0      0.2100      0.002060
# 237   4sr2xEhXQR5VuZ0LZX8TQ8  ...    0      0.2100      0.001950
# 1705  79xd4wnVuKZK4rJMsL2wPa  ...    0      0.1920      0.002150
# 1199  1uKFRCQYci8kVgMy3xzTVH  ...    1      0.0370      0.362000
# 703   37i9dQZF1DX56crgoe4TG3  ...    1      0.0632      0.605000
# 1418  4SdfG4cPG3skmTiQLozZGh  ...    1      0.0345      0.123000
# 501   37i9dQZF1DWWJOmJ7nRx0C  ...    1      0.4080      0.000439
# 1875  4Pbs84EQbuAblxlp6Chz0d  ...    0      0.2380      0.227000
# 1994  6HaCi9bqaiuSZEDfCEmwyo  ...    0      0.2380      0.227000
# 410   3ykXidKLz1eYPvuGoFlD1e  ...    1      0.0602      0.251000
# 1783  0VVH2Nzj6kBVGK3WIUQMAw  ...    1      0.1330      0.036200
# 458   64BvJcehegyvhqQtV82Ddz  ...    0      0.0554      0.000355
# 939   1VnvyBDqoV5TCZAnXYferL  ...    0      0.0371      0.154000
# 1142  37i9dQZF1DX68H8ZujdnN7  ...    1      0.0326      0.008190
# 1809  3krpccUV68nBGAQbvHEZDC  ...    0      0.0873      0.250000
# 372   0Ar0Ng9DlAWZtSPBvOQgOa  ...    0      0.0755      0.259000
# 1323  1dsaMvnC1hXPCNGC4aVtjj  ...    1      0.1090      0.155000
# 365   5wsWBmQgDtKa8CEg7wTEMi  ...    1      0.5760      0.277000
# 1378  4I6rTSxqKl1LRvES2O9owQ  ...    0      0.1230      0.366000
#
#       instrumentalness  liveness  valence    tempo  duration_ms  language  \
# 2             0.007230    0.4890    0.650  111.904       262467        en
# 622           0.001830    0.6340    0.783  111.879       261627        en
# 237           0.004170    0.6330    0.775  111.815       261853        en
# 1705          0.002680    0.6270    0.802  111.857       262027        en
# 1199          0.000004    0.5590    0.934  120.875       194000        en
# 703           0.000056    0.0685    0.157  120.043       267226        en
# 1418          0.000000    0.4100    0.287   89.909       240333        en
# 501           0.000000    0.1310    0.303  159.978       236734        en
# 1875          0.000000    0.2290    0.294  160.152       208813        en
# 1994          0.000000    0.2290    0.294  160.152       208813        en
# 410           0.000014    0.1150    0.573   84.612       229307        en
# 1783          0.004980    0.0461    0.739  103.013       243800        en
# 458           0.000004    0.0577    0.416   90.039       199960        en
# 939           0.888000    0.1060    0.623  120.209       296939        en
# 1142          0.000079    0.3690    0.648  156.103       241800        en
# 1809          0.000053    0.0841    0.855   98.996       276267        en
# 372           0.000030    0.0618    0.857   99.001       277413        en
# 1323          0.000000    0.0945    0.562   83.896       261427        en
# 365           0.000000    0.4950    0.485   80.021       253707        en
# 1378          0.004320    0.1190    0.252  159.832       243000        en
#
#          score
# 2     1.000000
# 622   0.994159
# 237   0.983802
# 1705  0.968680
# 1199  0.120369
# 703   0.111347
# 1418  0.110368
# 501   0.109022
# 1875  0.102159
# 1994  0.102159
# 410   0.101216
# 1783  0.099471
# 458   0.098697
# 939   0.097655
# 1142  0.097421
# 1809  0.093157
# 372   0.092600
# 1323  0.090622
# 365   0.090051
# 1378  0.086842
#
# [20 rows x 26 columns]

# %%
import os
import time
import shutil
import pandas as pd
import matplotlib.pyplot as plt

# Configuración
pathDatasets = "datasets/"
datasets = ["spotify_1000.csv", "spotify_2000.csv", "spotify_4000.csv", "spotify_8000.csv"]
datasets = ["spotify_1000.csv", "spotify_2000.csv", "spotify_4000.csv", "spotify_8000.csv","spotify_16000.csv", "spotify_32000.csv"]
# datasets = ["spotify_16000.csv", "spotify_32000.csv"]

# Querys
queries = [
    """Don't sweat all the little things 
    Just keep your eye on the bigger things
    Cause if you look a little closer 
    You're gonna get a bigger picture""",
    """I'mma make your CXRPSE dance
    Ugh, hop in that Jag, do the dash
    I shoot a nigga then laugh
    Bitch, don't talk to me if you ain't on that"""
]

def limpiar_directorios(directorios):
    for directorio in directorios:
        if os.path.exists(directorio):
            shutil.rmtree(directorio)
            print(f"Directorio eliminado: {directorio}")

def medir_tiempos(pathDatasets, datasets, queries, columnas = ["track_name","track_artist","lyrics", "track_album_name"]):
    tiempos_creacion = []
    tiempos_consulta = {dataset: [] for dataset in datasets}
    
    for dataset in datasets:
        dataset_path = os.path.join(pathDatasets, dataset)
        
        start_creacion = time.time()
        s = SPIMI(dataset_path, columnas=columnas)
        s.spimi_invert()
        end_creacion = time.time()
        tiempos_creacion.append(end_creacion - start_creacion)
        
        for query in queries:
            start_consulta = time.time()
            result = s.retrieval(query, 20)
            respuesta = getResultadosDF(result, dataset_path, disk_limit=s.disk_limit)
            end_consulta = time.time()
            tiempos_consulta[dataset].append(end_consulta - start_consulta)
        
        limpiar_directorios(["index_blocks", "index_blocks_merge"])
    
    return tiempos_creacion, tiempos_consulta

tiempos_creacion, tiempos_consulta = medir_tiempos(pathDatasets, datasets, queries)

os.makedirs("tiempos", exist_ok=True)

consulta_promedios = [
    sum(tiempos_consulta[dataset]) / len(queries) for dataset in datasets
]

df_resultados = pd.DataFrame({
    "Dataset": datasets,
    "Tiempo_Creacion (s)": tiempos_creacion,
    "Tiempo_Consulta_Promedio (s)": consulta_promedios
})

resultados_path = os.path.join("tiempos", "resultadosConcurrent.csv")
df_resultados.to_csv(resultados_path, index=False)

# Mostrar mensaje de finalización
print(f"Resultados guardados en {resultados_path}")
# Out:
# Creando y ordenando cada bloque
# Iniciando ordenamiento concurrente de los bloques...
# Bloque ordenado: index_blocks\block_0.txt
# Bloque ordenado: index_blocks\block_12.txt
# Ordenamiento completado para: index_blocks\block_0.txt
# Ordenamiento completado para: index_blocks\block_12.txt
# Bloque ordenado: index_blocks\block_11.txt
# Ordenamiento completado para: index_blocks\block_11.txt
# Bloque ordenado: index_blocks\block_15.txt
# Bloque ordenado: index_blocks\block_13.txt
# Bloque ordenado: index_blocks\block_17.txt
# Bloque ordenado: index_blocks\block_10.txt
# Bloque ordenado: index_blocks\block_1.txt
# Ordenamiento completado para: index_blocks\block_15.txt
# Ordenamiento completado para: index_blocks\block_13.txt
# Ordenamiento completado para: index_blocks\block_17.txt
# Ordenamiento completado para: index_blocks\block_10.txt
# Ordenamiento completado para: index_blocks\block_1.txt
# Bloque ordenado: index_blocks\block_18.txt
# Bloque ordenado: index_blocks\block_21.txt
# Bloque ordenado: index_blocks\block_23.txt
# Bloque ordenado: index_blocks\block_20.txt
# Bloque ordenado: index_blocks\block_14.txt
# Ordenamiento completado para: index_blocks\block_18.txt
# Ordenamiento completado para: index_blocks\block_21.txt
# Ordenamiento completado para: index_blocks\block_23.txt
# Ordenamiento completado para: index_blocks\block_20.txt
# Ordenamiento completado para: index_blocks\block_14.txt
# Bloque ordenado: index_blocks\block_2.txt
# Ordenamiento completado para: index_blocks\block_2.txt
# Bloque ordenado: index_blocks\block_22.txt
# Bloque ordenado: index_blocks\block_16.txt
# Ordenamiento completado para: index_blocks\block_22.txt
# Ordenamiento completado para: index_blocks\block_16.txt
# Bloque ordenado: index_blocks\block_24.txt
# Bloque ordenado: index_blocks\block_26.txt
# Bloque ordenado: index_blocks\block_25.txt
# Bloque ordenado: index_blocks\block_19.txt
# Ordenamiento completado para: index_blocks\block_24.txt
# Ordenamiento completado para: index_blocks\block_26.txt
# Ordenamiento completado para: index_blocks\block_25.txt
# Ordenamiento completado para: index_blocks\block_19.txt
# Bloque ordenado: index_blocks\block_27.txt
# Ordenamiento completado para: index_blocks\block_27.txt
# Bloque ordenado: index_blocks\block_28.txt
# Ordenamiento completado para: index_blocks\block_28.txt
# Bloque ordenado: index_blocks\block_29.txt
# Bloque ordenado: index_blocks\block_33.txt
# Ordenamiento completado para: index_blocks\block_29.txt
# Ordenamiento completado para: index_blocks\block_33.txt
# Bloque ordenado: index_blocks\block_32.txt
# Bloque ordenado: index_blocks\block_7.txt
# Ordenamiento completado para: index_blocks\block_32.txt
# Ordenamiento completado para: index_blocks\block_7.txt
# Bloque ordenado: index_blocks\block_8.txt
# Ordenamiento completado para: index_blocks\block_8.txt
# Bloque ordenado: index_blocks\block_30.txt
# Bloque ordenado: index_blocks\block_6.txt
# Bloque ordenado: index_blocks\block_4.txt
# Bloque ordenado: index_blocks\block_3.txt
# Ordenamiento completado para: index_blocks\block_30.txt
# Ordenamiento completado para: index_blocks\block_6.txt
# Ordenamiento completado para: index_blocks\block_4.txt
# Ordenamiento completado para: index_blocks\block_3.txt
# Bloque ordenado: index_blocks\block_34.txt
# Ordenamiento completado para: index_blocks\block_34.txt
# Bloque ordenado: index_blocks\block_5.txt
# Bloque ordenado: index_blocks\block_31.txt
# Bloque ordenado: index_blocks\block_9.txt
# Ordenamiento completado para: index_blocks\block_5.txt
# Ordenamiento completado para: index_blocks\block_31.txt
# Ordenamiento completado para: index_blocks\block_9.txt
# Iniciando con el merge
# Índice fusionado guardado en index_blocks_merge\postings.bin
# Diccionario de términos guardado en index_blocks_merge\term_dict.pkl
# Normas de documentos guardadas en index_blocks_merge\document_norms.pkl
#
# Resumen de tiempos:
# Tiempo para la creación Creación  y el ordenamiento de los bloques: 14.64 segundos
# Tiempo para la ejecución del merge: 1.39 segundos
# Tiempo total para la creación y el mergeo: 16.03 segundos
# Se cargó en total:  1000  documentos
# Se cargó en total:  1000  documentos
# Directorio eliminado: index_blocks
# Directorio eliminado: index_blocks_merge
# Creando y ordenando cada bloque
# Iniciando ordenamiento concurrente de los bloques...
# Bloque ordenado: index_blocks\block_1.txt
# Bloque ordenado: index_blocks\block_12.txt
# Bloque ordenado: index_blocks\block_10.txt
# Bloque ordenado: index_blocks\block_11.txt
# Bloque ordenado: index_blocks\block_13.txt
# Bloque ordenado: index_blocks\block_0.txt
# Bloque ordenado: index_blocks\block_14.txt
# Bloque ordenado: index_blocks\block_17.txt
# Bloque ordenado: index_blocks\block_18.txt
# Bloque ordenado: index_blocks\block_15.txt
# Ordenamiento completado para: index_blocks\block_18.txt
# Ordenamiento completado para: index_blocks\block_0.txt
# Ordenamiento completado para: index_blocks\block_15.txt
# Ordenamiento completado para: index_blocks\block_10.txt
# Ordenamiento completado para: index_blocks\block_1.txt
# Ordenamiento completado para: index_blocks\block_13.txt
# Ordenamiento completado para: index_blocks\block_17.txt
# Ordenamiento completado para: index_blocks\block_12.txt
# Ordenamiento completado para: index_blocks\block_14.txt
# Ordenamiento completado para: index_blocks\block_11.txt
# Bloque ordenado: index_blocks\block_2.txt
# Ordenamiento completado para: index_blocks\block_2.txt
# Bloque ordenado: index_blocks\block_19.txt
# Bloque ordenado: index_blocks\block_23.txt
# Bloque ordenado: index_blocks\block_20.txt
# Bloque ordenado: index_blocks\block_21.txt
# Ordenamiento completado para: index_blocks\block_19.txt
# Ordenamiento completado para: index_blocks\block_23.txt
# Ordenamiento completado para: index_blocks\block_20.txt
# Ordenamiento completado para: index_blocks\block_21.txt
# Bloque ordenado: index_blocks\block_16.txt
# Ordenamiento completado para: index_blocks\block_16.txt
# Bloque ordenado: index_blocks\block_25.txt
# Bloque ordenado: index_blocks\block_27.txt
# Bloque ordenado: index_blocks\block_22.txt
# Bloque ordenado: index_blocks\block_31.txt
# Ordenamiento completado para: index_blocks\block_25.txt
# Ordenamiento completado para: index_blocks\block_27.txt
# Ordenamiento completado para: index_blocks\block_22.txt
# Ordenamiento completado para: index_blocks\block_31.txt
# Bloque ordenado: index_blocks\block_26.txt
# Bloque ordenado: index_blocks\block_24.txt
# Bloque ordenado: index_blocks\block_32.txt
# Ordenamiento completado para: index_blocks\block_26.txt
# Ordenamiento completado para: index_blocks\block_24.txt
# Ordenamiento completado para: index_blocks\block_32.txt
# Bloque ordenado: index_blocks\block_29.txt
# Bloque ordenado: index_blocks\block_35.txt
# Bloque ordenado: index_blocks\block_28.txt
# Ordenamiento completado para: index_blocks\block_29.txt
# Ordenamiento completado para: index_blocks\block_35.txt
# Ordenamiento completado para: index_blocks\block_28.txt
# Bloque ordenado: index_blocks\block_30.txt
# Ordenamiento completado para: index_blocks\block_30.txt
# Bloque ordenado: index_blocks\block_33.txt
# Bloque ordenado: index_blocks\block_34.txt
# Bloque ordenado: index_blocks\block_3.txt
# Ordenamiento completado para: index_blocks\block_33.txt
# Ordenamiento completado para: index_blocks\block_34.txt
# Ordenamiento completado para: index_blocks\block_3.txt
# Bloque ordenado: index_blocks\block_36.txt
# Bloque ordenado: index_blocks\block_38.txt
# Ordenamiento completado para: index_blocks\block_36.txt
# Ordenamiento completado para: index_blocks\block_38.txt
# Bloque ordenado: index_blocks\block_43.txt
# Bloque ordenado: index_blocks\block_4.txt
# Bloque ordenado: index_blocks\block_42.txt
# Ordenamiento completado para: index_blocks\block_43.txt
# Ordenamiento completado para: index_blocks\block_4.txt
# Ordenamiento completado para: index_blocks\block_42.txt
# Bloque ordenado: index_blocks\block_37.txt
# Bloque ordenado: index_blocks\block_41.txt
# Ordenamiento completado para: index_blocks\block_37.txt
# Ordenamiento completado para: index_blocks\block_41.txt
# Bloque ordenado: index_blocks\block_46.txt
# Bloque ordenado: index_blocks\block_39.txt
# Bloque ordenado: index_blocks\block_47.txt
# Bloque ordenado: index_blocks\block_45.txt
# Ordenamiento completado para: index_blocks\block_46.txt
# Ordenamiento completado para: index_blocks\block_39.txt
# Ordenamiento completado para: index_blocks\block_47.txt
# Ordenamiento completado para: index_blocks\block_45.txt
# Bloque ordenado: index_blocks\block_40.txt
# Ordenamiento completado para: index_blocks\block_40.txt
# Bloque ordenado: index_blocks\block_49.txt
# Ordenamiento completado para: index_blocks\block_49.txt
# Bloque ordenado: index_blocks\block_5.txt
# Bloque ordenado: index_blocks\block_51.txt
# Bloque ordenado: index_blocks\block_50.txt
# Bloque ordenado: index_blocks\block_44.txt
# Bloque ordenado: index_blocks\block_57.txt
# Ordenamiento completado para: index_blocks\block_5.txt
# Ordenamiento completado para: index_blocks\block_51.txt
# Ordenamiento completado para: index_blocks\block_50.txt
# Ordenamiento completado para: index_blocks\block_44.txt
# Ordenamiento completado para: index_blocks\block_57.txt
# Bloque ordenado: index_blocks\block_48.txt
# Bloque ordenado: index_blocks\block_53.txt
# Bloque ordenado: index_blocks\block_55.txt
# Ordenamiento completado para: index_blocks\block_48.txt
# Ordenamiento completado para: index_blocks\block_53.txt
# Ordenamiento completado para: index_blocks\block_55.txt
# Bloque ordenado: index_blocks\block_54.txt
# Bloque ordenado: index_blocks\block_60.txt
# Ordenamiento completado para: index_blocks\block_54.txt
# Ordenamiento completado para: index_blocks\block_60.txt
# Bloque ordenado: index_blocks\block_58.txt
# Bloque ordenado: index_blocks\block_62.txt
# Ordenamiento completado para: index_blocks\block_58.txt
# Ordenamiento completado para: index_blocks\block_62.txt
# Bloque ordenado: index_blocks\block_59.txt
# Ordenamiento completado para: index_blocks\block_59.txt
# Bloque ordenado: index_blocks\block_52.txt
# Ordenamiento completado para: index_blocks\block_52.txt
# Bloque ordenado: index_blocks\block_6.txt
# Bloque ordenado: index_blocks\block_56.txt
# Bloque ordenado: index_blocks\block_63.txt
# Ordenamiento completado para: index_blocks\block_6.txt
# Ordenamiento completado para: index_blocks\block_56.txt
# Ordenamiento completado para: index_blocks\block_63.txt
# Bloque ordenado: index_blocks\block_61.txt
# Ordenamiento completado para: index_blocks\block_61.txt
# Bloque ordenado: index_blocks\block_67.txt
# Ordenamiento completado para: index_blocks\block_67.txt
# Bloque ordenado: index_blocks\block_70.txt
# Bloque ordenado: index_blocks\block_64.txt
# Ordenamiento completado para: index_blocks\block_70.txt
# Ordenamiento completado para: index_blocks\block_64.txt
# Bloque ordenado: index_blocks\block_65.txt
# Bloque ordenado: index_blocks\block_69.txt
# Bloque ordenado: index_blocks\block_68.txt
# Ordenamiento completado para: index_blocks\block_65.txt
# Ordenamiento completado para: index_blocks\block_69.txt
# Ordenamiento completado para: index_blocks\block_68.txt
# Bloque ordenado: index_blocks\block_66.txt
# Bloque ordenado: index_blocks\block_9.txt
# Ordenamiento completado para: index_blocks\block_66.txt
# Ordenamiento completado para: index_blocks\block_9.txt
# Bloque ordenado: index_blocks\block_8.txt
# Ordenamiento completado para: index_blocks\block_8.txt
# Bloque ordenado: index_blocks\block_7.txt
# Ordenamiento completado para: index_blocks\block_7.txt
# Iniciando con el merge
# Índice fusionado guardado en index_blocks_merge\postings.bin
# Diccionario de términos guardado en index_blocks_merge\term_dict.pkl
# Normas de documentos guardadas en index_blocks_merge\document_norms.pkl
#
# Resumen de tiempos:
# Tiempo para la creación Creación  y el ordenamiento de los bloques: 28.98 segundos
# Tiempo para la ejecución del merge: 2.58 segundos
# Tiempo total para la creación y el mergeo: 31.56 segundos
# Se cargó en total:  2000  documentos
# Se cargó en total:  2000  documentos
# Directorio eliminado: index_blocks
# Directorio eliminado: index_blocks_merge
# Creando y ordenando cada bloque
# Iniciando ordenamiento concurrente de los bloques...
# Bloque ordenado: index_blocks\block_1.txt
# Bloque ordenado: index_blocks\block_100.txt
# Bloque ordenado: index_blocks\block_10.txt
# Bloque ordenado: index_blocks\block_101.txt
# Bloque ordenado: index_blocks\block_0.txt
# Bloque ordenado: index_blocks\block_103.txt
# Ordenamiento completado para: index_blocks\block_0.txt
# Ordenamiento completado para: index_blocks\block_101.txt
# Ordenamiento completado para: index_blocks\block_1.txt
# Ordenamiento completado para: index_blocks\block_10.txt
# Ordenamiento completado para: index_blocks\block_103.txt
# Ordenamiento completado para: index_blocks\block_100.txt
# Bloque ordenado: index_blocks\block_106.txt
# Bloque ordenado: index_blocks\block_104.txt
# Bloque ordenado: index_blocks\block_102.txt
# Ordenamiento completado para: index_blocks\block_106.txt
# Ordenamiento completado para: index_blocks\block_104.txt
# Ordenamiento completado para: index_blocks\block_102.txt
# Bloque ordenado: index_blocks\block_107.txt
# Bloque ordenado: index_blocks\block_108.txt
# Ordenamiento completado para: index_blocks\block_107.txt
# Ordenamiento completado para: index_blocks\block_108.txt
# Bloque ordenado: index_blocks\block_105.txt
# Ordenamiento completado para: index_blocks\block_105.txt
# Bloque ordenado: index_blocks\block_11.txt
# Ordenamiento completado para: index_blocks\block_11.txt
# Bloque ordenado: index_blocks\block_111.txt
# Ordenamiento completado para: index_blocks\block_111.txt
# Bloque ordenado: index_blocks\block_109.txt
# Ordenamiento completado para: index_blocks\block_109.txt
# Bloque ordenado: index_blocks\block_119.txt
# Ordenamiento completado para: index_blocks\block_119.txt
# Bloque ordenado: index_blocks\block_118.txt
# Bloque ordenado: index_blocks\block_120.txt
# Bloque ordenado: index_blocks\block_115.txt
# Bloque ordenado: index_blocks\block_113.txt
# Bloque ordenado: index_blocks\block_110.txt
# Bloque ordenado: index_blocks\block_116.txt
# Bloque ordenado: index_blocks\block_122.txt
# Bloque ordenado: index_blocks\block_112.txt
# Ordenamiento completado para: index_blocks\block_118.txt
# Ordenamiento completado para: index_blocks\block_120.txt
# Ordenamiento completado para: index_blocks\block_115.txt
# Ordenamiento completado para: index_blocks\block_113.txt
# Ordenamiento completado para: index_blocks\block_110.txt
# Ordenamiento completado para: index_blocks\block_116.txt
# Ordenamiento completado para: index_blocks\block_122.txt
# Ordenamiento completado para: index_blocks\block_112.txt
# Bloque ordenado: index_blocks\block_12.txt
# Bloque ordenado: index_blocks\block_117.txt
# Bloque ordenado: index_blocks\block_127.txt
# Bloque ordenado: index_blocks\block_126.txt
# Ordenamiento completado para: index_blocks\block_12.txt
# Ordenamiento completado para: index_blocks\block_117.txt
# Ordenamiento completado para: index_blocks\block_127.txt
# Ordenamiento completado para: index_blocks\block_126.txt
# Bloque ordenado: index_blocks\block_114.txt
# Bloque ordenado: index_blocks\block_123.txt
# Ordenamiento completado para: index_blocks\block_114.txt
# Ordenamiento completado para: index_blocks\block_123.txt
# Bloque ordenado: index_blocks\block_121.txt
# Bloque ordenado: index_blocks\block_124.txt
# Ordenamiento completado para: index_blocks\block_121.txt
# Ordenamiento completado para: index_blocks\block_124.txt
# Bloque ordenado: index_blocks\block_129.txt
# Ordenamiento completado para: index_blocks\block_129.txt
# Bloque ordenado: index_blocks\block_13.txt
# Bloque ordenado: index_blocks\block_125.txt
# Bloque ordenado: index_blocks\block_134.txt
# Bloque ordenado: index_blocks\block_138.txt
# Ordenamiento completado para: index_blocks\block_13.txt
# Ordenamiento completado para: index_blocks\block_125.txt
# Ordenamiento completado para: index_blocks\block_134.txt
# Ordenamiento completado para: index_blocks\block_138.txt
# Bloque ordenado: index_blocks\block_132.txt
# Ordenamiento completado para: index_blocks\block_132.txt
# Bloque ordenado: index_blocks\block_133.txt
# Ordenamiento completado para: index_blocks\block_133.txt
# Bloque ordenado: index_blocks\block_137.txt
# Bloque ordenado: index_blocks\block_128.txt
# Bloque ordenado: index_blocks\block_130.txt
# Bloque ordenado: index_blocks\block_136.txt
# Ordenamiento completado para: index_blocks\block_137.txt
# Ordenamiento completado para: index_blocks\block_128.txt
# Ordenamiento completado para: index_blocks\block_130.txt
# Ordenamiento completado para: index_blocks\block_136.txt
# Bloque ordenado: index_blocks\block_135.txt
# Bloque ordenado: index_blocks\block_14.txt
# Ordenamiento completado para: index_blocks\block_135.txt
# Ordenamiento completado para: index_blocks\block_14.txt
# Bloque ordenado: index_blocks\block_17.txt
# Ordenamiento completado para: index_blocks\block_17.txt
# Bloque ordenado: index_blocks\block_131.txt
# Bloque ordenado: index_blocks\block_15.txt
# Bloque ordenado: index_blocks\block_16.txt
# Bloque ordenado: index_blocks\block_18.txt
# Ordenamiento completado para: index_blocks\block_131.txt
# Ordenamiento completado para: index_blocks\block_15.txt
# Ordenamiento completado para: index_blocks\block_16.txt
# Ordenamiento completado para: index_blocks\block_18.txt
# Bloque ordenado: index_blocks\block_2.txt
# Bloque ordenado: index_blocks\block_20.txt
# Bloque ordenado: index_blocks\block_19.txt
# Ordenamiento completado para: index_blocks\block_2.txt
# Ordenamiento completado para: index_blocks\block_20.txt
# Ordenamiento completado para: index_blocks\block_19.txt
# Bloque ordenado: index_blocks\block_24.txt
# Bloque ordenado: index_blocks\block_21.txt
# Ordenamiento completado para: index_blocks\block_24.txt
# Ordenamiento completado para: index_blocks\block_21.txt
# Bloque ordenado: index_blocks\block_23.txt
# Bloque ordenado: index_blocks\block_26.txt
# Bloque ordenado: index_blocks\block_3.txt
# Ordenamiento completado para: index_blocks\block_23.txt
# Ordenamiento completado para: index_blocks\block_26.txt
# Ordenamiento completado para: index_blocks\block_3.txt
# Bloque ordenado: index_blocks\block_25.txt
# Bloque ordenado: index_blocks\block_22.txt
# Bloque ordenado: index_blocks\block_33.txt
# Bloque ordenado: index_blocks\block_30.txt
# Bloque ordenado: index_blocks\block_27.txt
# Ordenamiento completado para: index_blocks\block_25.txt
# Ordenamiento completado para: index_blocks\block_22.txt
# Ordenamiento completado para: index_blocks\block_33.txt
# Ordenamiento completado para: index_blocks\block_30.txt
# Ordenamiento completado para: index_blocks\block_27.txt
# Bloque ordenado: index_blocks\block_29.txt
# Ordenamiento completado para: index_blocks\block_29.txt
# Bloque ordenado: index_blocks\block_28.txt
# Bloque ordenado: index_blocks\block_35.txt
# Ordenamiento completado para: index_blocks\block_28.txt
# Ordenamiento completado para: index_blocks\block_35.txt
# Bloque ordenado: index_blocks\block_31.txt
# Ordenamiento completado para: index_blocks\block_31.txt
# Bloque ordenado: index_blocks\block_32.txt
# Bloque ordenado: index_blocks\block_39.txt
# Ordenamiento completado para: index_blocks\block_32.txt
# Ordenamiento completado para: index_blocks\block_39.txt
# Bloque ordenado: index_blocks\block_34.txt
# Bloque ordenado: index_blocks\block_38.txt
# Ordenamiento completado para: index_blocks\block_34.txt
# Ordenamiento completado para: index_blocks\block_38.txt
# Bloque ordenado: index_blocks\block_37.txt
# Ordenamiento completado para: index_blocks\block_37.txt
# Bloque ordenado: index_blocks\block_36.txt
# Bloque ordenado: index_blocks\block_40.txt
# Ordenamiento completado para: index_blocks\block_36.txt
# Ordenamiento completado para: index_blocks\block_40.txt
# Bloque ordenado: index_blocks\block_43.txt
# Ordenamiento completado para: index_blocks\block_43.txt
# Bloque ordenado: index_blocks\block_42.txt
# Ordenamiento completado para: index_blocks\block_42.txt
# Bloque ordenado: index_blocks\block_4.txt
# Bloque ordenado: index_blocks\block_44.txt
# Bloque ordenado: index_blocks\block_41.txt
# Ordenamiento completado para: index_blocks\block_4.txt
# Ordenamiento completado para: index_blocks\block_44.txt
# Ordenamiento completado para: index_blocks\block_41.txt
# Bloque ordenado: index_blocks\block_49.txt
# Ordenamiento completado para: index_blocks\block_49.txt
# Bloque ordenado: index_blocks\block_5.txt
# Bloque ordenado: index_blocks\block_48.txt
# Bloque ordenado: index_blocks\block_47.txt
# Ordenamiento completado para: index_blocks\block_5.txt
# Ordenamiento completado para: index_blocks\block_48.txt
# Ordenamiento completado para: index_blocks\block_47.txt
# Bloque ordenado: index_blocks\block_50.txt
# Ordenamiento completado para: index_blocks\block_50.txt
# Bloque ordenado: index_blocks\block_45.txt
# Ordenamiento completado para: index_blocks\block_45.txt
# Bloque ordenado: index_blocks\block_46.txt
# Ordenamiento completado para: index_blocks\block_46.txt
# Bloque ordenado: index_blocks\block_51.txt
# Ordenamiento completado para: index_blocks\block_51.txt
# Bloque ordenado: index_blocks\block_56.txt
# Bloque ordenado: index_blocks\block_54.txt
# Bloque ordenado: index_blocks\block_53.txt
# Ordenamiento completado para: index_blocks\block_56.txt
# Ordenamiento completado para: index_blocks\block_54.txt
# Ordenamiento completado para: index_blocks\block_53.txt
# Bloque ordenado: index_blocks\block_58.txt
# Ordenamiento completado para: index_blocks\block_58.txt
# Bloque ordenado: index_blocks\block_57.txt
# Ordenamiento completado para: index_blocks\block_57.txt
# Bloque ordenado: index_blocks\block_60.txt
# Bloque ordenado: index_blocks\block_52.txt
# Bloque ordenado: index_blocks\block_55.txt
# Ordenamiento completado para: index_blocks\block_60.txt
# Ordenamiento completado para: index_blocks\block_52.txt
# Ordenamiento completado para: index_blocks\block_55.txt
# Bloque ordenado: index_blocks\block_62.txt
# Bloque ordenado: index_blocks\block_67.txt
# Ordenamiento completado para: index_blocks\block_62.txt
# Ordenamiento completado para: index_blocks\block_67.txt
# Bloque ordenado: index_blocks\block_65.txt
# Bloque ordenado: index_blocks\block_59.txt
# Ordenamiento completado para: index_blocks\block_59.txt
# Ordenamiento completado para: index_blocks\block_65.txt
# Bloque ordenado: index_blocks\block_6.txt
# Bloque ordenado: index_blocks\block_69.txt
# Ordenamiento completado para: index_blocks\block_6.txt
# Ordenamiento completado para: index_blocks\block_69.txt
# Bloque ordenado: index_blocks\block_61.txt
# Ordenamiento completado para: index_blocks\block_61.txt
# Bloque ordenado: index_blocks\block_64.txt
# Bloque ordenado: index_blocks\block_63.txt
# Ordenamiento completado para: index_blocks\block_64.txt
# Ordenamiento completado para: index_blocks\block_63.txt
# Bloque ordenado: index_blocks\block_66.txt
# Bloque ordenado: index_blocks\block_68.txt
# Ordenamiento completado para: index_blocks\block_66.txt
# Ordenamiento completado para: index_blocks\block_68.txt
# Bloque ordenado: index_blocks\block_7.txt
# Bloque ordenado: index_blocks\block_71.txt
# Ordenamiento completado para: index_blocks\block_7.txt
# Ordenamiento completado para: index_blocks\block_71.txt
# Bloque ordenado: index_blocks\block_75.txt
# Bloque ordenado: index_blocks\block_77.txt
# Ordenamiento completado para: index_blocks\block_75.txt
# Ordenamiento completado para: index_blocks\block_77.txt
# Bloque ordenado: index_blocks\block_73.txt
# Bloque ordenado: index_blocks\block_76.txt
# Ordenamiento completado para: index_blocks\block_73.txt
# Ordenamiento completado para: index_blocks\block_76.txt
# Bloque ordenado: index_blocks\block_70.txt
# Bloque ordenado: index_blocks\block_72.txt
# Bloque ordenado: index_blocks\block_82.txt
# Bloque ordenado: index_blocks\block_74.txt
# Bloque ordenado: index_blocks\block_79.txt
# Ordenamiento completado para: index_blocks\block_70.txt
# Ordenamiento completado para: index_blocks\block_72.txt
# Ordenamiento completado para: index_blocks\block_82.txt
# Ordenamiento completado para: index_blocks\block_74.txt
# Ordenamiento completado para: index_blocks\block_79.txt
# Bloque ordenado: index_blocks\block_88.txt
# Ordenamiento completado para: index_blocks\block_88.txt
# Bloque ordenado: index_blocks\block_80.txt
# Bloque ordenado: index_blocks\block_83.txt
# Bloque ordenado: index_blocks\block_78.txt
# Bloque ordenado: index_blocks\block_86.txt
# Ordenamiento completado para: index_blocks\block_80.txt
# Ordenamiento completado para: index_blocks\block_83.txt
# Ordenamiento completado para: index_blocks\block_78.txt
# Ordenamiento completado para: index_blocks\block_86.txt
# Bloque ordenado: index_blocks\block_85.txt
# Ordenamiento completado para: index_blocks\block_85.txt
# Bloque ordenado: index_blocks\block_8.txt
# Bloque ordenado: index_blocks\block_81.txt
# Ordenamiento completado para: index_blocks\block_8.txt
# Ordenamiento completado para: index_blocks\block_81.txt
# Bloque ordenado: index_blocks\block_90.txt
# Bloque ordenado: index_blocks\block_84.txt
# Bloque ordenado: index_blocks\block_89.txt
# Bloque ordenado: index_blocks\block_87.txt
# Ordenamiento completado para: index_blocks\block_90.txt
# Ordenamiento completado para: index_blocks\block_84.txt
# Ordenamiento completado para: index_blocks\block_89.txt
# Ordenamiento completado para: index_blocks\block_87.txt
# Bloque ordenado: index_blocks\block_92.txt
# Bloque ordenado: index_blocks\block_9.txt
# Ordenamiento completado para: index_blocks\block_92.txt
# Ordenamiento completado para: index_blocks\block_9.txt
# Bloque ordenado: index_blocks\block_93.txt
# Ordenamiento completado para: index_blocks\block_93.txt
# Bloque ordenado: index_blocks\block_95.txt
# Bloque ordenado: index_blocks\block_96.txt
# Bloque ordenado: index_blocks\block_97.txt
# Ordenamiento completado para: index_blocks\block_95.txt
# Ordenamiento completado para: index_blocks\block_96.txt
# Ordenamiento completado para: index_blocks\block_97.txt
# Bloque ordenado: index_blocks\block_91.txt
# Bloque ordenado: index_blocks\block_98.txt
# Bloque ordenado: index_blocks\block_94.txt
# Ordenamiento completado para: index_blocks\block_91.txt
# Ordenamiento completado para: index_blocks\block_98.txt
# Ordenamiento completado para: index_blocks\block_94.txt
# Bloque ordenado: index_blocks\block_99.txt
# Ordenamiento completado para: index_blocks\block_99.txt
# Iniciando con el merge
# Índice fusionado guardado en index_blocks_merge\postings.bin
# Diccionario de términos guardado en index_blocks_merge\term_dict.pkl
# Normas de documentos guardadas en index_blocks_merge\document_norms.pkl
#
# Resumen de tiempos:
# Tiempo para la creación Creación  y el ordenamiento de los bloques: 54.24 segundos
# Tiempo para la ejecución del merge: 6.07 segundos
# Tiempo total para la creación y el mergeo: 60.31 segundos
# Se cargó en total:  4000  documentos
# Se cargó en total:  4000  documentos
# Directorio eliminado: index_blocks
# Directorio eliminado: index_blocks_merge
# Creando y ordenando cada bloque
# Iniciando ordenamiento concurrente de los bloques...
# Bloque ordenado: index_blocks\block_10.txt
# Bloque ordenado: index_blocks\block_101.txt
# Bloque ordenado: index_blocks\block_1.txt
# Bloque ordenado: index_blocks\block_100.txt
# Bloque ordenado: index_blocks\block_104.txt
# Bloque ordenado: index_blocks\block_102.txt
# Bloque ordenado: index_blocks\block_103.txt
# Bloque ordenado: index_blocks\block_0.txt
# Bloque ordenado: index_blocks\block_106.txt
# Bloque ordenado: index_blocks\block_108.txt
# Bloque ordenado: index_blocks\block_107.txt
# Bloque ordenado: index_blocks\block_113.txt
# Bloque ordenado: index_blocks\block_112.txt
# Bloque ordenado: index_blocks\block_105.txt
# Bloque ordenado: index_blocks\block_109.txt
# Bloque ordenado: index_blocks\block_110.txt
# Ordenamiento completado para: index_blocks\block_112.txt
# Ordenamiento completado para: index_blocks\block_10.txt
# Ordenamiento completado para: index_blocks\block_103.txt
# Ordenamiento completado para: index_blocks\block_102.txt
# Ordenamiento completado para: index_blocks\block_109.txt
# Ordenamiento completado para: index_blocks\block_0.txt
# Ordenamiento completado para: index_blocks\block_113.txt
# Ordenamiento completado para: index_blocks\block_108.txt
# Ordenamiento completado para: index_blocks\block_105.txt
# Ordenamiento completado para: index_blocks\block_100.txt
# Ordenamiento completado para: index_blocks\block_101.txt
# Ordenamiento completado para: index_blocks\block_106.txt
# Ordenamiento completado para: index_blocks\block_1.txt
# Ordenamiento completado para: index_blocks\block_110.txt
# Ordenamiento completado para: index_blocks\block_107.txt
# Ordenamiento completado para: index_blocks\block_104.txt
# Bloque ordenado: index_blocks\block_11.txt
# Ordenamiento completado para: index_blocks\block_11.txt
# Bloque ordenado: index_blocks\block_114.txt
# Bloque ordenado: index_blocks\block_116.txt
# Bloque ordenado: index_blocks\block_111.txt
# Ordenamiento completado para: index_blocks\block_114.txt
# Ordenamiento completado para: index_blocks\block_116.txt
# Ordenamiento completado para: index_blocks\block_111.txt
# Bloque ordenado: index_blocks\block_118.txt
# Ordenamiento completado para: index_blocks\block_118.txt
# Bloque ordenado: index_blocks\block_121.txt
# Bloque ordenado: index_blocks\block_124.txt
# Bloque ordenado: index_blocks\block_115.txt
# Ordenamiento completado para: index_blocks\block_121.txt
# Ordenamiento completado para: index_blocks\block_124.txt
# Ordenamiento completado para: index_blocks\block_115.txt
# Bloque ordenado: index_blocks\block_119.txt
# Bloque ordenado: index_blocks\block_125.txt
# Bloque ordenado: index_blocks\block_122.txt
# Bloque ordenado: index_blocks\block_117.txt
# Ordenamiento completado para: index_blocks\block_119.txt
# Ordenamiento completado para: index_blocks\block_125.txt
# Ordenamiento completado para: index_blocks\block_122.txt
# Ordenamiento completado para: index_blocks\block_117.txt
# Bloque ordenado: index_blocks\block_123.txt
# Bloque ordenado: index_blocks\block_129.txt
# Bloque ordenado: index_blocks\block_120.txt
# Ordenamiento completado para: index_blocks\block_123.txt
# Ordenamiento completado para: index_blocks\block_129.txt
# Ordenamiento completado para: index_blocks\block_120.txt
# Bloque ordenado: index_blocks\block_126.txt
# Ordenamiento completado para: index_blocks\block_126.txt
# Bloque ordenado: index_blocks\block_128.txt
# Bloque ordenado: index_blocks\block_12.txt
# Ordenamiento completado para: index_blocks\block_128.txt
# Ordenamiento completado para: index_blocks\block_12.txt
# Bloque ordenado: index_blocks\block_127.txt
# Bloque ordenado: index_blocks\block_13.txt
# Bloque ordenado: index_blocks\block_137.txt
# Ordenamiento completado para: index_blocks\block_127.txt
# Ordenamiento completado para: index_blocks\block_13.txt
# Ordenamiento completado para: index_blocks\block_137.txt
# Bloque ordenado: index_blocks\block_135.txt
# Ordenamiento completado para: index_blocks\block_135.txt
# Bloque ordenado: index_blocks\block_138.txt
# Bloque ordenado: index_blocks\block_132.txt
# Bloque ordenado: index_blocks\block_134.txt
# Bloque ordenado: index_blocks\block_14.txt
# Bloque ordenado: index_blocks\block_136.txt
# Ordenamiento completado para: index_blocks\block_138.txt
# Ordenamiento completado para: index_blocks\block_132.txt
# Ordenamiento completado para: index_blocks\block_134.txt
# Ordenamiento completado para: index_blocks\block_14.txt
# Ordenamiento completado para: index_blocks\block_136.txt
# Bloque ordenado: index_blocks\block_133.txt
# Bloque ordenado: index_blocks\block_131.txt
# Ordenamiento completado para: index_blocks\block_133.txt
# Ordenamiento completado para: index_blocks\block_131.txt
# Bloque ordenado: index_blocks\block_144.txt
# Ordenamiento completado para: index_blocks\block_144.txt
# Bloque ordenado: index_blocks\block_130.txt
# Bloque ordenado: index_blocks\block_146.txt
# Ordenamiento completado para: index_blocks\block_130.txt
# Ordenamiento completado para: index_blocks\block_146.txt
# Bloque ordenado: index_blocks\block_145.txt
# Bloque ordenado: index_blocks\block_141.txt
# Ordenamiento completado para: index_blocks\block_145.txt
# Ordenamiento completado para: index_blocks\block_141.txt
# Bloque ordenado: index_blocks\block_139.txt
# Bloque ordenado: index_blocks\block_143.txt
# Ordenamiento completado para: index_blocks\block_139.txt
# Ordenamiento completado para: index_blocks\block_143.txt
# Bloque ordenado: index_blocks\block_142.txt
# Bloque ordenado: index_blocks\block_147.txt
# Ordenamiento completado para: index_blocks\block_142.txt
# Ordenamiento completado para: index_blocks\block_147.txt
# Bloque ordenado: index_blocks\block_152.txt
# Ordenamiento completado para: index_blocks\block_152.txt
# Bloque ordenado: index_blocks\block_148.txt
# Bloque ordenado: index_blocks\block_140.txt
# Bloque ordenado: index_blocks\block_151.txt
# Ordenamiento completado para: index_blocks\block_148.txt
# Ordenamiento completado para: index_blocks\block_140.txt
# Ordenamiento completado para: index_blocks\block_151.txt
# Bloque ordenado: index_blocks\block_153.txt
# Bloque ordenado: index_blocks\block_150.txt
# Bloque ordenado: index_blocks\block_15.txt
# Bloque ordenado: index_blocks\block_149.txt
# Ordenamiento completado para: index_blocks\block_153.txt
# Ordenamiento completado para: index_blocks\block_150.txt
# Ordenamiento completado para: index_blocks\block_15.txt
# Ordenamiento completado para: index_blocks\block_149.txt
# Bloque ordenado: index_blocks\block_155.txt
# Bloque ordenado: index_blocks\block_157.txt
# Bloque ordenado: index_blocks\block_154.txt
# Bloque ordenado: index_blocks\block_158.txt
# Ordenamiento completado para: index_blocks\block_155.txt
# Ordenamiento completado para: index_blocks\block_157.txt
# Ordenamiento completado para: index_blocks\block_154.txt
# Ordenamiento completado para: index_blocks\block_158.txt
# Bloque ordenado: index_blocks\block_156.txt
# Ordenamiento completado para: index_blocks\block_156.txt
# Bloque ordenado: index_blocks\block_159.txt
# Ordenamiento completado para: index_blocks\block_159.txt
# Bloque ordenado: index_blocks\block_164.txt
# Bloque ordenado: index_blocks\block_161.txt
# Ordenamiento completado para: index_blocks\block_164.txt
# Ordenamiento completado para: index_blocks\block_161.txt
# Bloque ordenado: index_blocks\block_160.txt
# Ordenamiento completado para: index_blocks\block_160.txt
# Bloque ordenado: index_blocks\block_16.txt
# Bloque ordenado: index_blocks\block_166.txt
# Bloque ordenado: index_blocks\block_17.txt
# Ordenamiento completado para: index_blocks\block_16.txt
# Ordenamiento completado para: index_blocks\block_166.txt
# Ordenamiento completado para: index_blocks\block_17.txt
# Bloque ordenado: index_blocks\block_162.txt
# Ordenamiento completado para: index_blocks\block_162.txt
# Bloque ordenado: index_blocks\block_165.txt
# Ordenamiento completado para: index_blocks\block_165.txt
# Bloque ordenado: index_blocks\block_163.txt
# Bloque ordenado: index_blocks\block_171.txt
# Ordenamiento completado para: index_blocks\block_163.txt
# Ordenamiento completado para: index_blocks\block_171.txt
# Bloque ordenado: index_blocks\block_168.txt
# Bloque ordenado: index_blocks\block_170.txt
# Ordenamiento completado para: index_blocks\block_168.txt
# Ordenamiento completado para: index_blocks\block_170.txt
# Bloque ordenado: index_blocks\block_167.txt
# Ordenamiento completado para: index_blocks\block_167.txt
# Bloque ordenado: index_blocks\block_173.txt
# Ordenamiento completado para: index_blocks\block_173.txt
# Bloque ordenado: index_blocks\block_172.txt
# Bloque ordenado: index_blocks\block_175.txt
# Ordenamiento completado para: index_blocks\block_172.txt
# Ordenamiento completado para: index_blocks\block_175.txt
# Bloque ordenado: index_blocks\block_174.txt
# Ordenamiento completado para: index_blocks\block_174.txt
# Bloque ordenado: index_blocks\block_177.txt
# Ordenamiento completado para: index_blocks\block_177.txt
# Bloque ordenado: index_blocks\block_176.txt
# Bloque ordenado: index_blocks\block_181.txt
# Bloque ordenado: index_blocks\block_178.txt
# Ordenamiento completado para: index_blocks\block_176.txt
# Ordenamiento completado para: index_blocks\block_181.txt
# Ordenamiento completado para: index_blocks\block_178.txt
# Bloque ordenado: index_blocks\block_169.txt
# Bloque ordenado: index_blocks\block_180.txt
# Ordenamiento completado para: index_blocks\block_169.txt
# Ordenamiento completado para: index_blocks\block_180.txt
# Bloque ordenado: index_blocks\block_179.txt
# Bloque ordenado: index_blocks\block_18.txt
# Ordenamiento completado para: index_blocks\block_179.txt
# Ordenamiento completado para: index_blocks\block_18.txt
# Bloque ordenado: index_blocks\block_185.txt
# Bloque ordenado: index_blocks\block_184.txt
# Ordenamiento completado para: index_blocks\block_185.txt
# Ordenamiento completado para: index_blocks\block_184.txt
# Bloque ordenado: index_blocks\block_188.txt
# Ordenamiento completado para: index_blocks\block_188.txt
# Bloque ordenado: index_blocks\block_183.txtBloque ordenado: index_blocks\block_182.txt
# Bloque ordenado: index_blocks\block_19.txt
# Bloque ordenado: index_blocks\block_187.txt
#
# Ordenamiento completado para: index_blocks\block_182.txt
# Ordenamiento completado para: index_blocks\block_19.txt
# Ordenamiento completado para: index_blocks\block_187.txt
# Ordenamiento completado para: index_blocks\block_183.txt
# Bloque ordenado: index_blocks\block_186.txt
# Ordenamiento completado para: index_blocks\block_186.txt
# Bloque ordenado: index_blocks\block_189.txt
# Ordenamiento completado para: index_blocks\block_189.txt
# Bloque ordenado: index_blocks\block_192.txt
# Bloque ordenado: index_blocks\block_194.txt
# Ordenamiento completado para: index_blocks\block_192.txt
# Ordenamiento completado para: index_blocks\block_194.txt
# Bloque ordenado: index_blocks\block_193.txt
# Ordenamiento completado para: index_blocks\block_193.txt
# Bloque ordenado: index_blocks\block_191.txt
# Bloque ordenado: index_blocks\block_190.txt
# Bloque ordenado: index_blocks\block_2.txt
# Bloque ordenado: index_blocks\block_197.txt
# Bloque ordenado: index_blocks\block_198.txt
# Ordenamiento completado para: index_blocks\block_191.txt
# Ordenamiento completado para: index_blocks\block_190.txt
# Ordenamiento completado para: index_blocks\block_2.txt
# Ordenamiento completado para: index_blocks\block_197.txt
# Ordenamiento completado para: index_blocks\block_198.txt
# Bloque ordenado: index_blocks\block_196.txt
# Bloque ordenado: index_blocks\block_199.txt
# Ordenamiento completado para: index_blocks\block_196.txt
# Ordenamiento completado para: index_blocks\block_199.txt
# Bloque ordenado: index_blocks\block_200.txt
# Bloque ordenado: index_blocks\block_195.txt
# Bloque ordenado: index_blocks\block_20.txt
# Ordenamiento completado para: index_blocks\block_200.txt
# Ordenamiento completado para: index_blocks\block_195.txt
# Ordenamiento completado para: index_blocks\block_20.txt
# Bloque ordenado: index_blocks\block_203.txt
# Ordenamiento completado para: index_blocks\block_203.txt
# Bloque ordenado: index_blocks\block_21.txt
# Bloque ordenado: index_blocks\block_204.txt
# Ordenamiento completado para: index_blocks\block_21.txt
# Ordenamiento completado para: index_blocks\block_204.txt
# Bloque ordenado: index_blocks\block_201.txt
# Bloque ordenado: index_blocks\block_202.txt
# Ordenamiento completado para: index_blocks\block_201.txt
# Ordenamiento completado para: index_blocks\block_202.txt
# Bloque ordenado: index_blocks\block_206.txt
# Bloque ordenado: index_blocks\block_205.txt
# Ordenamiento completado para: index_blocks\block_206.txt
# Ordenamiento completado para: index_blocks\block_205.txt
# Bloque ordenado: index_blocks\block_207.txt
# Ordenamiento completado para: index_blocks\block_207.txt
# Bloque ordenado: index_blocks\block_208.txt
# Bloque ordenado: index_blocks\block_210.txt
# Ordenamiento completado para: index_blocks\block_208.txt
# Ordenamiento completado para: index_blocks\block_210.txt
# Bloque ordenado: index_blocks\block_216.txt
# Ordenamiento completado para: index_blocks\block_216.txt
# Bloque ordenado: index_blocks\block_213.txt
# Ordenamiento completado para: index_blocks\block_213.txt
# Bloque ordenado: index_blocks\block_212.txt
# Bloque ordenado: index_blocks\block_215.txt
# Bloque ordenado: index_blocks\block_214.txt
# Ordenamiento completado para: index_blocks\block_212.txt
# Ordenamiento completado para: index_blocks\block_215.txt
# Ordenamiento completado para: index_blocks\block_214.txt
# Bloque ordenado: index_blocks\block_22.txt
# Bloque ordenado: index_blocks\block_211.txt
# Bloque ordenado: index_blocks\block_217.txt
# Bloque ordenado: index_blocks\block_219.txt
# Ordenamiento completado para: index_blocks\block_22.txt
# Ordenamiento completado para: index_blocks\block_211.txt
# Ordenamiento completado para: index_blocks\block_217.txt
# Ordenamiento completado para: index_blocks\block_219.txt
# Bloque ordenado: index_blocks\block_220.txt
# Bloque ordenado: index_blocks\block_209.txt
# Bloque ordenado: index_blocks\block_218.txt
# Ordenamiento completado para: index_blocks\block_220.txt
# Ordenamiento completado para: index_blocks\block_209.txt
# Ordenamiento completado para: index_blocks\block_218.txt
# Bloque ordenado: index_blocks\block_221.txt
# Bloque ordenado: index_blocks\block_222.txt
# Ordenamiento completado para: index_blocks\block_221.txt
# Ordenamiento completado para: index_blocks\block_222.txt
# Bloque ordenado: index_blocks\block_223.txt
# Ordenamiento completado para: index_blocks\block_223.txt
# Bloque ordenado: index_blocks\block_225.txt
# Ordenamiento completado para: index_blocks\block_225.txt
# Bloque ordenado: index_blocks\block_228.txt
# Ordenamiento completado para: index_blocks\block_228.txt
# Bloque ordenado: index_blocks\block_229.txt
# Ordenamiento completado para: index_blocks\block_229.txtBloque ordenado: index_blocks\block_224.txt
#
# Ordenamiento completado para: index_blocks\block_224.txt
# Bloque ordenado: index_blocks\block_226.txt
# Bloque ordenado: index_blocks\block_227.txt
# Ordenamiento completado para: index_blocks\block_226.txt
# Ordenamiento completado para: index_blocks\block_227.txt
# Bloque ordenado: index_blocks\block_230.txt
# Ordenamiento completado para: index_blocks\block_230.txt
# Bloque ordenado: index_blocks\block_231.txt
# Bloque ordenado: index_blocks\block_23.txt
# Ordenamiento completado para: index_blocks\block_231.txt
# Ordenamiento completado para: index_blocks\block_23.txt
# Bloque ordenado: index_blocks\block_235.txt
# Bloque ordenado: index_blocks\block_236.txt
# Bloque ordenado: index_blocks\block_24.txt
# Ordenamiento completado para: index_blocks\block_235.txt
# Ordenamiento completado para: index_blocks\block_236.txt
# Ordenamiento completado para: index_blocks\block_24.txt
# Bloque ordenado: index_blocks\block_237.txt
# Bloque ordenado: index_blocks\block_233.txt
# Bloque ordenado: index_blocks\block_239.txt
# Bloque ordenado: index_blocks\block_234.txt
# Ordenamiento completado para: index_blocks\block_237.txt
# Ordenamiento completado para: index_blocks\block_233.txt
# Ordenamiento completado para: index_blocks\block_239.txt
# Ordenamiento completado para: index_blocks\block_234.txt
# Bloque ordenado: index_blocks\block_232.txt
# Ordenamiento completado para: index_blocks\block_232.txt
# Bloque ordenado: index_blocks\block_238.txt
# Bloque ordenado: index_blocks\block_243.txt
# Ordenamiento completado para: index_blocks\block_238.txt
# Ordenamiento completado para: index_blocks\block_243.txt
# Bloque ordenado: index_blocks\block_241.txt
# Bloque ordenado: index_blocks\block_240.txt
# Bloque ordenado: index_blocks\block_246.txt
# Ordenamiento completado para: index_blocks\block_241.txt
# Ordenamiento completado para: index_blocks\block_240.txt
# Ordenamiento completado para: index_blocks\block_246.txt
# Bloque ordenado: index_blocks\block_245.txt
# Bloque ordenado: index_blocks\block_242.txt
# Ordenamiento completado para: index_blocks\block_245.txt
# Ordenamiento completado para: index_blocks\block_242.txt
# Bloque ordenado: index_blocks\block_248.txt
# Bloque ordenado: index_blocks\block_244.txt
# Bloque ordenado: index_blocks\block_247.txt
# Bloque ordenado: index_blocks\block_256.txt
# Ordenamiento completado para: index_blocks\block_248.txt
# Ordenamiento completado para: index_blocks\block_244.txt
# Ordenamiento completado para: index_blocks\block_247.txt
# Ordenamiento completado para: index_blocks\block_256.txt
# Bloque ordenado: index_blocks\block_250.txt
# Bloque ordenado: index_blocks\block_249.txt
# Bloque ordenado: index_blocks\block_257.txt
# Bloque ordenado: index_blocks\block_25.txt
# Ordenamiento completado para: index_blocks\block_250.txt
# Ordenamiento completado para: index_blocks\block_249.txt
# Ordenamiento completado para: index_blocks\block_257.txt
# Ordenamiento completado para: index_blocks\block_25.txt
# Bloque ordenado: index_blocks\block_252.txt
# Ordenamiento completado para: index_blocks\block_252.txt
# Bloque ordenado: index_blocks\block_254.txt
# Bloque ordenado: index_blocks\block_255.txt
# Bloque ordenado: index_blocks\block_251.txt
# Ordenamiento completado para: index_blocks\block_254.txt
# Ordenamiento completado para: index_blocks\block_255.txt
# Ordenamiento completado para: index_blocks\block_251.txt
# Bloque ordenado: index_blocks\block_26.txt
# Bloque ordenado: index_blocks\block_258.txt
# Bloque ordenado: index_blocks\block_260.txt
# Bloque ordenado: index_blocks\block_253.txt
# Ordenamiento completado para: index_blocks\block_26.txt
# Ordenamiento completado para: index_blocks\block_258.txt
# Ordenamiento completado para: index_blocks\block_260.txt
# Ordenamiento completado para: index_blocks\block_253.txt
# Bloque ordenado: index_blocks\block_259.txt
# Ordenamiento completado para: index_blocks\block_259.txt
# Bloque ordenado: index_blocks\block_261.txt
# Ordenamiento completado para: index_blocks\block_261.txt
# Bloque ordenado: index_blocks\block_262.txt
# Ordenamiento completado para: index_blocks\block_262.txt
# Bloque ordenado: index_blocks\block_263.txt
# Ordenamiento completado para: index_blocks\block_263.txt
# Bloque ordenado: index_blocks\block_266.txt
# Ordenamiento completado para: index_blocks\block_266.txt
# Bloque ordenado: index_blocks\block_264.txt
# Ordenamiento completado para: index_blocks\block_264.txt
# Bloque ordenado: index_blocks\block_268.txt
# Ordenamiento completado para: index_blocks\block_268.txt
# Bloque ordenado: index_blocks\block_269.txtBloque ordenado: index_blocks\block_270.txt
# Bloque ordenado: index_blocks\block_265.txt
# Bloque ordenado: index_blocks\block_279.txt
#
# Bloque ordenado: index_blocks\block_27.txt
# Ordenamiento completado para: index_blocks\block_270.txt
# Ordenamiento completado para: index_blocks\block_265.txt
# Ordenamiento completado para: index_blocks\block_279.txt
# Ordenamiento completado para: index_blocks\block_269.txt
# Ordenamiento completado para: index_blocks\block_27.txt
# Bloque ordenado: index_blocks\block_267.txt
# Bloque ordenado: index_blocks\block_280.txt
# Bloque ordenado: index_blocks\block_278.txt
# Bloque ordenado: index_blocks\block_274.txt
# Ordenamiento completado para: index_blocks\block_267.txt
# Ordenamiento completado para: index_blocks\block_280.txt
# Ordenamiento completado para: index_blocks\block_278.txt
# Ordenamiento completado para: index_blocks\block_274.txt
# Bloque ordenado: index_blocks\block_275.txt
# Bloque ordenado: index_blocks\block_272.txt
# Bloque ordenado: index_blocks\block_276.txt
# Bloque ordenado: index_blocks\block_277.txt
# Bloque ordenado: index_blocks\block_273.txt
# Bloque ordenado: index_blocks\block_30.txt
# Ordenamiento completado para: index_blocks\block_275.txt
# Ordenamiento completado para: index_blocks\block_272.txt
# Ordenamiento completado para: index_blocks\block_276.txt
# Ordenamiento completado para: index_blocks\block_277.txt
# Ordenamiento completado para: index_blocks\block_273.txt
# Ordenamiento completado para: index_blocks\block_30.txt
# Bloque ordenado: index_blocks\block_271.txt
# Bloque ordenado: index_blocks\block_3.txt
# Bloque ordenado: index_blocks\block_28.txt
# Ordenamiento completado para: index_blocks\block_271.txt
# Ordenamiento completado para: index_blocks\block_3.txt
# Ordenamiento completado para: index_blocks\block_28.txt
# Bloque ordenado: index_blocks\block_29.txt
# Bloque ordenado: index_blocks\block_36.txt
# Bloque ordenado: index_blocks\block_31.txt
# Ordenamiento completado para: index_blocks\block_29.txt
# Ordenamiento completado para: index_blocks\block_36.txt
# Ordenamiento completado para: index_blocks\block_31.txt
# Bloque ordenado: index_blocks\block_34.txt
# Bloque ordenado: index_blocks\block_32.txt
# Ordenamiento completado para: index_blocks\block_34.txt
# Ordenamiento completado para: index_blocks\block_32.txt
# Bloque ordenado: index_blocks\block_35.txt
# Bloque ordenado: index_blocks\block_37.txt
# Ordenamiento completado para: index_blocks\block_35.txt
# Ordenamiento completado para: index_blocks\block_37.txt
# Bloque ordenado: index_blocks\block_40.txt
# Bloque ordenado: index_blocks\block_33.txt
# Bloque ordenado: index_blocks\block_41.txt
# Ordenamiento completado para: index_blocks\block_40.txt
# Ordenamiento completado para: index_blocks\block_33.txt
# ...
# Ordenamiento completado para: index_blocks\block_860.txt
# Ordenamiento completado para: index_blocks\block_857.txt
# Bloque ordenado: index_blocks\block_865.txt
# Ordenamiento completado para: index_blocks\block_865.txtBloque ordenado: index_blocks\block_862.txt
# Bloque ordenado: index_blocks\block_866.txt
#
# Ordenamiento completado para: index_blocks\block_862.txt
# Ordenamiento completado para: index_blocks\block_866.txt
# Bloque ordenado: index_blocks\block_864.txt
# Bloque ordenado: index_blocks\block_868.txt
# Bloque ordenado: index_blocks\block_870.txt
# Ordenamiento completado para: index_blocks\block_864.txt
# Ordenamiento completado para: index_blocks\block_868.txt
# Ordenamiento completado para: index_blocks\block_870.txt
# Bloque ordenado: index_blocks\block_87.txt
# Bloque ordenado: index_blocks\block_871.txt
# Bloque ordenado: index_blocks\block_867.txt
# Ordenamiento completado para: index_blocks\block_87.txt
# Ordenamiento completado para: index_blocks\block_871.txt
# Ordenamiento completado para: index_blocks\block_867.txt
# Bloque ordenado: index_blocks\block_869.txt
# Ordenamiento completado para: index_blocks\block_869.txt
# Bloque ordenado: index_blocks\block_875.txt
# Bloque ordenado: index_blocks\block_876.txt
# Bloque ordenado: index_blocks\block_878.txt
# Bloque ordenado: index_blocks\block_872.txt
# Bloque ordenado: index_blocks\block_874.txt
# Bloque ordenado: index_blocks\block_881.txt
# Ordenamiento completado para: index_blocks\block_875.txt
# Ordenamiento completado para: index_blocks\block_876.txt
# Ordenamiento completado para: index_blocks\block_878.txt
# Ordenamiento completado para: index_blocks\block_872.txt
# Ordenamiento completado para: index_blocks\block_874.txt
# Ordenamiento completado para: index_blocks\block_881.txt
# Bloque ordenado: index_blocks\block_873.txt
# Ordenamiento completado para: index_blocks\block_873.txt
# Bloque ordenado: index_blocks\block_88.txt
# Bloque ordenado: index_blocks\block_885.txt
# Ordenamiento completado para: index_blocks\block_88.txt
# Ordenamiento completado para: index_blocks\block_885.txt
# Bloque ordenado: index_blocks\block_887.txt
# Bloque ordenado: index_blocks\block_879.txt
# Bloque ordenado: index_blocks\block_877.txt
# Ordenamiento completado para: index_blocks\block_887.txt
# Ordenamiento completado para: index_blocks\block_879.txt
# Ordenamiento completado para: index_blocks\block_877.txt
# Bloque ordenado: index_blocks\block_884.txt
# Ordenamiento completado para: index_blocks\block_884.txt
# Bloque ordenado: index_blocks\block_880.txt
# Bloque ordenado: index_blocks\block_882.txt
# Bloque ordenado: index_blocks\block_883.txt
# Ordenamiento completado para: index_blocks\block_880.txt
# Ordenamiento completado para: index_blocks\block_882.txt
# Ordenamiento completado para: index_blocks\block_883.txt
# Bloque ordenado: index_blocks\block_886.txt
# Ordenamiento completado para: index_blocks\block_886.txt
# Bloque ordenado: index_blocks\block_888.txt
# Bloque ordenado: index_blocks\block_892.txt
# Bloque ordenado: index_blocks\block_894.txt
# Ordenamiento completado para: index_blocks\block_888.txt
# Ordenamiento completado para: index_blocks\block_892.txt
# Ordenamiento completado para: index_blocks\block_894.txt
# Bloque ordenado: index_blocks\block_889.txt
# Ordenamiento completado para: index_blocks\block_889.txt
# Bloque ordenado: index_blocks\block_9.txt
# Ordenamiento completado para: index_blocks\block_9.txt
# Bloque ordenado: index_blocks\block_893.txt
# Ordenamiento completado para: index_blocks\block_893.txt
# Bloque ordenado: index_blocks\block_891.txt
# Ordenamiento completado para: index_blocks\block_891.txt
# Bloque ordenado: index_blocks\block_890.txt
# Ordenamiento completado para: index_blocks\block_890.txt
# Bloque ordenado: index_blocks\block_89.txt
# Ordenamiento completado para: index_blocks\block_89.txt
# Bloque ordenado: index_blocks\block_898.txt
# Ordenamiento completado para: index_blocks\block_898.txt
# Bloque ordenado: index_blocks\block_900.txt
# Bloque ordenado: index_blocks\block_896.txt
# Ordenamiento completado para: index_blocks\block_900.txt
# Ordenamiento completado para: index_blocks\block_896.txt
# Bloque ordenado: index_blocks\block_895.txt
# Bloque ordenado: index_blocks\block_897.txt
# Ordenamiento completado para: index_blocks\block_895.txt
# Ordenamiento completado para: index_blocks\block_897.txt
# Bloque ordenado: index_blocks\block_904.txt
# Bloque ordenado: index_blocks\block_902.txt
# Bloque ordenado: index_blocks\block_903.txt
# Bloque ordenado: index_blocks\block_899.txt
# Bloque ordenado: index_blocks\block_90.txt
# Ordenamiento completado para: index_blocks\block_904.txt
# Ordenamiento completado para: index_blocks\block_902.txt
# Ordenamiento completado para: index_blocks\block_903.txt
# Ordenamiento completado para: index_blocks\block_899.txt
# Ordenamiento completado para: index_blocks\block_90.txt
# Bloque ordenado: index_blocks\block_907.txt
# Ordenamiento completado para: index_blocks\block_907.txt
# Bloque ordenado: index_blocks\block_908.txt
# Ordenamiento completado para: index_blocks\block_908.txt
# Bloque ordenado: index_blocks\block_91.txt
# Ordenamiento completado para: index_blocks\block_91.txt
# Bloque ordenado: index_blocks\block_905.txt
# Ordenamiento completado para: index_blocks\block_905.txt
# Bloque ordenado: index_blocks\block_901.txt
# Bloque ordenado: index_blocks\block_909.txt
# Bloque ordenado: index_blocks\block_906.txt
# Ordenamiento completado para: index_blocks\block_901.txt
# Ordenamiento completado para: index_blocks\block_909.txt
# Ordenamiento completado para: index_blocks\block_906.txt
# Bloque ordenado: index_blocks\block_913.txt
# Ordenamiento completado para: index_blocks\block_913.txt
# Bloque ordenado: index_blocks\block_914.txt
# Ordenamiento completado para: index_blocks\block_914.txt
# Bloque ordenado: index_blocks\block_911.txt
# Bloque ordenado: index_blocks\block_92.txt
# Bloque ordenado: index_blocks\block_920.txt
# Ordenamiento completado para: index_blocks\block_911.txt
# Ordenamiento completado para: index_blocks\block_92.txt
# Ordenamiento completado para: index_blocks\block_920.txt
# Bloque ordenado: index_blocks\block_919.txt
# Bloque ordenado: index_blocks\block_916.txt
# Bloque ordenado: index_blocks\block_915.txt
# Bloque ordenado: index_blocks\block_910.txt
# Bloque ordenado: index_blocks\block_912.txt
# Bloque ordenado: index_blocks\block_918.txt
# Bloque ordenado: index_blocks\block_923.txt
# Ordenamiento completado para: index_blocks\block_919.txt
# Ordenamiento completado para: index_blocks\block_916.txt
# Ordenamiento completado para: index_blocks\block_915.txt
# Ordenamiento completado para: index_blocks\block_910.txt
# Ordenamiento completado para: index_blocks\block_912.txt
# Ordenamiento completado para: index_blocks\block_918.txt
# Ordenamiento completado para: index_blocks\block_923.txt
# Bloque ordenado: index_blocks\block_922.txt
# Ordenamiento completado para: index_blocks\block_922.txt
# Bloque ordenado: index_blocks\block_921.txt
# Ordenamiento completado para: index_blocks\block_921.txt
# Bloque ordenado: index_blocks\block_929.txt
# Ordenamiento completado para: index_blocks\block_929.txt
# Bloque ordenado: index_blocks\block_925.txt
# Bloque ordenado: index_blocks\block_924.txt
# Bloque ordenado: index_blocks\block_93.txt
# Ordenamiento completado para: index_blocks\block_925.txt
# Ordenamiento completado para: index_blocks\block_924.txt
# Ordenamiento completado para: index_blocks\block_93.txt
# Bloque ordenado: index_blocks\block_917.txt
# Bloque ordenado: index_blocks\block_928.txt
# Bloque ordenado: index_blocks\block_927.txt
# Ordenamiento completado para: index_blocks\block_917.txt
# Ordenamiento completado para: index_blocks\block_928.txt
# Ordenamiento completado para: index_blocks\block_927.txt
# Bloque ordenado: index_blocks\block_931.txt
# Bloque ordenado: index_blocks\block_932.txt
# Ordenamiento completado para: index_blocks\block_931.txt
# Ordenamiento completado para: index_blocks\block_932.txt
# Bloque ordenado: index_blocks\block_933.txt
# Bloque ordenado: index_blocks\block_930.txt
# Ordenamiento completado para: index_blocks\block_933.txt
# Ordenamiento completado para: index_blocks\block_930.txt
# Bloque ordenado: index_blocks\block_935.txt
# Bloque ordenado: index_blocks\block_94.txt
# Ordenamiento completado para: index_blocks\block_935.txt
# Ordenamiento completado para: index_blocks\block_94.txt
# Bloque ordenado: index_blocks\block_926.txt
# Ordenamiento completado para: index_blocks\block_926.txt
# Bloque ordenado: index_blocks\block_943.txt
# Ordenamiento completado para: index_blocks\block_943.txt
# Bloque ordenado: index_blocks\block_941.txt
# Bloque ordenado: index_blocks\block_944.txt
# Bloque ordenado: index_blocks\block_939.txt
# Bloque ordenado: index_blocks\block_938.txt
# Bloque ordenado: index_blocks\block_934.txt
# Bloque ordenado: index_blocks\block_936.txt
# Bloque ordenado: index_blocks\block_947.txt
# Bloque ordenado: index_blocks\block_946.txt
# Bloque ordenado: index_blocks\block_952.txt
# Bloque ordenado: index_blocks\block_95.txt
# Bloque ordenado: index_blocks\block_951.txt
# Ordenamiento completado para: index_blocks\block_941.txt
# Ordenamiento completado para: index_blocks\block_944.txt
# Ordenamiento completado para: index_blocks\block_939.txt
# Ordenamiento completado para: index_blocks\block_938.txt
# Ordenamiento completado para: index_blocks\block_934.txt
# Ordenamiento completado para: index_blocks\block_936.txt
# Ordenamiento completado para: index_blocks\block_947.txt
# Ordenamiento completado para: index_blocks\block_946.txt
# Ordenamiento completado para: index_blocks\block_952.txt
# Ordenamiento completado para: index_blocks\block_95.txt
# Ordenamiento completado para: index_blocks\block_951.txt
# Bloque ordenado: index_blocks\block_942.txt
# Ordenamiento completado para: index_blocks\block_942.txt
# Bloque ordenado: index_blocks\block_940.txt
# Ordenamiento completado para: index_blocks\block_940.txt
# Bloque ordenado: index_blocks\block_945.txt
# Bloque ordenado: index_blocks\block_937.txt
# Ordenamiento completado para: index_blocks\block_945.txt
# Ordenamiento completado para: index_blocks\block_937.txt
# Bloque ordenado: index_blocks\block_957.txt
# Ordenamiento completado para: index_blocks\block_957.txt
# Bloque ordenado: index_blocks\block_953.txt
# Bloque ordenado: index_blocks\block_948.txt
# Ordenamiento completado para: index_blocks\block_953.txt
# Ordenamiento completado para: index_blocks\block_948.txt
# Bloque ordenado: index_blocks\block_949.txt
# Bloque ordenado: index_blocks\block_955.txt
# Ordenamiento completado para: index_blocks\block_949.txt
# Ordenamiento completado para: index_blocks\block_955.txt
# Bloque ordenado: index_blocks\block_956.txt
# Bloque ordenado: index_blocks\block_961.txt
# Bloque ordenado: index_blocks\block_959.txt
# Ordenamiento completado para: index_blocks\block_956.txt
# Ordenamiento completado para: index_blocks\block_961.txt
# Ordenamiento completado para: index_blocks\block_959.txt
# Bloque ordenado: index_blocks\block_954.txt
# Bloque ordenado: index_blocks\block_962.txt
# Bloque ordenado: index_blocks\block_950.txt
# Ordenamiento completado para: index_blocks\block_954.txt
# Ordenamiento completado para: index_blocks\block_962.txt
# Ordenamiento completado para: index_blocks\block_950.txt
# Bloque ordenado: index_blocks\block_96.txt
# Bloque ordenado: index_blocks\block_960.txt
# Bloque ordenado: index_blocks\block_958.txt
# Bloque ordenado: index_blocks\block_965.txt
# Ordenamiento completado para: index_blocks\block_96.txt
# Ordenamiento completado para: index_blocks\block_960.txt
# Ordenamiento completado para: index_blocks\block_958.txt
# Ordenamiento completado para: index_blocks\block_965.txt
# Bloque ordenado: index_blocks\block_963.txt
# Bloque ordenado: index_blocks\block_964.txt
# Ordenamiento completado para: index_blocks\block_963.txt
# Ordenamiento completado para: index_blocks\block_964.txt
# Bloque ordenado: index_blocks\block_97.txt
# Bloque ordenado: index_blocks\block_966.txt
# Bloque ordenado: index_blocks\block_967.txt
# Ordenamiento completado para: index_blocks\block_97.txt
# Ordenamiento completado para: index_blocks\block_966.txt
# Ordenamiento completado para: index_blocks\block_967.txt
# Bloque ordenado: index_blocks\block_968.txt
# Bloque ordenado: index_blocks\block_973.txt
# Bloque ordenado: index_blocks\block_976.txt
# Bloque ordenado: index_blocks\block_971.txt
# Bloque ordenado: index_blocks\block_969.txt
# Ordenamiento completado para: index_blocks\block_968.txt
# Ordenamiento completado para: index_blocks\block_973.txt
# Ordenamiento completado para: index_blocks\block_976.txt
# Ordenamiento completado para: index_blocks\block_971.txt
# Ordenamiento completado para: index_blocks\block_969.txt
# Bloque ordenado: index_blocks\block_974.txt
# Ordenamiento completado para: index_blocks\block_974.txt
# Bloque ordenado: index_blocks\block_970.txt
# Bloque ordenado: index_blocks\block_979.txt
# Ordenamiento completado para: index_blocks\block_970.txt
# Ordenamiento completado para: index_blocks\block_979.txt
# Bloque ordenado: index_blocks\block_975.txt
# Bloque ordenado: index_blocks\block_981.txt
# Bloque ordenado: index_blocks\block_977.txt
# Bloque ordenado: index_blocks\block_972.txt
# Ordenamiento completado para: index_blocks\block_975.txt
# Ordenamiento completado para: index_blocks\block_981.txt
# Ordenamiento completado para: index_blocks\block_977.txt
# Ordenamiento completado para: index_blocks\block_972.txt
# Bloque ordenado: index_blocks\block_988.txt
# Ordenamiento completado para: index_blocks\block_988.txt
# Bloque ordenado: index_blocks\block_983.txt
# Bloque ordenado: index_blocks\block_980.txt
# Bloque ordenado: index_blocks\block_982.txt
# Ordenamiento completado para: index_blocks\block_983.txt
# Ordenamiento completado para: index_blocks\block_980.txt
# Ordenamiento completado para: index_blocks\block_982.txt
# Bloque ordenado: index_blocks\block_98.txt
# Ordenamiento completado para: index_blocks\block_98.txt
# Bloque ordenado: index_blocks\block_99.txt
# Ordenamiento completado para: index_blocks\block_99.txt
# Bloque ordenado: index_blocks\block_978.txt
# Ordenamiento completado para: index_blocks\block_978.txt
# Bloque ordenado: index_blocks\block_989.txt
# Bloque ordenado: index_blocks\block_987.txt
# Ordenamiento completado para: index_blocks\block_989.txt
# Ordenamiento completado para: index_blocks\block_987.txt
# Bloque ordenado: index_blocks\block_990.txt
# Bloque ordenado: index_blocks\block_984.txt
# Bloque ordenado: index_blocks\block_991.txt
# Ordenamiento completado para: index_blocks\block_990.txt
# Ordenamiento completado para: index_blocks\block_984.txt
# Ordenamiento completado para: index_blocks\block_991.txt
# Bloque ordenado: index_blocks\block_986.txt
# Bloque ordenado: index_blocks\block_985.txt
# Bloque ordenado: index_blocks\block_995.txt
# Ordenamiento completado para: index_blocks\block_986.txt
# Ordenamiento completado para: index_blocks\block_985.txt
# Ordenamiento completado para: index_blocks\block_995.txt
# Bloque ordenado: index_blocks\block_996.txt
# Ordenamiento completado para: index_blocks\block_996.txt
# Bloque ordenado: index_blocks\block_993.txt
# Ordenamiento completado para: index_blocks\block_993.txt
# Bloque ordenado: index_blocks\block_992.txt
# Bloque ordenado: index_blocks\block_997.txt
# Ordenamiento completado para: index_blocks\block_992.txt
# Ordenamiento completado para: index_blocks\block_997.txt
# Bloque ordenado: index_blocks\block_999.txt
# Bloque ordenado: index_blocks\block_994.txt
# Ordenamiento completado para: index_blocks\block_999.txt
# Ordenamiento completado para: index_blocks\block_994.txt
# Bloque ordenado: index_blocks\block_998.txt
# Ordenamiento completado para: index_blocks\block_998.txt
# Iniciando con el merge
# Índice fusionado guardado en index_blocks_merge\postings.bin
# Diccionario de términos guardado en index_blocks_merge\term_dict.pkl
# Normas de documentos guardadas en index_blocks_merge\document_norms.pkl
#
# Resumen de tiempos:
# Tiempo para la creación Creación  y el ordenamiento de los bloques: 486.04 segundos
# Tiempo para la ejecución del merge: 66.04 segundos
# Tiempo total para la creación y el mergeo: 552.08 segundos
# Se cargó en total:  32000  documentos
# Se cargó en total:  32000  documentos
# Directorio eliminado: index_blocks
# Directorio eliminado: index_blocks_merge
# Resultados guardados en tiempos\resultadosConcurrent.csv
