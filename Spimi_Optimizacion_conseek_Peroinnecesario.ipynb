# %% [markdown]
# Proyecto jiji

# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\ce mar\appdata\local\programs\python\python310\lib\site-packages (0.3.4)
# Requirement already satisfied: packaging in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from kagglehub) (23.2)
# Requirement already satisfied: tqdm in c:\users\ce mar\appdata\local\programs\python\python310\lib\site-packages (from kagglehub) (4.66.1)
# Requirement already satisfied: requests in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from kagglehub) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from requests->kagglehub) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from requests->kagglehub) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ce mar\appdata\roaming\python\python310\site-packages (from requests->kagglehub) (2022.12.7)
# Requirement already satisfied: colorama in c:\users\ce mar\appdata\local\programs\python\python310\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# [notice] A new release of pip available: 22.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
import numpy as np
from nltk.stem.snowball import SnowballStemmer
nltk.download('punkt')
import regex as re
import os
import pandas as pd
stemmer = SnowballStemmer('english')
import os
import pickle
import sys
import math
import dbm
import time
import heapq
import json
# Out:
# c:\Users\Ce mar\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\__init__.py:177: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [nltk_data] Downloading package punkt to C:\Users\Ce
# [nltk_data]     mar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
with open("stopwords-en.txt", encoding="latin1") as file:
   stoplist = [line.rstrip().lower() for line in file]
stoplist += ['?', '-', '.', ':', ',', '!', ';']

def preprocesamiento(texto, stemming=True):
  words = []
  texto = str(texto)
  texto = texto.lower()
  texto = re.sub(r'[^a-zA-Z0-9_À-ÿ]', ' ', texto)
  # tokenizar
  words = nltk.word_tokenize(texto, language='english')
  # filtrar stopwords
  words = [word for word in words if word not in stoplist]
  # reducir palabras (stemming)
  if stemming:
      words = [stemmer.stem(word) for word in words]
  return words

# %%
# Funciones AUXILIARES para recuperar la información

def getNumberWithAtributo(dataset_head, atributo):
    if atributo in dataset_head.columns:
        return dataset_head.columns.get_loc(atributo)  # Obtiene la posición del atributo
    return -1  # Retorna -1 si no existe
 

def getResultados(result, path, disk_limit):
    res = []
    for chunk in pd.read_csv(path, chunksize=disk_limit):
        for doc, score in result:
            if doc in chunk.index:
                res.append((chunk.iloc[doc], score))
    return pd.DataFrame(res, columns=['doc_id', 'score'])  
def getResultadosDF(result, path, disk_limit):
    res = []
    for chunk in pd.read_csv(path, chunksize=disk_limit):
        for doc, score in result:
            row = chunk.iloc[doc].copy()
            row['score'] = score  
            res.append(row)
    return pd.DataFrame(res) 
def get_dfTex_Cols(path, row, columnas): #We don´t use it is only ofr simple an very fast testing
    dataset =  pd.read_csv(path)
    res = [dataset.iloc[row, i] for i in columnas]
    return ' '.join(res)  
#Funciones auxiliares para el mergeo:

# %%
class SPIMI:
    def __init__(self, index_dataset_path="path",bloques_dir="index_blocks" , columnas = ["track_name","track_artist","lyrics", "track_album_name"]):
        self.bloques_dir = bloques_dir  
        self.dataset_path = index_dataset_path  
        self.block_counter = 0      
        self.doc_ids = None  
        self.idf = {}
        self.length = {}
        self.disk_limit = 40000  
        
        #--Columnas:
        self.columnas = columnas 
        # ----Direciones de memoria para los files--
        self.dirIndex = self.bloques_dir + "_merge"
        
        self.term_dict_path = os.path.join(self.dirIndex, 'term_dict.pkl')
        self.postings_file_path = os.path.join(self.dirIndex, 'postings.bin')
        self.norms_file_path = os.path.join(self.dirIndex, 'document_norms.pkl')
        #Guardar los ids
        self.doc_count_path = os.path.join(self.dirIndex, 'doc_count.txt')  

        if not os.path.exists(self.dirIndex):
            os.makedirs(self.dirIndex)
        if not os.path.exists(self.bloques_dir):
            os.makedirs(self.bloques_dir)

        if os.path.exists(self.doc_count_path): # Guardamos el total de docs en ves de usar un set
            with open(self.doc_count_path, 'r') as f:
                self.doc_ids = int(f.read().strip())

        self.load_doc_ids()   

    def load_doc_ids(self):
        if os.path.exists(self.doc_count_path):
            try:
                with open(self.doc_count_path, 'r') as f:
                    self.doc_ids = int(f.read().strip())
                    print(f"Documentos cargados: {self.doc_ids}")
            except (ValueError, FileNotFoundError):
                self.doc_ids = 0  # Si el archivo está vacío o corrupto
        else:
            self.doc_ids = 0
 
       
        
                  

    def spimi_invert(self):
        print("Creando y ordenando cada bloque")
        dictionary = {}
        doc_ids = set()
        time_spimiInvert_start = time.time()

        #Get columna indeces: 
        with open(self.dataset_path, mode='r', encoding='utf-8') as file:
            primera_linea = file.readline().strip()
        #Get number columns
        columnas = primera_linea.split(',')
        columnas_numbers  = [i for i in range(len(columnas)) if columnas[i] in self.columnas]

        # Creamos los diccionarios a los bloques
        for chunk in pd.read_csv(self.dataset_path,chunksize= self.disk_limit): 
            for doc_id_, row in chunk.iterrows():
                self.doc_ids +=1 # Actualizamos la cantidad de id
                preFila = [str(row.iloc[i]) for i in columnas_numbers]
                texto = ' '.join(item for item in preFila)
                words = preprocesamiento(texto)
                for text in words:
                    doc_id = doc_id_
                    token = text
                    if token not in dictionary:
                        dictionary[token] = {}  

                    if doc_id not in dictionary[token]:
                        dictionary[token][doc_id] = 1  
                    else:
                        dictionary[token][doc_id] += 1  

                    dictionary_size = sys.getsizeof(dictionary)
                    if dictionary_size >= self.disk_limit:
                        self.write_block_to_disk(dictionary)
                        dictionary.clear()

        if dictionary:
            self.write_block_to_disk(dictionary)  
        
        with open(self.doc_count_path, 'w') as f:
            f.write(str(self.doc_ids))

        time_spimiInvert = time.time()- time_spimiInvert_start

        # MERGE
        print("Iniciando con el merge")
        time_Merge_start = time.time()
        self.mergeHeap()
        time_Merge = time.time() - time_Merge_start


        print("\nResumen de tiempos:")
        print(f"Tiempo para la creación Creación  y el ordenamiento de los bloques: {time_spimiInvert:.2f} segundos")
        print(f"Tiempo para la ejecución del merge: {time_Merge:.2f} segundos")
        print(f"Tiempo total para la creación y el mergeo: {time_Merge + time_spimiInvert:.2f} segundos")
    


    def write_block_to_disk(self, dictionary): # Guardo los ordenados
        # TO DO
        # Probar con guardar y luego ordenar con hilos
        sorted_terms = dict(sorted(dictionary.items())) 
        file_path = os.path.join(self.bloques_dir, f"block_{self.block_counter}.txt")
        with open(file_path, "w", encoding="utf-8") as f:
            for term, postings in sorted_terms.items():
                postings_str = json.dumps(postings)  
                f.write(f"{term}: {postings_str}\n")  
        self.block_counter += 1


    def load_term_dict(self):
        term_dict = {}
        with open(self.term_dict_path, 'rb') as f:
            while True:
                try:
                    term_entry = pickle.load(f)
                    term_dict.update(term_entry)
                except EOFError:
                    break
        return term_dict

    def show_Block(self, index):
        print("Imprimiendo contenido del bloque: ", index)
        file_path = os.path.join(self.bloques_dir, f'block_{index}.pkl')
        if not os.path.exists(file_path):
            print(f"El bloque {index} no existe en la ruta: {file_path}")
            return
        try:
            with open(file_path, 'rb') as f:
                block_content = pickle.load(f)
            print(block_content)
        except Exception as e:
            print(f"Error al abrir el bloque {index}: {e}")



    # Ya se comprobó el correcto merge 
    # Ahora los archivo son terminos postings y salto de linea, asi se getea linea por línea 
    def mergeHeap(self):
        lista_bloques = os.listdir(self.bloques_dir)
        priority_queue = []
        idx = 0 
    
        postings_file_path = os.path.join(self.dirIndex, 'postings.bin')
        term_dict_path = os.path.join(self.dirIndex, 'term_dict.pkl')
        norms_file_path = os.path.join(self.dirIndex, 'document_norms.pkl')
    
        open_files = {}
        doc_norms_temp = {}  
    
        #Para optimizar en término s de manejo de memoria secundaria a term_dict.pkl haremos lo siguiente: 
        # en un diccionario temporal y si se supera a disk_limit se guarda
        # las el mañao del diccionario y le diccionario, de tal forma que luego se puda abrir por bloques
        # En términos prácticos es (pos, tamanio) diccionario tempora ...
        temp_term_dict = {}
        temp_term_dict_position = 0

        try:
            for bloque_path in lista_bloques:  # Referencias de bloques y pusheo de una línea (term, postings)
                bloque_full_path = os.path.join(self.bloques_dir, bloque_path)
                open_files[bloque_path] = open(bloque_full_path, "r", encoding="utf-8")
                term_postings = self.read_next_term(open_files[bloque_path])
                if term_postings:
                    term, postings = term_postings
                    heapq.heappush(priority_queue, (term, idx, postings, bloque_path))
                    idx += 1
    
            current_term = None
            current_postings = {}
            postings_file_position = 0
    
            with open(postings_file_path, 'wb') as postings_file, \
                 open(term_dict_path, 'ab') as term_dict_file:
    
                while priority_queue:
                    term, _, postings, bloque_path = heapq.heappop(priority_queue)
                    file = open_files[bloque_path]
    
                    if term == current_term:  # Caso en que el término es igual
                        for doc_id, tf in postings.items():
                            current_postings[doc_id] = current_postings.get(doc_id, 0) + tf
                    else:  # Nuevo término
                        if current_term is not None:
                            # Calcular IDF
                            idf = math.log10(self.doc_ids / (1 + len(current_postings)))
    
                            # Guardar postings (TF e IDF) en postings.bin
                            tf_idf_postings = {}
                            for doc_id, tf in current_postings.items():
                                tf_weighted = math.log10(1 + tf)
                                tfidf = tf_weighted * idf
                                tf_idf_postings[doc_id] = {"tf": tf_weighted, "idf": idf}
    
                                # Acumular el cuadrado del TF-IDF en las normas temporales
                                doc_norms_temp[doc_id] = doc_norms_temp.get(doc_id, 0) + tfidf ** 2
    
                            postings_data = pickle.dumps(tf_idf_postings)
                            postings_file.write(postings_data)
    
                            # Guardar término en term_dict_temporal: 

                            # ----- Guia -----
                            # postings_file.seek(position)  
                            # postings_data = postings_file.read(length) 
                            # ----- End Guia -----


                            # pickle.dump({current_term: (postings_file_position, len(postings_data))}, term_dict_file)
                            temp_term_dict[current_term] =  (postings_file_position, len(postings_data)) 
                            print("Term_dict para current term es: " )
                            print({current_term: (postings_file_position, len(postings_data))})
                            postings_file_position += len(postings_data)

                        # Actualizar current_term y current_postings
                        current_term = term
                        current_postings = postings.copy()

                        # Si se puera el limite ------><------
                        dictionary_size = sys.getsizeof(temp_term_dict)
                        if dictionary_size >= self.disk_limit: 
                            #pickle.dump({current_term: (postings_file_position, len(postings_data))}, term_dict_file
                            pickle.dump((temp_term_dict_position, len(temp_term_dict)), term_dict_file) # Guardo las posiciones
                            pickle.dump(temp_term_dict, term_dict_file) #Guardo el diccionario
                            temp_term_dict_position+=len((temp_term_dict_position, len(temp_term_dict))) #Tam de la tupla pos
                            temp_term_dict_position+=len(temp_term_dict) #Tam del diccionario
                            temp_term_dict.clear()
                        
    
                    next_term_postings = self.read_next_term(file)
                    if next_term_postings:
                        next_term, next_postings = next_term_postings
                        heapq.heappush(priority_queue, (next_term, idx, next_postings, bloque_path))
                        idx += 1
    
                
                if current_term is not None:
                    idf = math.log10(self.doc_ids / (1 + len(current_postings)))
                    tf_idf_postings = {}
                    for doc_id, tf in current_postings.items():
                        tf_weighted = math.log10(1 + tf)
                        tfidf = tf_weighted * idf
                        tf_idf_postings[doc_id] = {"tf": tf_weighted, "idf": idf}
    
                        # Acumular el cuadrado del TF-IDF en las normas temporales
                        doc_norms_temp[doc_id] = doc_norms_temp.get(doc_id, 0) + tfidf ** 2

                    

                    postings_data = pickle.dumps(tf_idf_postings)
                    postings_file.write(postings_data)
                    pickle.dump({current_term: (postings_file_position, len(postings_data))}, term_dict_file)
                    postings_file_position += len(postings_data)

                    #Guardamos de frente temp_term_dict
                    pickle.dump((temp_term_dict_position, len(temp_term_dict)), term_dict_file) # Guardo las posiciones
                    pickle.dump(temp_term_dict, term_dict_file) #Guardo el diccionario
                    temp_term_dict_position+=len((temp_term_dict_position, len(temp_term_dict))) #Tam de la tupla pos
                    temp_term_dict_position+=len(temp_term_dict) #Tam del diccionario
                    temp_term_dict.clear()
    
        finally:
            # Cerrar todos los archivos abiertos
            for file in open_files.values():
                file.close()
    
        # Guardar las normas finales tomando la raíz cuadrada
        final_norms = {int(doc_id): math.sqrt(value) for doc_id, value in doc_norms_temp.items()}
        with open(norms_file_path, 'wb') as norms_file:
            pickle.dump(final_norms, norms_file)
    
        self.term_dict_path = term_dict_path
        self.postings_file_path = postings_file_path
        print(f"Índice fusionado guardado en {postings_file_path}")
        print(f"Diccionario de términos guardado en {term_dict_path}")
        print(f"Normas de documentos guardadas en {norms_file_path}")
            # Realiza merge de todos los bloques:
            # Manejaremos un archivo para ubicar los un indice general self.indexTerms donde se guarda la posición del termino
            # En el otro archivo se guardaran completito tanto la palabra como el posting list pero ya ordenado
    
    def read_next_term(self, file):
        line = file.readline()
        if not line:  # Si llegamos al final del archivo
            return None
        term, postings_str = line.strip().split(":", 1)
        postings = json.loads(postings_str)  
        return term, postings

    #--Funciones para testing--
    def print_all_norms(self):
        if not os.path.exists(self.norms_file_path):
            print("El archivo de normas no existe. Asegúrate de haber ejecutado 'spimi_invert' correctamente.")
            return

        try:
            with open(self.norms_file_path, 'rb') as norms_file:
                norms = pickle.load(norms_file)
                if not norms:
                    print("El archivo de normas está vacío.")
                    return

                print("Normas de los documentos:")
                for doc_id, norm in sorted(norms.items()):
                    print(f"Documento ID: {doc_id}, Norma: {norm}")
        except Exception as e:
            print(f"Error al leer o procesar las normas: {e}")

    def show_terms_and_positions(self):
        term_dict = self.load_term_dict()
        print("Términos y sus posiciones en el archivo de postings:")

        # for term, (position, length) in term_dict.items():
        #     print(f"Término: '{term}', Posición: {position}, Longitud: {length}")

        terms = list(term_dict.keys())
        if terms == sorted(terms):
            print("----->Yeeeei, Los términos están ordenados alfabéticamente en el diccionario final.")
        else:
            print("Los términos NO están ordenados alfabéticamente en el diccionario final.")

    def show_terms_with_postings(self):
        # Cargar el diccionario de términos desde el archivo term_dict.pkl
        term_dict = self.load_term_dict()

        if not os.path.exists(self.postings_file_path):
            print("El archivo de postings no existe. Ejecuta 'mergeHeap' primero.")
            return

        print("Términos y sus listas de postings:")
        try:
            with open(self.postings_file_path, 'rb') as postings_file:
                for term, (position, length) in term_dict.items():
                    postings_file.seek(position)  
                    postings_data = postings_file.read(length) 
                    postings = pickle.loads(postings_data) 
                    print(f"Término: '{term}', Postings: {postings}")
        except Exception as e:
            print(f"Error al mostrar los términos y postings: {e}")

    def retrieval(self, query, k):
        #Cargamos docs: 
        if self.doc_ids is None:
            self.load_doc_ids()

        if self.doc_ids == 0:  
            raise ValueError("El índice no está construido o no contiene documentos. Ejecuta 'spimi_invert' antes de realizar consultas.")
        print("Se cargo en total: ", self.doc_ids, " documentos")

        # Preprocesar la consulta
        terms = preprocesamiento(query)

        # Calcular el TF-IDF de la consulta
        tf_query = {}
        for term in terms:
            if term in tf_query:
                tf_query[term] += 1
            else:
                tf_query[term] = 1

        tfidf_query = {}
        norm_query = 0

        term_dict = self.load_term_dict()

        for term, tf in tf_query.items():
            if term in term_dict:  # Solo considerar términos presentes en el índice
                position, length = term_dict[term]
                # Calcular IDF basado en postings
                with open(self.postings_file_path, 'rb') as postings_file:
                    postings_file.seek(position)
                    postings_data = postings_file.read(length)
                    postings = pickle.loads(postings_data)  # Cargar postings
                    idf = math.log10(self.doc_ids / (1 + len(postings)))  # IDF

                tfidf_query[term] = math.log10(1 + tf) * idf
                norm_query += (tfidf_query[term]) ** 2
        norm_query = math.sqrt(norm_query) 

        scores = [0] * self.doc_ids  

        with open(self.postings_file_path, 'rb') as postings_file, \
             open(self.norms_file_path, 'rb') as norms_file:

            for term, w_tq in tfidf_query.items():
                if term in term_dict:
                    position, length = term_dict[term]
                    postings_file.seek(position)
                    postings_data = postings_file.read(length)
                    postings = pickle.loads(postings_data)  # Diccionario {doc_id: {'tf': tf, 'idf': idf}}

                    for doc_id_str, values in postings.items():
                        doc_id = int(doc_id_str)  # Convertimos la clave a entero
                        tfidf_td = values['tf'] * values['idf']
                        scores[doc_id] += tfidf_td * w_tq 

            # Normalizar las puntuaciones por la norma de los documentos
            norms_file.seek(0)
            norms = pickle.load(norms_file)
            # Convertir las claves de normas a enteros
            # norms = {int(k): v for k, v in norms.items()}

            for doc_id in range(self.doc_ids):
                doc_norm = norms.get(doc_id, 0)
                # print(f"Doc ID: {doc_id}, Score before normalization: {scores[doc_id]}, Doc Norm: {doc_norm}, Query Norm: {norm_query}")
                # print(f"Tipo de doc_id en postings: {type(doc_id)}, Tipo de doc_id en normas: {type(next(iter(norms.keys())))}")
                if doc_norm != 0:
                    scores[doc_id] /= (doc_norm * norm_query)

        # Ordenar las puntuaciones en orden descendente y devolver los k más relevantes
        result = sorted(enumerate(scores), key=lambda x: x[1], reverse=True)
        return result[:k]




path = "spotify_20.csv"
# ---------Creation---------
s = SPIMI( path)  
s.spimi_invert() 

# ---------End Creation---------
print("Se procesaron en total:  ", s.doc_ids)


#Prubas de merge
# s.show_terms_and_positions()
# s.show_terms_with_postings()
# Out:
# Documentos cargados: 20
# Creando y ordenando cada bloque
# Iniciando con el merge
# Term_dict para current term es:
# {'1': (0, 53)}
# Term_dict para current term es:
# {'2011': (53, 53)}
# Term_dict para current term es:
# {'2nd': (106, 52)}
# Term_dict para current term es:
# {'2pac': (158, 53)}
# Term_dict para current term es:
# {'6': (211, 52)}
# Term_dict para current term es:
# {'aaa': (263, 52)}
# Term_dict para current term es:
# {'abrazadito': (315, 53)}
# Term_dict para current term es:
# {'accordar': (368, 52)}
# Term_dict para current term es:
# {'acemo': (420, 53)}
# Term_dict para current term es:
# {'aceptarlo': (473, 53)}
# Term_dict para current term es:
# {'actin': (526, 53)}
# Term_dict para current term es:
# {'action': (579, 53)}
# Term_dict para current term es:
# {'actitud': (632, 53)}
# Term_dict para current term es:
# {'ador': (685, 52)}
# Term_dict para current term es:
# {'aguilera': (737, 52)}
# Term_dict para current term es:
# {'ain': (789, 115)}
# Term_dict para current term es:
# {'air': (904, 84)}
# Term_dict para current term es:
# {'aisl': (988, 53)}
# Term_dict para current term es:
# {'ake': (1041, 52)}
# Term_dict para current term es:
# {'akin': (1093, 52)}
# Term_dict para current term es:
# {'ako': (1145, 52)}
# Term_dict para current term es:
# {'ala': (1197, 53)}
# Term_dict para current term es:
# {'alam': (1250, 52)}
# Term_dict para current term es:
# {'aliv': (1302, 52)}
# Term_dict para current term es:
# {'alla': (1354, 52)}
# Term_dict para current term es:
# {'alright': (1406, 53)}
# Term_dict para current term es:
# {'altra': (1459, 52)}
# Term_dict para current term es:
# {'amanec': (1511, 53)}
# Term_dict para current term es:
# {'amanecimo': (1564, 53)}
# Term_dict para current term es:
# {'amarradito': (1617, 53)}
# Term_dict para current term es:
# {'america': (1670, 52)}
# Term_dict para current term es:
# {'amo': (1722, 52)}
# Term_dict para current term es:
# {'amplif': (1774, 53)}
# Term_dict para current term es:
# {'anch': (1827, 52)}
# Term_dict para current term es:
# {'ando': (1879, 53)}
# Term_dict para current term es:
# {'anello': (1932, 52)}
# Term_dict para current term es:
# {'ang': (1984, 52)}
# Term_dict para current term es:
# {'angel': (2036, 84)}
# Term_dict para current term es:
# {'answer': (2120, 52)}
# Term_dict para current term es:
# {'appeal': (2172, 53)}
# Term_dict para current term es:
# {'appear': (2225, 52)}
# Term_dict para current term es:
# {'aquí': (2277, 53)}
# Term_dict para current term es:
# {'arm': (2330, 52)}
# Term_dict para current term es:
# {'aserej': (2382, 52)}
# Term_dict para current term es:
# {'askin': (2434, 53)}
# Term_dict para current term es:
# {'así': (2487, 53)}
# Term_dict para current term es:
# {'atención': (2540, 53)}
# Term_dict para current term es:
# {'attract': (2593, 53)}
# Term_dict para current term es:
# {'aunt': (2646, 52)}
# Term_dict para current term es:
# {'awar': (2698, 52)}
# Term_dict para current term es:
# {'aww': (2750, 53)}
# Term_dict para current term es:
# {'ax': (2803, 52)}
# Term_dict para current term es:
# {'ay': (2855, 115)}
# Term_dict para current term es:
# {'aye': (2970, 52)}
# Term_dict para current term es:
# {'azucar': (3022, 53)}
# Term_dict para current term es:
# {'babi': (3075, 206)}
# Term_dict para current term es:
# {'babyfac': (3281, 52)}
# Term_dict para current term es:
# {'bacano': (3333, 53)}
# Term_dict para current term es:
# {'bacio': (3386, 52)}
# Term_dict para current term es:
# {'backstag': (3438, 53)}
# Term_dict para current term es:
# {'bad': (3491, 113)}
# Term_dict para current term es:
# {'baguett': (3604, 52)}
# Term_dict para current term es:
# {'bailar': (3656, 85)}
# Term_dict para current term es:
# {'baina': (3741, 53)}
# Term_dict para current term es:
# {'bajar': (3794, 53)}
# Term_dict para current term es:
# {'baje': (3847, 53)}
# Term_dict para current term es:
# {'bajo': (3900, 53)}
# Term_dict para current term es:
# {'balla': (3953, 52)}
# Term_dict para current term es:
# {'balliamo': (4005, 52)}
# Term_dict para current term es:
# {'bang': (4057, 52)}
# Term_dict para current term es:
# {'barbi': (4109, 52)}
# Term_dict para current term es:
# {'barch': (4161, 52)}
# Term_dict para current term es:
# {'bash': (4213, 53)}
# Term_dict para current term es:
# {'basterebb': (4266, 52)}
# Term_dict para current term es:
# {'bawat': (4318, 52)}
# Term_dict para current term es:
# {'bañarno': (4370, 53)}
# Term_dict para current term es:
# {'beat': (4423, 53)}
# Term_dict para current term es:
# {'beauti': (4476, 113)}
# Term_dict para current term es:
# {'becki': (4589, 53)}
# Term_dict para current term es:
# {'bed': (4642, 52)}
# Term_dict para current term es:
# {'bein': (4694, 53)}
# Term_dict para current term es:
# {'believ': (4747, 52)}
# Term_dict para current term es:
# {'bell': (4799, 52)}
# Term_dict para current term es:
# {'bella': (4851, 53)}
# Term_dict para current term es:
# {'bello': (4904, 52)}
# Term_dict para current term es:
# {'belong': (4956, 52)}
# Term_dict para current term es:
# {'bench': (5008, 52)}
# Term_dict para current term es:
# {'bend': (5060, 52)}
# Term_dict para current term es:
# {'bene': (5112, 52)}
# Term_dict para current term es:
# {'berata': (5164, 53)}
# Term_dict para current term es:
# {'besart': (5217, 53)}
# Term_dict para current term es:
# {'besito': (5270, 53)}
# Term_dict para current term es:
# {'bewar': (5323, 52)}
# Term_dict para current term es:
# {'bien': (5375, 53)}
# Term_dict para current term es:
# {'billi': (5428, 52)}
# Term_dict para current term es:
# {'bit': (5480, 53)}
# Term_dict para current term es:
# {'bitch': (5533, 53)}
# Term_dict para current term es:
# {'biv': (5586, 52)}
# Term_dict para current term es:
# {'black': (5638, 85)}
# Term_dict para current term es:
# {'blade': (5723, 53)}
# Term_dict para current term es:
# {'blast': (5776, 53)}
# Term_dict para current term es:
# {'blasterjaxx': (5829, 52)}
# Term_dict para current term es:
# {'blind': (5881, 52)}
# Term_dict para current term es:
# {'blizzard': (5933, 52)}
# Term_dict para current term es:
# {'blow': (5985, 84)}
# Term_dict para current term es:
# {'blue': (6069, 52)}
# Term_dict para current term es:
# {'bocado': (6121, 53)}
# Term_dict para current term es:
# {'bodi': (6174, 115)}
# Term_dict para current term es:
# {'book': (6289, 53)}
# Term_dict para current term es:
# {'boomdabash': (6342, 52)}
# Term_dict para current term es:
# {'boquita': (6394, 53)}
# Term_dict para current term es:
# {'bother': (6447, 53)}
# Term_dict para current term es:
# {'bound': (6500, 52)}
# Term_dict para current term es:
# {'bout': (6552, 145)}
# Term_dict para current term es:
# {'boy': (6697, 144)}
# Term_dict para current term es:
# {'brain': (6841, 52)}
# Term_dict para current term es:
# {'brave': (6893, 52)}
# Term_dict para current term es:
# {'break': (6945, 113)}
# Term_dict para current term es:
# {'breakfast': (7058, 53)}
# Term_dict para current term es:
# {'breakin': (7111, 52)}
# Term_dict para current term es:
# {'breath': (7163, 83)}
# Term_dict para current term es:
# {'brian': (7246, 53)}
# Term_dict para current term es:
# {'broken': (7299, 52)}
# Term_dict para current term es:
# {'brother': (7351, 84)}
# Term_dict para current term es:
# {'brown': (7435, 52)}
# Term_dict para current term es:
# {'brum': (7487, 53)}
# Term_dict para current term es:
# {'buck': (7540, 53)}
# Term_dict para current term es:
# {'buena': (7593, 53)}
# Term_dict para current term es:
# {'bugi': (7646, 52)}
# Term_dict para current term es:
# {'bumulong': (7698, 52)}
# Term_dict para current term es:
# {'busi': (7750, 52)}
# Term_dict para current term es:
# {'bust': (7802, 53)}
# Term_dict para current term es:
# {'butt': (7855, 52)}
# Term_dict para current term es:
# {'búscame': (7907, 53)}
# Term_dict para current term es:
# {'cab': (7960, 52)}
# Term_dict para current term es:
# {'caiga': (8012, 53)}
# Term_dict para current term es:
# {'calcio': (8065, 52)}
# Term_dict para current term es:
# {'callar': (8117, 53)}
# Term_dict para current term es:
# {'cama': (8170, 53)}
# Term_dict para current term es:
# {'cambi': (8223, 53)}
# Term_dict para current term es:
# {'cambiar': (8276, 53)}
# Term_dict para current term es:
# {'cambiast': (8329, 53)}
# Term_dict para current term es:
# {'cambió': (8382, 53)}
# Term_dict para current term es:
# {'camera': (8435, 53)}
# Term_dict para current term es:
# {'campana': (8488, 53)}
# Term_dict para current term es:
# {'canzoni': (8541, 52)}
# Term_dict para current term es:
# {'car': (8593, 52)}
# Term_dict para current term es:
# {'care': (8645, 84)}
# Term_dict para current term es:
# {'caress': (8729, 52)}
# Term_dict para current term es:
# {'carri': (8781, 52)}
# Term_dict para current term es:
# {'carro': (8833, 53)}
# Term_dict para current term es:
# {'cart': (8886, 53)}
# Term_dict para current term es:
# {'castl': (8939, 53)}
# Term_dict para current term es:
# {'catch': (8992, 53)}
# Term_dict para current term es:
# {'caught': (9045, 52)}
# Term_dict para current term es:
# {'caution': (9097, 52)}
# Term_dict para current term es:
# {'ceelo': (9149, 52)}
# Term_dict para current term es:
# {'ceil': (9201, 53)}
# Term_dict para current term es:
# {'cervello': (9254, 52)}
# Term_dict para current term es:
# {'chabli': (9306, 53)}
# Term_dict para current term es:
# {'chang': (9359, 53)}
# Term_dict para current term es:
# {'chapter': (9412, 52)}
# Term_dict para current term es:
# {'chat': (9464, 53)}
# Term_dict para current term es:
# {'che': (9517, 84)}
# Term_dict para current term es:
# {'cheat': (9601, 52)}
# Term_dict para current term es:
# {'checkin': (9653, 52)}
# Term_dict para current term es:
# {'chest': (9705, 84)}
# Term_dict para current term es:
# {'chez': (9789, 53)}
# Term_dict para current term es:
# {'chicago': (9842, 53)}
# Term_dict para current term es:
# {'chick': (9895, 53)}
# Term_dict para current term es:
# {'child': (9948, 52)}
# Term_dict para current term es:
# {'chill': (10000, 53)}
# Term_dict para current term es:
# {'chissà': (10053, 52)}
# Term_dict para current term es:
# {'chit': (10105, 53)}
# Term_dict para current term es:
# {'chitarra': (10158, 52)}
# Term_dict para current term es:
# {'chiusi': (10210, 52)}
# Term_dict para current term es:
# {'choco': (10262, 53)}
# Term_dict para current term es:
# {'chose': (10315, 52)}
# Term_dict para current term es:
# {'christina': (10367, 52)}
# Term_dict para current term es:
# {'chulo': (10419, 53)}
# Term_dict para current term es:
# {'ciego': (10472, 53)}
# Term_dict para current term es:
# {'cielo': (10525, 53)}
# Term_dict para current term es:
# {'cigarett': (10578, 52)}
# Term_dict para current term es:
# {'cintura': (10630, 53)}
# Term_dict para current term es:
# {'circl': (10683, 53)}
# Term_dict para current term es:
# {'citi': (10736, 53)}
# Term_dict para current term es:
# {'clockin': (10789, 52)}
# Term_dict para current term es:
# {'close': (10841, 115)}
# Term_dict para current term es:
# {'closer': (10956, 113)}
# Term_dict para current term es:
# {'cloud': (11069, 52)}
# Term_dict para current term es:
# {'coat': (11121, 52)}
# Term_dict para current term es:
# {'coca': (11173, 52)}
# Term_dict para current term es:
# {'coil': (11225, 52)}
# Term_dict para current term es:
# {'cola': (11277, 52)}
# Term_dict para current term es:
# {'cold': (11329, 52)}
# Term_dict para current term es:
# {'colder': (11381, 52)}
# Term_dict para current term es:
# {'comin': (11433, 53)}
# Term_dict para current term es:
# {'como': (11486, 85)}
# Term_dict para current term es:
# {'conceal': (11571, 53)}
# Term_dict para current term es:
# {'confesart': (11624, 53)}
# Term_dict para current term es:
# {'confiar': (11677, 53)}
# Term_dict para current term es:
# {'confond': (11730, 52)}
# Term_dict para current term es:
# {'confort': (11782, 53)}
# Term_dict para current term es:
# {'contest': (11835, 53)}
# Term_dict para current term es:
# {'contigo': (11888, 116)}
# Term_dict para current term es:
# {'conto': (12004, 52)}
# Term_dict para current term es:
# {'contro': (12056, 52)}
# Term_dict para current term es:
# {'convers': (12108, 53)}
# Term_dict para current term es:
# {'convertí': (12161, 53)}
# Term_dict para current term es:
# {'cool': (12214, 85)}
# Term_dict para current term es:
# {'cop': (12299, 53)}
# Term_dict para current term es:
# {'corazon': (12352, 53)}
# Term_dict para current term es:
# {'corner': (12405, 52)}
# Term_dict para current term es:
# {'cos': (12457, 52)}
# Term_dict para current term es:
# {'cosa': (12509, 52)}
# Term_dict para current term es:
# {'costum': (12561, 53)}
# Term_dict para current term es:
# {'count': (12614, 52)}
# Term_dict para current term es:
# {'courag': (12666, 52)}
# Term_dict para current term es:
# {'crack': (12718, 53)}
# Term_dict para current term es:
# {'cradl': (12771, 52)}
# Term_dict para current term es:
# {'crampin': (12823, 53)}
# Term_dict para current term es:
# {'crazi': (12876, 53)}
# Term_dict para current term es:
# {'credi': (12929, 52)}
# Term_dict para current term es:
# {'cree': (12981, 53)}
# Term_dict para current term es:
# {'crew': (13034, 52)}
# Term_dict para current term es:
# {'crime': (13086, 53)}
# Term_dict para current term es:
# {'crimin': (13139, 52)}
# Term_dict para current term es:
# {'cross': (13191, 53)}
# Term_dict para current term es:
# {'cruella': (13244, 53)}
# Term_dict para current term es:
# {'cruis': (13297, 53)}
# Term_dict para current term es:
# {'crujient': (13350, 53)}
# Term_dict para current term es:
# {'crumbl': (13403, 52)}
# Term_dict para current term es:
# {'cuando': (13455, 116)}
# Term_dict para current term es:
# {'cubana': (13571, 53)}
# Term_dict para current term es:
# {'cuerpo': (13624, 53)}
# Term_dict para current term es:
# {'cuesta': (13677, 53)}
# Term_dict para current term es:
# {'culpa': (13730, 53)}
# Term_dict para current term es:
# {'cumpl': (13783, 53)}
# Term_dict para current term es:
# {'cura': (13836, 85)}
# Term_dict para current term es:
# {'cure': (13921, 52)}
# Term_dict para current term es:
# {'cut': (13973, 52)}
# Term_dict para current term es:
# {'cómo': (14025, 53)}
# Term_dict para current term es:
# {'da': (14078, 52)}
# Term_dict para current term es:
# {'dai': (14130, 52)}
# Term_dict para current term es:
# {'dal': (14182, 52)}
# Term_dict para current term es:
# {'dalla': (14234, 52)}
# Term_dict para current term es:
# {'dame': (14286, 53)}
# Term_dict para current term es:
# {'damn': (14339, 85)}
# Term_dict para current term es:
# {'danc': (14424, 145)}
# Term_dict para current term es:
# {'darat': (14569, 52)}
# Term_dict para current term es:
# {'dark': (14621, 53)}
# Term_dict para current term es:
# {'darkest': (14674, 52)}
# Term_dict para current term es:
# {'darl': (14726, 52)}
# Term_dict para current term es:
# {'dart': (14778, 53)}
# Term_dict para current term es:
# {'day': (14831, 84)}
# Term_dict para current term es:
# {'dead': (14915, 84)}
# Term_dict para current term es:
# {'deal': (14999, 53)}
# Term_dict para current term es:
# {'dealin': (15052, 52)}
# Term_dict para current term es:
# {'deceiv': (15104, 52)}
# Term_dict para current term es:
# {'decirt': (15156, 53)}
# Term_dict para current term es:
# {'decis': (15209, 52)}
# Term_dict para current term es:
# {'dedica': (15261, 52)}
# Term_dict para current term es:
# {'dedicar': (15313, 52)}
# Term_dict para current term es:
# {'deg': (15365, 52)}
# Term_dict para current term es:
# {'deja': (15417, 53)}
# Term_dict para current term es:
# {'dejast': (15470, 53)}
# Term_dict para current term es:
# {'del': (15523, 84)}
# Term_dict para current term es:
# {'delici': (15607, 52)}
# Term_dict para current term es:
# {'dell': (15659, 52)}
# Term_dict para current term es:
# {'della': (15711, 52)}
# Term_dict para current term es:
# {'delux': (15763, 53)}
# Term_dict para current term es:
# {'dement': (15816, 53)}
# Term_dict para current term es:
# {'demon': (15869, 52)}
# Term_dict para current term es:
# {'depth': (15921, 52)}
# Term_dict para current term es:
# {'desahogar': (15973, 53)}
# Term_dict para current term es:
# {'descontrola': (16026, 53)}
# Term_dict para current term es:
# {'desea': (16079, 53)}
# Term_dict para current term es:
# {'desir': (16132, 53)}
# Term_dict para current term es:
# {'despacito': (16185, 53)}
# Term_dict para current term es:
# {'despair': (16238, 83)}
# Term_dict para current term es:
# {'destila': (16321, 53)}
# Term_dict para current term es:
# {'devic': (16374, 53)}
# Term_dict para current term es:
# {'devil': (16427, 53)}
# Term_dict para current term es:
# {'devill': (16480, 53)}
# Term_dict para current term es:
# {'devo': (16533, 52)}
# Term_dict para current term es:
# {'di': (16585, 52)}
# Term_dict para current term es:
# {'diablo': (16637, 53)}
# Term_dict para current term es:
# {'diamond': (16690, 52)}
# Term_dict para current term es:
# {'dice': (16742, 53)}
# Term_dict para current term es:
# {'diciamo': (16795, 52)}
# Term_dict para current term es:
# {'diddi': (16847, 52)}
# Term_dict para current term es:
# {'die': (16899, 84)}
# Term_dict para current term es:
# {'dient': (16983, 53)}
# Term_dict para current term es:
# {'diferent': (17036, 53)}
# Term_dict para current term es:
# {'dig': (17089, 116)}
# Term_dict para current term es:
# {'diga': (17205, 53)}
# Term_dict para current term es:
# {'digit': (17258, 52)}
# Term_dict para current term es:
# {'dijist': (17310, 53)}
# Term_dict para current term es:
# {'dile': (17363, 53)}
# Term_dict para current term es:
# {'dimmi': (17416, 52)}
# Term_dict para current term es:
# {'dio': (17468, 53)}
# Term_dict para current term es:
# {'dirti': (17521, 84)}
# Term_dict para current term es:
# {'disapprov': (17605, 52)}
# Term_dict para current term es:
# {'disfruta': (17657, 53)}
# Term_dict para current term es:
# {'disgrac': (17710, 53)}
# Term_dict para current term es:
# {'dist': (17763, 53)}
# Term_dict para current term es:
# {'distanc': (17816, 52)}
# Term_dict para current term es:
# {'distant': (17868, 53)}
# Term_dict para current term es:
# {'dito': (17921, 52)}
# Term_dict para current term es:
# {'diversi': (17973, 52)}
# Term_dict para current term es:
# {'divid': (18025, 53)}
# Term_dict para current term es:
# {'divina': (18078, 53)}
# Term_dict para current term es:
# {'divorc': (18131, 53)}
# Term_dict para current term es:
# {'dolc': (18184, 53)}
# Term_dict para current term es:
# {'dond': (18237, 53)}
# Term_dict para current term es:
# {'donn': (18290, 52)}
# Term_dict para current term es:
# {'door': (18342, 52)}
# Term_dict para current term es:
# {'doowop': (18394, 53)}
# Term_dict para current term es:
# {'dope': (18447, 53)}
# Term_dict para current term es:
# {'doubt': (18500, 52)}
# Term_dict para current term es:
# {'dove': (18552, 53)}
# Term_dict para current term es:
# {'drama': (18605, 52)}
# Term_dict para current term es:
# {'dreamin': (18657, 52)}
# Term_dict para current term es:
# {'dress': (18709, 53)}
# Term_dict para current term es:
# {'drink': (18762, 84)}
# Term_dict para current term es:
# {'drippin': (18846, 52)}
# Term_dict para current term es:
# {'drive': (18898, 83)}
# Term_dict para current term es:
# {'drivin': (18981, 52)}
# Term_dict para current term es:
# {'drop': (19033, 52)}
# Term_dict para current term es:
# {'drug': (19085, 53)}
# Term_dict para current term es:
# {'drum': (19138, 52)}
# Term_dict para current term es:
# {'dude': (19190, 53)}
# Term_dict para current term es:
# {'dumb': (19243, 52)}
# Term_dict para current term es:
# {'dura': (19295, 84)}
# Term_dict para current term es:
# {'duro': (19379, 85)}
# Term_dict para current term es:
# {'dé': (19464, 53)}
# Term_dict para current term es:
# {'déjà': (19517, 52)}
# Term_dict para current term es:
# {'día': (19569, 53)}
# Term_dict para current term es:
# {'díselo': (19622, 53)}
# Term_dict para current term es:
# {'eas': (19675, 52)}
# Term_dict para current term es:
# {'easi': (19727, 53)}
# Term_dict para current term es:
# {'east': (19780, 53)}
# Term_dict para current term es:
# {'eat': (19833, 53)}
# Term_dict para current term es:
# {'edit': (19886, 85)}
# Term_dict para current term es:
# {'eilish': (19971, 52)}
# Term_dict para current term es:
# {'el': (20023, 147)}
# Term_dict para current term es:
# {'eleanor': (20170, 52)}
# Term_dict para current term es:
# {'elektra': (20222, 53)}
# Term_dict para current term es:
# {'ella': (20275, 85)}
# Term_dict para current term es:
# {'em': (20360, 115)}
# Term_dict para current term es:
# {'emi': (20475, 53)}
# Term_dict para current term es:
# {'empezando': (20528, 53)}
# Term_dict para current term es:
# {'empezar': (20581, 53)}
# Term_dict para current term es:
# {'empti': (20634, 52)}
# Term_dict para current term es:
# {'en': (20686, 147)}
# Term_dict para current term es:
# {'enamorada': (20833, 53)}
# Term_dict para current term es:
# {'enamorado': (20886, 53)}
# Term_dict para current term es:
# {'enamoré': (20939, 53)}
# Term_dict para current term es:
# {'energi': (20992, 53)}
# Term_dict para current term es:
# {'enseñart': (21045, 53)}
# Term_dict para current term es:
# {'entendido': (21098, 53)}
# Term_dict para current term es:
# {'entero': (21151, 53)}
# Term_dict para current term es:
# {'entertain': (21204, 53)}
# Term_dict para current term es:
# {'entr': (21257, 53)}
# Term_dict para current term es:
# {'entrambi': (21310, 52)}
# Term_dict para current term es:
# {'envi': (21362, 52)}
# Term_dict para current term es:
# {'envida': (21414, 53)}
# Term_dict para current term es:
# {'ep': (21467, 53)}
# Term_dict para current term es:
# {'era': (21520, 52)}
# Term_dict para current term es:
# {'eras': (21572, 53)}
# Term_dict para current term es:
# {'erba': (21625, 52)}
# Term_dict para current term es:
# {'ere': (21677, 85)}
# Term_dict para current term es:
# {'esci': (21762, 52)}
# Term_dict para current term es:
# {'escono': (21814, 52)}
# Term_dict para current term es:
# {'escuchar': (21866, 53)}
# Term_dict para current term es:
# {'eso': (21919, 53)}
# Term_dict para current term es:
# {'esperaba': (21972, 53)}
# Term_dict para current term es:
# {'esperaban': (22025, 53)}
# Term_dict para current term es:
# {'esperando': (22078, 53)}
# Term_dict para current term es:
# {'estamo': (22131, 53)}
# Term_dict para current term es:
# {'esto': (22184, 53)}
# Term_dict para current term es:
# {'estoy': (22237, 85)}
# Term_dict para current term es:
# {'estrella': (22322, 53)}
# Term_dict para current term es:
# {'está': (22375, 116)}
# Term_dict para current term es:
# {'eterno': (22491, 52)}
# Term_dict para current term es:
# {'eto': (22543, 53)}
# Term_dict para current term es:
# {'even': (22596, 52)}
# Term_dict para current term es:
# {'evil': (22648, 53)}
# Term_dict para current term es:
# {'evitarlo': (22701, 53)}
# Term_dict para current term es:
# {'expir': (22754, 53)}
# Term_dict para current term es:
# {'explico': (22807, 53)}
# Term_dict para current term es:
# {'extraño': (22860, 53)}
# Term_dict para current term es:
# {'ey': (22913, 53)}
# Term_dict para current term es:
# {'eye': (22966, 144)}
# Term_dict para current term es:
# {'fa': (23110, 84)}
# Term_dict para current term es:
# {'facil': (23194, 52)}
# Term_dict para current term es:
# {'fade': (23246, 52)}
# Term_dict para current term es:
# {'fai': (23298, 52)}
# Term_dict para current term es:
# {'fall': (23350, 114)}
# Term_dict para current term es:
# {'fare': (23464, 52)}
# Term_dict para current term es:
# {'farlo': (23516, 52)}
# Term_dict para current term es:
# {'fat': (23568, 53)}
# Term_dict para current term es:
# {'father': (23621, 52)}
# Term_dict para current term es:
# {'fatta': (23673, 52)}
# Term_dict para current term es:
# {'fault': (23725, 52)}
# Term_dict para current term es:
# {'favorita': (23777, 53)}
# Term_dict para current term es:
# {'fear': (23830, 52)}
# Term_dict para current term es:
# {'feat': (23882, 144)}
# Term_dict para current term es:
# {'feel': (24026, 204)}
# Term_dict para current term es:
# {'feelin': (24230, 85)}
# Term_dict para current term es:
# {'fella': (24315, 52)}
# Term_dict para current term es:
# {'fellow': (24367, 52)}
# Term_dict para current term es:
# {'femminil': (24419, 52)}
# Term_dict para current term es:
# {'fenc': (24471, 52)}
# Term_dict para current term es:
# {'ferrari': (24523, 53)}
# Term_dict para current term es:
# {'fiesta': (24576, 53)}
# Term_dict para current term es:
# {'fight': (24629, 84)}
# Term_dict para current term es:
# {'fill': (24713, 53)}
# Term_dict para current term es:
# {'fin': (24766, 53)}
# Term_dict para current term es:
# {'fina': (24819, 53)}
# Term_dict para current term es:
# {'finché': (24872, 52)}
# Term_dict para current term es:
# {'finest': (24924, 53)}
# Term_dict para current term es:
# {'fino': (24977, 52)}
# Term_dict para current term es:
# {'fireplac': (25029, 52)}
# Term_dict para current term es:
# {'flama': (25081, 53)}
# Term_dict para current term es:
# {'flame': (25134, 53)}
# Term_dict para current term es:
# {'flashin': (25187, 53)}
# Term_dict para current term es:
# {'fli': (25240, 84)}
# Term_dict para current term es:
# {'fling': (25324, 53)}
# Term_dict para current term es:
# {'floor': (25377, 52)}
# Term_dict para current term es:
# {'flow': (25429, 53)}
# Term_dict para current term es:
# {'follow': (25482, 52)}
# Term_dict para current term es:
# {'fool': (25534, 85)}
# Term_dict para current term es:
# {'forc': (25619, 53)}
# Term_dict para current term es:
# {'forget': (25672, 52)}
# Term_dict para current term es:
# {'frame': (25724, 52)}
# Term_dict para current term es:
# {'freez': (25776, 83)}
# Term_dict para current term es:
# {'frenar': (25859, 53)}
# Term_dict para current term es:
# {'freno': (25912, 53)}
# Term_dict para current term es:
# {'friend': (25965, 53)}
# Term_dict para current term es:
# {'frighten': (26018, 52)}
# Term_dict para current term es:
# {'fro': (26070, 52)}
# Term_dict para current term es:
# {'fuck': (26122, 53)}
# Term_dict para current term es:
# {'fue': (26175, 85)}
# Term_dict para current term es:
# {'fuego': (26260, 85)}
# Term_dict para current term es:
# {'fumando': (26345, 53)}
# Term_dict para current term es:
# {'funni': (26398, 53)}
# Term_dict para current term es:
# {'futuroo': (26451, 53)}
# Term_dict para current term es:
# {'gabbana': (26504, 53)}
# Term_dict para current term es:
# {'game': (26557, 84)}
# Term_dict para current term es:
# {'gawin': (26641, 52)}
# Term_dict para current term es:
# {'gent': (26693, 84)}
# Term_dict para current term es:
# {'gentlemen': (26777, 53)}
# Term_dict para current term es:
# {'gettin': (26830, 52)}
# Term_dict para current term es:
# {'gift': (26882, 53)}
# Term_dict para current term es:
# {'gioiello': (26935, 52)}
# Term_dict para current term es:
# {'girl': (26987, 144)}
# Term_dict para current term es:
# {'giuro': (27131, 52)}
# Term_dict para current term es:
# {'givin': (27183, 53)}
# Term_dict para current term es:
# {'gli': (27236, 52)}
# Term_dict para current term es:
# {'glisten': (27288, 52)}
# Term_dict para current term es:
# {'gloria': (27340, 53)}
# Term_dict para current term es:
# {'gold': (27393, 52)}
# Term_dict para current term es:
# {'gon': (27445, 236)}
# Term_dict para current term es:
# {'goowi': (27681, 53)}
# Term_dict para current term es:
# {'gosh': (27734, 52)}
# Term_dict para current term es:
# {'grand': (27786, 52)}
# Term_dict para current term es:
# {'grave': (27838, 53)}
# Term_dict para current term es:
# {'gray': (27891, 52)}
# Term_dict para current term es:
# {'green': (27943, 52)}
# Term_dict para current term es:
# {'grip': (27995, 52)}
# Term_dict para current term es:
# {'grita': (28047, 53)}
# Term_dict para current term es:
# {'groovi': (28100, 53)}
# Term_dict para current term es:
# {'ground': (28153, 53)}
# Term_dict para current term es:
# {'groupi': (28206, 53)}
# Term_dict para current term es:
# {'grow': (28259, 114)}
# Term_dict para current term es:
# {'grown': (28373, 84)}
# Term_dict para current term es:
# {'guarda': (28457, 52)}
# Term_dict para current term es:
# {'gun': (28509, 53)}
# Term_dict para current term es:
# {'gurl': (28562, 53)}
# Term_dict para current term es:
# {'gusta': (28615, 53)}
# Term_dict para current term es:
# {'gustan': (28668, 53)}
# Term_dict para current term es:
# {'guy': (28721, 53)}
# Term_dict para current term es:
# {'ha': (28774, 53)}
# Term_dict para current term es:
# {'habitación': (28827, 53)}
# Term_dict para current term es:
# {'hacemo': (28880, 53)}
# Term_dict para current term es:
# {'hacer': (28933, 53)}
# Term_dict para current term es:
# {'haga': (28986, 53)}
# Term_dict para current term es:
# {'hago': (29039, 53)}
# Term_dict para current term es:
# {'hair': (29092, 52)}
# Term_dict para current term es:
# {'hand': (29144, 83)}
# Term_dict para current term es:
# {'hanggang': (29227, 52)}
# Term_dict para current term es:
# {'hangin': (29279, 52)}
# Term_dict para current term es:
# {'hard': (29331, 83)}
# Term_dict para current term es:
# {'harm': (29414, 52)}
# Term_dict para current term es:
# {'haré': (29466, 53)}
# Term_dict para current term es:
# {'hasta': (29519, 85)}
# Term_dict para current term es:
# {'hat': (29604, 52)}
# Term_dict para current term es:
# {'hate': (29656, 53)}
# Term_dict para current term es:
# {'hay': (29709, 53)}
# Term_dict para current term es:
# {'head': (29762, 52)}
# Term_dict para current term es:
# {'heal': (29814, 53)}
# Term_dict para current term es:
# {'hear': (29867, 84)}
# Term_dict para current term es:
# {'heart': (29951, 205)}
# Term_dict para current term es:
# {'heartfelt': (30156, 52)}
# Term_dict para current term es:
# {'heaven': (30208, 53)}
# Term_dict para current term es:
# {'heidi': (30261, 52)}
# Term_dict para current term es:
# {'hero': (30313, 53)}
# Term_dict para current term es:
# {'hey': (30366, 145)}
# Term_dict para current term es:
# {'hice': (30511, 53)}
# Term_dict para current term es:
# {'hicimo': (30564, 53)}
# Term_dict para current term es:
# {'hide': (30617, 84)}
# Term_dict para current term es:
# {'hideaway': (30701, 52)}
# Term_dict para current term es:
# {'high': (30753, 52)}
# Term_dict para current term es:
# {'highdrow': (30805, 53)}
# Term_dict para current term es:
# {'hindi': (30858, 52)}
# Term_dict para current term es:
# {'hippi': (30910, 53)}
# Term_dict para current term es:
# {'hit': (30963, 53)}
# Term_dict para current term es:
# {'ho': (31016, 114)}
# Term_dict para current term es:
# {'hoe': (31130, 52)}
# Term_dict para current term es:
# {'hola': (31182, 53)}
# Term_dict para current term es:
# {'hold': (31235, 235)}
# Term_dict para current term es:
# {'homi': (31470, 53)}
# Term_dict para current term es:
# {'hoo': (31523, 52)}
# Term_dict para current term es:
# {'hope': (31575, 52)}
# Term_dict para current term es:
# {'hous': (31627, 52)}
# Term_dict para current term es:
# {'huey': (31679, 53)}
# Term_dict para current term es:
# {'huh': (31732, 52)}
# Term_dict para current term es:
# {'hungri': (31784, 53)}
# Term_dict para current term es:
# {'hunnybun': (31837, 53)}
# Term_dict para current term es:
# {'hunt': (31890, 84)}
# Term_dict para current term es:
# {'hurri': (31974, 52)}
# Term_dict para current term es:
# {'hurt': (32026, 144)}
# Term_dict para current term es:
# {'huski': (32170, 52)}
# Term_dict para current term es:
# {'ice': (32222, 52)}
# Term_dict para current term es:
# {'ickey': (32274, 53)}
# Term_dict para current term es:
# {'ignorar': (32327, 53)}
# Term_dict para current term es:
# {'igual': (32380, 53)}
# Term_dict para current term es:
# {'ihhh': (32433, 53)}
# Term_dict para current term es:
# {'ika': (32486, 52)}
# Term_dict para current term es:
# {'ikaw': (32538, 52)}
# Term_dict para current term es:
# {'imaginando': (32590, 53)}
# Term_dict para current term es:
# {'impli': (32643, 52)}
# Term_dict para current term es:
# {'importa': (32695, 52)}
# Term_dict para current term es:
# {'impress': (32747, 52)}
# Term_dict para current term es:
# {'incostanti': (32799, 52)}
# Term_dict para current term es:
# {'indecent': (32851, 53)}
# Term_dict para current term es:
# {'inocent': (32904, 53)}
# Term_dict para current term es:
# {'intenté': (32957, 53)}
# Term_dict para current term es:
# {'iphon': (33010, 53)}
# Term_dict para current term es:
# {'isang': (33063, 52)}
# Term_dict para current term es:
# {'ita': (33115, 53)}
# Term_dict para current term es:
# {'italian': (33168, 53)}
# Term_dict para current term es:
# {'ito': (33221, 52)}
# Term_dict para current term es:
# {'iyong': (33273, 52)}
# Term_dict para current term es:
# {'ja': (33325, 53)}
# Term_dict para current term es:
# {'jack': (33378, 53)}
# Term_dict para current term es:
# {'jaja': (33431, 53)}
# Term_dict para current term es:
# {'jajaja': (33484, 53)}
# Term_dict para current term es:
# {'jame': (33537, 52)}
# Term_dict para current term es:
# {'japanes': (33589, 53)}
# Term_dict para current term es:
# {'jax': (33642, 53)}
# Term_dict para current term es:
# {'jay': (33695, 53)}
# Term_dict para current term es:
# {'jazz': (33748, 53)}
# Term_dict para current term es:
# {'jealous': (33801, 84)}
# Term_dict para current term es:
# {'jet': (33885, 52)}
# Term_dict para current term es:
# {'johnni': (33937, 52)}
# Term_dict para current term es:
# {'jone': (33989, 53)}
# Term_dict para current term es:
# {'jugueton': (34042, 53)}
# Term_dict para current term es:
# {'jump': (34095, 52)}
# Term_dict para current term es:
# {'juro': (34147, 53)}
# Term_dict para current term es:
# {'ka': (34200, 52)}
# Term_dict para current term es:
# {'kailan': (34252, 52)}
# Term_dict para current term es:
# {'kard': (34304, 52)}
# Term_dict para current term es:
# {'kay': (34356, 52)}
# Term_dict para current term es:
# {'kaya': (34408, 52)}
# Term_dict para current term es:
# {'keepin': (34460, 52)}
# Term_dict para current term es:
# {'kick': (34512, 53)}
# Term_dict para current term es:
# {'kid': (34565, 84)}
# Term_dict para current term es:
# {'kill': (34649, 53)}
# Term_dict para current term es:
# {'killin': (34702, 53)}
# Term_dict para current term es:
# {'king': (34755, 52)}
# Term_dict para current term es:
# {'kiss': (34807, 83)}
# Term_dict para current term es:
# {'knee': (34890, 52)}
# Term_dict para current term es:
# {'knock': (34942, 52)}
# Term_dict para current term es:
# {'know': (34994, 52)}
# Term_dict para current term es:
# {'ko': (35046, 52)}
# Term_dict para current term es:
# {'kong': (35098, 52)}
# Term_dict para current term es:
# {'kung': (35150, 52)}
# Term_dict para current term es:
# {'kénsel': (35202, 53)}
# Term_dict para current term es:
# {'labio': (35255, 53)}
# Term_dict para current term es:
# {'lace': (35308, 52)}
# Term_dict para current term es:
# {'ladi': (35360, 53)}
# Term_dict para current term es:
# {'laid': (35413, 52)}
# Term_dict para current term es:
# {'lamig': (35465, 52)}
# Term_dict para current term es:
# {'lang': (35517, 52)}
# Term_dict para current term es:
# {'langit': (35569, 52)}
# Term_dict para current term es:
# {'las': (35621, 85)}
# Term_dict para current term es:
# {'latina': (35706, 53)}
# Term_dict para current term es:
# {'laugh': (35759, 52)}
# Term_dict para current term es:
# {'lay': (35811, 114)}
# Term_dict para current term es:
# {'le': (35925, 115)}
# Term_dict para current term es:
# {'learn': (36040, 84)}
# Term_dict para current term es:
# {'leather': (36124, 53)}
# Term_dict para current term es:
# {'leav': (36177, 52)}
# Term_dict para current term es:
# {'left': (36229, 53)}
# Term_dict para current term es:
# {'lend': (36282, 52)}
# Term_dict para current term es:
# {'letal': (36334, 53)}
# Term_dict para current term es:
# {'libertà': (36387, 52)}
# Term_dict para current term es:
# {'lick': (36439, 53)}
# Term_dict para current term es:
# {'lie': (36492, 145)}
# Term_dict para current term es:
# {'life': (36637, 175)}
# Term_dict para current term es:
# {'lift': (36812, 53)}
# Term_dict para current term es:
# {'light': (36865, 115)}
# Term_dict para current term es:
# {'lil': (36980, 53)}
# Term_dict para current term es:
# {'lilingon': (37033, 52)}
# Term_dict para current term es:
# {'limeston': (37085, 53)}
# Term_dict para current term es:
# {'limit': (37138, 52)}
# Term_dict para current term es:
# {'lip': (37190, 83)}
# Term_dict para current term es:
# {'listen': (37273, 114)}
# Term_dict para current term es:
# {'litti': (37387, 52)}
# Term_dict para current term es:
# {'live': (37439, 115)}
# Term_dict para current term es:
# {'livin': (37554, 53)}
# Term_dict para current term es:
# {'llama': (37607, 53)}
# Term_dict para current term es:
# {'llamada': (37660, 53)}
# Term_dict para current term es:
# {'llamar': (37713, 53)}
# Term_dict para current term es:
# {'llamart': (37766, 53)}
# Term_dict para current term es:
# {'llegaba': (37819, 53)}
# Term_dict para current term es:
# {'llego': (37872, 53)}
# Term_dict para current term es:
# {'lleva': (37925, 53)}
# Term_dict para current term es:
# {'llevara': (37978, 53)}
# Term_dict para current term es:
# {'llevo': (38031, 53)}
# Term_dict para current term es:
# {'llevé': (38084, 53)}
# Term_dict para current term es:
# {'llorado': (38137, 53)}
# Term_dict para current term es:
# {'lo': (38190, 147)}
# Term_dict para current term es:
# {'loca': (38337, 53)}
# Term_dict para current term es:
# {'locaa': (38390, 53)}
# Term_dict para current term es:
# {'locat': (38443, 53)}
# Term_dict para current term es:
# {'loco': (38496, 85)}
# Term_dict para current term es:
# {'lone': (38581, 52)}
# Term_dict para current term es:
# {'lontana': (38633, 52)}
# Term_dict para current term es:
# {'lookin': (38685, 84)}
# Term_dict para current term es:
# {'los': (38769, 85)}
# Term_dict para current term es:
# {'loser': (38854, 52)}
# Term_dict para current term es:
# {'loss': (38906, 52)}
# Term_dict para current term es:
# {'lot': (38958, 53)}
# Term_dict para current term es:
# {'loui': (39011, 53)}
# Term_dict para current term es:
# {'love': (39064, 328)}
# Term_dict para current term es:
# {'lover': (39392, 83)}
# Term_dict para current term es:
# {'low': (39475, 52)}
# Term_dict para current term es:
# {'loyal': (39527, 52)}
# Term_dict para current term es:
# {'lucio': (39579, 52)}
# Term_dict para current term es:
# {'lucki': (39631, 52)}
# Term_dict para current term es:
# {'lujuria': (39683, 53)}
# Term_dict para current term es:
# {'luna': (39736, 53)}
# Term_dict para current term es:
# {'lust': (39789, 53)}
# Term_dict para current term es:
# {'luz': (39842, 53)}
# Term_dict para current term es:
# {'líder': (39895, 53)}
# Term_dict para current term es:
# {'magic': (39948, 84)}
# Term_dict para current term es:
# {'mai': (40032, 52)}
# Term_dict para current term es:
# {'maiden': (40084, 52)}
# Term_dict para current term es:
# {'makin': (40136, 53)}
# Term_dict para current term es:
# {'male': (40189, 52)}
# Term_dict para current term es:
# {'malibu': (40241, 52)}
# Term_dict para current term es:
# {'maluma': (40293, 53)}
# Term_dict para current term es:
# {'mama': (40346, 85)}
# Term_dict para current term es:
# {'mamacita': (40431, 53)}
# Term_dict para current term es:
# {'mami': (40484, 85)}
# Term_dict para current term es:
# {'manbo': (40569, 53)}
# Term_dict para current term es:
# {'mangarap': (40622, 52)}
# Term_dict para current term es:
# {'mano': (40674, 52)}
# Term_dict para current term es:
# {'mantien': (40726, 53)}
# Term_dict para current term es:
# {'manzana': (40779, 53)}
# Term_dict para current term es:
# {'maradona': (40832, 52)}
# Term_dict para current term es:
# {'marat': (40884, 52)}
# Term_dict para current term es:
# {'mare': (40936, 52)}
# Term_dict para current term es:
# {'marea': (40988, 53)}
# Term_dict para current term es:
# {'mari': (41041, 53)}
# Term_dict para current term es:
# {'martin': (41094, 53)}
# Term_dict para current term es:
# {'maschi': (41147, 52)}
# Term_dict para current term es:
# {'matter': (41199, 52)}
# Term_dict para current term es:
# {'meant': (41251, 52)}
# Term_dict para current term es:
# {'meet': (41303, 52)}
# Term_dict para current term es:
# {'meglio': (41355, 52)}
# Term_dict para current term es:
# {'mellow': (41407, 52)}
# Term_dict para current term es:
# {'melt': (41459, 52)}
# Term_dict para current term es:
# {'menu': (41511, 53)}
# Term_dict para current term es:
# {'merchandis': (41564, 53)}
# Term_dict para current term es:
# {'met': (41617, 52)}
# Term_dict para current term es:
# {'metrica': (41669, 52)}
# Term_dict para current term es:
# {'mga': (41721, 52)}
# Term_dict para current term es:
# {'mi': (41773, 146)}
# Term_dict para current term es:
# {'mia': (41919, 52)}
# Term_dict para current term es:
# {'michael': (41971, 52)}
# Term_dict para current term es:
# {'michell': (42023, 53)}
# Term_dict para current term es:
# {'middl': (42076, 53)}
# Term_dict para current term es:
# {'midnight': (42129, 52)}
# Term_dict para current term es:
# {'miel': (42181, 53)}
# Term_dict para current term es:
# {'mike': (42234, 52)}
# Term_dict para current term es:
# {'miley': (42286, 52)}
# Term_dict para current term es:
# {'mill': (42338, 52)}
# Term_dict para current term es:
# {'mind': (42390, 113)}
# Term_dict para current term es:
# {'minsan': (42503, 52)}
# Term_dict para current term es:
# {'mio': (42555, 52)}
# Term_dict para current term es:
# {'mira': (42607, 85)}
# Term_dict para current term es:
# {'mis': (42692, 53)}
# Term_dict para current term es:
# {'misplac': (42745, 53)}
# Term_dict para current term es:
# {'mistak': (42798, 52)}
# Term_dict para current term es:
# {'mma': (42850, 52)}
# Term_dict para current term es:
# {'mmm': (42902, 53)}
# Term_dict para current term es:
# {'mobil': (42955, 53)}
# Term_dict para current term es:
# {'moda': (43008, 52)}
# Term_dict para current term es:
# {'modert': (43060, 53)}
# Term_dict para current term es:
# {'mold': (43113, 52)}
# Term_dict para current term es:
# {'molestart': (43165, 53)}
# Term_dict para current term es:
# {'moment': (43218, 113)}
# Term_dict para current term es:
# {'momento': (43331, 52)}
# Term_dict para current term es:
# {'mon': (43383, 53)}
# Term_dict para current term es:
# {'money': (43436, 145)}
# Term_dict para current term es:
# {'mong': (43581, 52)}
# Term_dict para current term es:
# {'monro': (43633, 52)}
# Term_dict para current term es:
# {'monto': (43685, 53)}
# Term_dict para current term es:
# {'mood': (43738, 53)}
# Term_dict para current term es:
# {'morder': (43791, 53)}
# Term_dict para current term es:
# {'mordidita': (43844, 53)}
# Term_dict para current term es:
# {'morn': (43897, 53)}
# Term_dict para current term es:
# {'mother': (43950, 84)}
# Term_dict para current term es:
# {'mountain': (44034, 53)}
# Term_dict para current term es:
# {'mouth': (44087, 53)}
# Term_dict para current term es:
# {'movimiento': (44140, 53)}
# Term_dict para current term es:
# {'movin': (44193, 52)}
# Term_dict para current term es:
# {'muer': (44245, 53)}
# Term_dict para current term es:
# {'muero': (44298, 53)}
# Term_dict para current term es:
# {'muli': (44351, 52)}
# Term_dict para current term es:
# {'mundo': (44403, 53)}
# Term_dict para current term es:
# {'musiica': (44456, 53)}
# Term_dict para current term es:
# {'má': (44509, 53)}
# Term_dict para current term es:
# {'más': (44562, 85)}
# Term_dict para current term es:
# {'nabitawan': (44647, 52)}
# Term_dict para current term es:
# {'nada': (44699, 84)}
# Term_dict para current term es:
# {'nadi': (44783, 53)}
# Term_dict para current term es:
# {'nah': (44836, 85)}
# Term_dict para current term es:
# {'nakapagbigay': (44921, 52)}
# Term_dict para current term es:
# {'name': (44973, 53)}
# Term_dict para current term es:
# {'nang': (45026, 52)}
# Term_dict para current term es:
# {'napalingon': (45078, 52)}
# Term_dict para current term es:
# {'natur': (45130, 85)}
# Term_dict para current term es:
# {'negar': (45215, 53)}
# Term_dict para current term es:
# {'neglect': (45268, 52)}
# Term_dict para current term es:
# {'negro': (45320, 53)}
# Term_dict para current term es:
# {'nei': (45373, 52)}
# Term_dict para current term es:
# {'neighbor': (45425, 52)}
# Term_dict para current term es:
# {'nella': (45477, 52)}
# Term_dict para current term es:
# {'nephew': (45529, 53)}
# Term_dict para current term es:
# {'nere': (45582, 52)}
# Term_dict para current term es:
# {'netflix': (45634, 53)}
# Term_dict para current term es:
# {'ngiti': (45687, 52)}
# Term_dict para current term es:
# {'nice': (45739, 52)}
# Term_dict para current term es:
# {'niego': (45791, 53)}
# Term_dict para current term es:
# {'nigga': (45844, 53)}
# Term_dict para current term es:
# {'night': (45897, 175)}
# Term_dict para current term es:
# {'ninguna': (46072, 53)}
# Term_dict para current term es:
# {'niña': (46125, 53)}
# Term_dict para current term es:
# {'noch': (46178, 85)}
# Term_dict para current term es:
# {'nostr': (46263, 52)}
# Term_dict para current term es:
# {'nott': (46315, 52)}
# Term_dict para current term es:
# {'notti': (46367, 52)}
# Term_dict para current term es:
# {'nulla': (46419, 52)}
# Term_dict para current term es:
# {'nunca': (46471, 53)}
# Term_dict para current term es:
# {'occhi': (46524, 52)}
# Term_dict para current term es:
# {'odd': (46576, 52)}
# Term_dict para current term es:
# {'ogni': (46628, 52)}
# Term_dict para current term es:
# {'olvid': (46680, 53)}
# Term_dict para current term es:
# {'olvidart': (46733, 53)}
# Term_dict para current term es:
# {'ombr': (46786, 52)}
# Term_dict para current term es:
# {'ond': (46838, 52)}
# Term_dict para current term es:
# {'ooh': (46890, 146)}
# Term_dict para current term es:
# {'oowi': (47036, 53)}
# Term_dict para current term es:
# {'oper': (47089, 53)}
# Term_dict para current term es:
# {'ore': (47142, 52)}
# Term_dict para current term es:
# {'orillita': (47194, 53)}
# Term_dict para current term es:
# {'orizzont': (47247, 52)}
# Term_dict para current term es:
# {'orlean': (47299, 53)}
# Term_dict para current term es:
# {'outrag': (47352, 53)}
# Term_dict para current term es:
# {'outta': (47405, 53)}
# Term_dict para current term es:
# {'pace': (47458, 52)}
# Term_dict para current term es:
# {'pack': (47510, 53)}
# Term_dict para current term es:
# {'paid': (47563, 84)}
# Term_dict para current term es:
# {'pain': (47647, 52)}
# Term_dict para current term es:
# {'pal': (47699, 53)}
# Term_dict para current term es:
# {'pangarap': (47752, 52)}
# Term_dict para current term es:
# {'pansin': (47804, 52)}
# Term_dict para current term es:
# {'para': (47856, 53)}
# Term_dict para current term es:
# {'parcero': (47909, 53)}
# Term_dict para current term es:
# {'pare': (47962, 53)}
# Term_dict para current term es:
# {'parec': (48015, 53)}
# Term_dict para current term es:
# {'park': (48068, 83)}
# Term_dict para current term es:
# {'parol': (48151, 52)}
# Term_dict para current term es:
# {'part': (48203, 52)}
# Term_dict para current term es:
# {'parti': (48255, 114)}
# Term_dict para current term es:
# {'pasado': (48369, 53)}
# Term_dict para current term es:
# {'pass': (48422, 53)}
# Term_dict para current term es:
# {'passin': (48475, 53)}
# Term_dict para current term es:
# {'pastel': (48528, 53)}
# Term_dict para current term es:
# {'payback': (48581, 53)}
# Term_dict para current term es:
# {'peac': (48634, 53)}
# Term_dict para current term es:
# {'pege': (48687, 53)}
# Term_dict para current term es:
# {'pelé': (48740, 52)}
# Term_dict para current term es:
# {'penitentiari': (48792, 53)}
# Term_dict para current term es:
# {'pensando': (48845, 53)}
# Term_dict para current term es:
# {'pensar': (48898, 85)}
# Term_dict para current term es:
# {'pensart': (48983, 53)}
# Term_dict para current term es:
# {'penso': (49036, 52)}
# Term_dict para current term es:
# {'pentot': (49088, 52)}
# Term_dict para current term es:
# {'peopl': (49140, 53)}
# Term_dict para current term es:
# {'pequemo': (49193, 53)}
# Term_dict para current term es:
# {'perché': (49246, 52)}
# Term_dict para current term es:
# {'perder': (49298, 53)}
# Term_dict para current term es:
# {'perdi': (49351, 52)}
# Term_dict para current term es:
# {'perdiamo': (49403, 52)}
# Term_dict para current term es:
# {'perfect': (49455, 83)}
# Term_dict para current term es:
# {'perform': (49538, 53)}
# Term_dict para current term es:
# {'permit': (49591, 53)}
# Term_dict para current term es:
# {'pero': (49644, 53)}
# Term_dict para current term es:
# {'persist': (49697, 52)}
# Term_dict para current term es:
# {'phone': (49749, 53)}
# Term_dict para current term es:
# {'pica': (49802, 53)}
# Term_dict para current term es:
# {'piec': (49855, 53)}
# Term_dict para current term es:
# {'piel': (49908, 53)}
# Term_dict para current term es:
# {'pijama': (49961, 53)}
# Term_dict para current term es:
# {'pill': (50014, 53)}
# Term_dict para current term es:
# {'pimp': (50067, 53)}
# Term_dict para current term es:
# {'più': (50120, 52)}
# Term_dict para current term es:
# {'plane': (50172, 53)}
# Term_dict para current term es:
# {'plant': (50225, 52)}
# Term_dict para current term es:
# {'platónico': (50277, 53)}
# Term_dict para current term es:
# {'play': (50330, 175)}
# Term_dict para current term es:
# {'playa': (50505, 53)}
# Term_dict para current term es:
# {'pleasur': (50558, 53)}
# Term_dict para current term es:
# {'plenti': (50611, 52)}
# Term_dict para current term es:
# {'pneumonia': (50663, 52)}
# Term_dict para current term es:
# {'poetica': (50715, 52)}
# Term_dict para current term es:
# {'poi': (50767, 52)}
# Term_dict para current term es:
# {'poison': (50819, 52)}
# Term_dict para current term es:
# {'polemica': (50871, 52)}
# Term_dict para current term es:
# {'polic': (50923, 53)}
# Term_dict para current term es:
# {'polit': (50976, 53)}
# Term_dict para current term es:
# {'pone': (51029, 53)}
# Term_dict para current term es:
# {'poniendo': (51082, 53)}
# Term_dict para current term es:
# {'pool': (51135, 53)}
# Term_dict para current term es:
# {'poor': (51188, 53)}
# Term_dict para current term es:
# {'por': (51241, 116)}
# Term_dict para current term es:
# {'porqu': (51357, 85)}
# Term_dict para current term es:
# {'portion': (51442, 52)}
# Term_dict para current term es:
# {'posicion': (51494, 53)}
# Term_dict para current term es:
# {'potrei': (51547, 52)}
# ...
# Term_dict para current term es:
# {'servono': (59602, 52)}
# Term_dict para current term es:
# {'set': (59654, 85)}
# Term_dict para current term es:
# {'sexi': (59739, 53)}
# Term_dict para current term es:
# {'sha': (59792, 53)}
# Term_dict para current term es:
# {'shake': (59845, 52)}
# Term_dict para current term es:
# {'shape': (59897, 53)}
# Term_dict para current term es:
# {'share': (59950, 84)}
# Term_dict para current term es:
# {'shift': (60034, 53)}
# Term_dict para current term es:
# {'shine': (60087, 52)}
# Term_dict para current term es:
# {'ship': (60139, 53)}
# Term_dict para current term es:
# {'shit': (60192, 84)}
# Term_dict para current term es:
# {'shore': (60276, 52)}
# Term_dict para current term es:
# {'shori': (60328, 53)}
# Term_dict para current term es:
# {'shot': (60381, 53)}
# Term_dict para current term es:
# {'shoulder': (60434, 52)}
# Term_dict para current term es:
# {'sicuro': (60486, 52)}
# Term_dict para current term es:
# {'siempr': (60538, 53)}
# Term_dict para current term es:
# {'sient': (60591, 53)}
# Term_dict para current term es:
# {'siento': (60644, 85)}
# Term_dict para current term es:
# {'siero': (60729, 52)}
# Term_dict para current term es:
# {'sight': (60781, 53)}
# Term_dict para current term es:
# {'sign': (60834, 52)}
# Term_dict para current term es:
# {'simpli': (60886, 83)}
# Term_dict para current term es:
# {'sin': (60969, 85)}
# Term_dict para current term es:
# {'sing': (61054, 114)}
# Term_dict para current term es:
# {'singl': (61168, 83)}
# Term_dict para current term es:
# {'sir': (61251, 52)}
# Term_dict para current term es:
# {'sister': (61303, 114)}
# Term_dict para current term es:
# {'sit': (61417, 84)}
# Term_dict para current term es:
# {'situat': (61501, 52)}
# Term_dict para current term es:
# {'skill': (61553, 53)}
# Term_dict para current term es:
# {'skull': (61606, 53)}
# Term_dict para current term es:
# {'sky': (61659, 83)}
# Term_dict para current term es:
# {'sleazi': (61742, 53)}
# Term_dict para current term es:
# {'sleep': (61795, 53)}
# Term_dict para current term es:
# {'slick': (61848, 52)}
# Term_dict para current term es:
# {'slow': (61900, 52)}
# Term_dict para current term es:
# {'smack': (61952, 53)}
# Term_dict para current term es:
# {'smile': (62005, 83)}
# Term_dict para current term es:
# {'smokin': (62088, 85)}
# Term_dict para current term es:
# {'snatch': (62173, 53)}
# Term_dict para current term es:
# {'sofa': (62226, 52)}
# Term_dict para current term es:
# {'soft': (62278, 52)}
# Term_dict para current term es:
# {'sogni': (62330, 52)}
# Term_dict para current term es:
# {'soil': (62382, 52)}
# Term_dict para current term es:
# {'sola': (62434, 53)}
# Term_dict para current term es:
# {'soldier': (62487, 83)}
# Term_dict para current term es:
# {'sole': (62570, 52)}
# Term_dict para current term es:
# {'solo': (62622, 52)}
# Term_dict para current term es:
# {'son': (62674, 116)}
# Term_dict para current term es:
# {'song': (62790, 52)}
# Term_dict para current term es:
# {'sono': (62842, 52)}
# Term_dict para current term es:
# {'sonó': (62894, 53)}
# Term_dict para current term es:
# {'sorrow': (62947, 52)}
# Term_dict para current term es:
# {'soul': (62999, 52)}
# Term_dict para current term es:
# {'sound': (63051, 85)}
# Term_dict para current term es:
# {'soy': (63136, 85)}
# Term_dict para current term es:
# {'spark': (63221, 53)}
# Term_dict para current term es:
# {'special': (63274, 52)}
# Term_dict para current term es:
# {'spell': (63326, 52)}
# Term_dict para current term es:
# {'spend': (63378, 83)}
# Term_dict para current term es:
# {'spiagg': (63461, 52)}
# Term_dict para current term es:
# {'spirit': (63513, 52)}
# Term_dict para current term es:
# {'spite': (63565, 52)}
# Term_dict para current term es:
# {'spog': (63617, 52)}
# Term_dict para current term es:
# {'spyderman': (63669, 52)}
# Term_dict para current term es:
# {'stack': (63721, 53)}
# Term_dict para current term es:
# {'star': (63774, 84)}
# Term_dict para current term es:
# {'starboy': (63858, 53)}
# Term_dict para current term es:
# {'starlight': (63911, 52)}
# Term_dict para current term es:
# {'start': (63963, 144)}
# Term_dict para current term es:
# {'stato': (64107, 52)}
# Term_dict para current term es:
# {'stay': (64159, 144)}
# Term_dict para current term es:
# {'stayin': (64303, 53)}
# Term_dict para current term es:
# {'steadi': (64356, 52)}
# Term_dict para current term es:
# {'steal': (64408, 52)}
# Term_dict para current term es:
# {'step': (64460, 85)}
# Term_dict para current term es:
# {'stiamo': (64545, 52)}
# Term_dict para current term es:
# {'stickel': (64597, 53)}
# Term_dict para current term es:
# {'sticki': (64650, 53)}
# Term_dict para current term es:
# {'stimul': (64703, 52)}
# Term_dict para current term es:
# {'stomach': (64755, 53)}
# Term_dict para current term es:
# {'stood': (64808, 52)}
# Term_dict para current term es:
# {'storm': (64860, 52)}
# Term_dict para current term es:
# {'straight': (64912, 52)}
# Term_dict para current term es:
# {'strang': (64964, 52)}
# Term_dict para current term es:
# {'stranger': (65016, 53)}
# Term_dict para current term es:
# {'strap': (65069, 53)}
# Term_dict para current term es:
# {'street': (65122, 53)}
# Term_dict para current term es:
# {'strengthen': (65175, 52)}
# Term_dict para current term es:
# {'strong': (65227, 52)}
# Term_dict para current term es:
# {'stumbl': (65279, 52)}
# Term_dict para current term es:
# {'stupid': (65331, 52)}
# Term_dict para current term es:
# {'style': (65383, 85)}
# Term_dict para current term es:
# {'sudar': (65468, 53)}
# Term_dict para current term es:
# {'sudor': (65521, 53)}
# Term_dict para current term es:
# {'suga': (65574, 53)}
# Term_dict para current term es:
# {'sugar': (65627, 53)}
# Term_dict para current term es:
# {'sul': (65680, 52)}
# Term_dict para current term es:
# {'sun': (65732, 52)}
# Term_dict para current term es:
# {'superfli': (65784, 53)}
# Term_dict para current term es:
# {'suppos': (65837, 84)}
# Term_dict para current term es:
# {'sur': (65921, 53)}
# Term_dict para current term es:
# {'surviv': (65974, 53)}
# Term_dict para current term es:
# {'suspici': (66027, 52)}
# Term_dict para current term es:
# {'swe': (66079, 53)}
# Term_dict para current term es:
# {'swear': (66132, 52)}
# Term_dict para current term es:
# {'sweet': (66184, 53)}
# Term_dict para current term es:
# {'swell': (66237, 52)}
# Term_dict para current term es:
# {'sé': (66289, 85)}
# Term_dict para current term es:
# {'sí': (66374, 53)}
# Term_dict para current term es:
# {'sólo': (66427, 53)}
# Term_dict para current term es:
# {'ta': (66480, 85)}
# Term_dict para current term es:
# {'take': (66565, 53)}
# Term_dict para current term es:
# {'takin': (66618, 52)}
# Term_dict para current term es:
# {'tal': (66670, 53)}
# Term_dict para current term es:
# {'talk': (66723, 84)}
# Term_dict para current term es:
# {'talkin': (66807, 53)}
# Term_dict para current term es:
# {'tanong': (66860, 52)}
# Term_dict para current term es:
# {'tanqu': (66912, 53)}
# Term_dict para current term es:
# {'tanto': (66965, 53)}
# Term_dict para current term es:
# {'tat': (67018, 53)}
# Term_dict para current term es:
# {'te': (67071, 177)}
# Term_dict para current term es:
# {'tear': (67248, 52)}
# Term_dict para current term es:
# {'telegram': (67300, 52)}
# Term_dict para current term es:
# {'tellin': (67352, 52)}
# Term_dict para current term es:
# {'tempo': (67404, 52)}
# Term_dict para current term es:
# {'tender': (67456, 52)}
# Term_dict para current term es:
# {'tengo': (67508, 53)}
# Term_dict para current term es:
# {'tensión': (67561, 53)}
# Term_dict para current term es:
# {'tenso': (67614, 53)}
# Term_dict para current term es:
# {'tequila': (67667, 53)}
# Term_dict para current term es:
# {'tha': (67720, 53)}
# Term_dict para current term es:
# {'thang': (67773, 53)}
# Term_dict para current term es:
# {'think': (67826, 53)}
# Term_dict para current term es:
# {'thrill': (67879, 84)}
# Term_dict para current term es:
# {'throne': (67963, 53)}
# Term_dict para current term es:
# {'throw': (68016, 53)}
# Term_dict para current term es:
# {'thug': (68069, 53)}
# Term_dict para current term es:
# {'ti': (68122, 84)}
# Term_dict para current term es:
# {'tiempo': (68206, 53)}
# Term_dict para current term es:
# {'tien': (68259, 147)}
# Term_dict para current term es:
# {'tiffani': (68406, 53)}
# Term_dict para current term es:
# {'tight': (68459, 53)}
# Term_dict para current term es:
# {'tiguer': (68512, 53)}
# Term_dict para current term es:
# {'time': (68565, 298)}
# Term_dict para current term es:
# {'tingin': (68863, 52)}
# Term_dict para current term es:
# {'tinig': (68915, 52)}
# Term_dict para current term es:
# {'tire': (68967, 85)}
# Term_dict para current term es:
# {'toda': (69052, 116)}
# Term_dict para current term es:
# {'todito': (69168, 53)}
# Term_dict para current term es:
# {'todo': (69221, 85)}
# Term_dict para current term es:
# {'told': (69306, 84)}
# Term_dict para current term es:
# {'tom': (69390, 53)}
# Term_dict para current term es:
# {'tomorrow': (69443, 52)}
# Term_dict para current term es:
# {'tone': (69495, 53)}
# Term_dict para current term es:
# {'tongu': (69548, 53)}
# Term_dict para current term es:
# {'tonight': (69601, 53)}
# Term_dict para current term es:
# {'tool': (69654, 53)}
# Term_dict para current term es:
# {'totoo': (69707, 52)}
# Term_dict para current term es:
# {'touch': (69759, 114)}
# Term_dict para current term es:
# {'tour': (69873, 53)}
# Term_dict para current term es:
# {'toy': (69926, 52)}
# Term_dict para current term es:
# {'tra': (69978, 52)}
# Term_dict para current term es:
# {'track': (70030, 53)}
# Term_dict para current term es:
# {'traje': (70083, 53)}
# Term_dict para current term es:
# {'trama': (70136, 53)}
# Term_dict para current term es:
# {'trato': (70189, 53)}
# Term_dict para current term es:
# {'treat': (70242, 115)}
# Term_dict para current term es:
# {'tree': (70357, 52)}
# Term_dict para current term es:
# {'tremenda': (70409, 53)}
# Term_dict para current term es:
# {'tri': (70462, 52)}
# Term_dict para current term es:
# {'tribù': (70514, 52)}
# Term_dict para current term es:
# {'trigger': (70566, 53)}
# Term_dict para current term es:
# {'trip': (70619, 52)}
# Term_dict para current term es:
# {'tropic': (70671, 52)}
# Term_dict para current term es:
# {'troppo': (70723, 52)}
# Term_dict para current term es:
# {'trovarl': (70775, 52)}
# Term_dict para current term es:
# {'trovato': (70827, 52)}
# Term_dict para current term es:
# {'true': (70879, 84)}
# Term_dict para current term es:
# {'trust': (70963, 84)}
# Term_dict para current term es:
# {'tryna': (71047, 52)}
# Term_dict para current term es:
# {'tu': (71099, 177)}
# Term_dict para current term es:
# {'tum': (71276, 53)}
# Term_dict para current term es:
# {'tus': (71329, 85)}
# Term_dict para current term es:
# {'tutta': (71414, 52)}
# Term_dict para current term es:
# {'tutto': (71466, 52)}
# Term_dict para current term es:
# {'tutugon': (71518, 52)}
# Term_dict para current term es:
# {'tuve': (71570, 53)}
# Term_dict para current term es:
# {'tuyo': (71623, 53)}
# Term_dict para current term es:
# {'tú': (71676, 85)}
# Term_dict para current term es:
# {'uh': (71761, 145)}
# Term_dict para current term es:
# {'ulit': (71906, 52)}
# Term_dict para current term es:
# {'ultim': (71958, 53)}
# Term_dict para current term es:
# {'una': (72011, 146)}
# Term_dict para current term es:
# {'understand': (72157, 52)}
# Term_dict para current term es:
# {'unit': (72209, 52)}
# Term_dict para current term es:
# {'uoh': (72261, 53)}
# Term_dict para current term es:
# {'vain': (72314, 53)}
# Term_dict para current term es:
# {'vaina': (72367, 53)}
# Term_dict para current term es:
# {'vale': (72420, 52)}
# Term_dict para current term es:
# {'vali': (72472, 52)}
# Term_dict para current term es:
# {'vamo': (72524, 53)}
# Term_dict para current term es:
# {'vampir': (72577, 53)}
# Term_dict para current term es:
# {'vampiro': (72630, 53)}
# Term_dict para current term es:
# {'vas': (72683, 53)}
# Term_dict para current term es:
# {'vaya': (72736, 53)}
# Term_dict para current term es:
# {'vena': (72789, 52)}
# Term_dict para current term es:
# {'vendita': (72841, 52)}
# Term_dict para current term es:
# {'ver': (72893, 53)}
# Term_dict para current term es:
# {'verità': (72946, 52)}
# Term_dict para current term es:
# {'vestido': (72998, 53)}
# Term_dict para current term es:
# {'vibe': (73051, 53)}
# Term_dict para current term es:
# {'vicina': (73104, 52)}
# Term_dict para current term es:
# {'vicious': (73156, 52)}
# Term_dict para current term es:
# {'vida': (73208, 53)}
# Term_dict para current term es:
# {'viendo': (73261, 53)}
# Term_dict para current term es:
# {'viern': (73314, 53)}
# Term_dict para current term es:
# {'vinil': (73367, 52)}
# Term_dict para current term es:
# {'viril': (73419, 52)}
# Term_dict para current term es:
# {'voic': (73471, 52)}
# Term_dict para current term es:
# {'void': (73523, 52)}
# Term_dict para current term es:
# {'volevo': (73575, 52)}
# Term_dict para current term es:
# {'volt': (73627, 52)}
# Term_dict para current term es:
# {'volum': (73679, 52)}
# Term_dict para current term es:
# {'volver': (73731, 53)}
# Term_dict para current term es:
# {'vos': (73784, 53)}
# Term_dict para current term es:
# {'voy': (73837, 85)}
# Term_dict para current term es:
# {'voz': (73922, 53)}
# Term_dict para current term es:
# {'vuelto': (73975, 53)}
# Term_dict para current term es:
# {'wait': (74028, 52)}
# Term_dict para current term es:
# {'wake': (74080, 84)}
# Term_dict para current term es:
# {'wall': (74164, 52)}
# Term_dict para current term es:
# {'wan': (74216, 145)}
# Term_dict para current term es:
# {'war': (74361, 53)}
# Term_dict para current term es:
# {'warm': (74414, 52)}
# Term_dict para current term es:
# {'warn': (74466, 52)}
# Term_dict para current term es:
# {'wassup': (74518, 52)}
# Term_dict para current term es:
# {'wast': (74570, 53)}
# Term_dict para current term es:
# {'watch': (74623, 85)}
# Term_dict para current term es:
# {'wave': (74708, 52)}
# Term_dict para current term es:
# {'weak': (74760, 52)}
# Term_dict para current term es:
# {'wealth': (74812, 52)}
# Term_dict para current term es:
# {'wee': (74864, 53)}
# Term_dict para current term es:
# {'weeknd': (74917, 53)}
# Term_dict para current term es:
# {'welfar': (74970, 53)}
# Term_dict para current term es:
# {'wheeler': (75023, 53)}
# Term_dict para current term es:
# {'white': (75076, 53)}
# Term_dict para current term es:
# {'wild': (75129, 52)}
# Term_dict para current term es:
# {'wind': (75181, 52)}
# Term_dict para current term es:
# {'window': (75233, 52)}
# Term_dict para current term es:
# {'winner': (75285, 52)}
# Term_dict para current term es:
# {'wipe': (75337, 53)}
# Term_dict para current term es:
# {'wit': (75390, 52)}
# Term_dict para current term es:
# {'woah': (75442, 85)}
# Term_dict para current term es:
# {'woman': (75527, 52)}
# Term_dict para current term es:
# {'woo': (75579, 52)}
# Term_dict para current term es:
# {'workin': (75631, 53)}
# Term_dict para current term es:
# {'worri': (75684, 206)}
# Term_dict para current term es:
# {'wors': (75890, 53)}
# Term_dict para current term es:
# {'worth': (75943, 84)}
# Term_dict para current term es:
# {'worthwhil': (76027, 52)}
# Term_dict para current term es:
# {'wou': (76079, 53)}
# Term_dict para current term es:
# {'wow': (76132, 53)}
# Term_dict para current term es:
# {'wrap': (76185, 52)}
# Term_dict para current term es:
# {'write': (76237, 53)}
# Term_dict para current term es:
# {'wrong': (76290, 114)}
# Term_dict para current term es:
# {'wuh': (76404, 53)}
# Term_dict para current term es:
# {'wuoh': (76457, 53)}
# Term_dict para current term es:
# {'ya': (76510, 53)}
# Term_dict para current term es:
# {'yah': (76563, 53)}
# Term_dict para current term es:
# {'yata': (76616, 52)}
# Term_dict para current term es:
# {'yeah': (76668, 268)}
# Term_dict para current term es:
# {'yeih': (76936, 53)}
# Term_dict para current term es:
# {'yo': (76989, 208)}
# Term_dict para current term es:
# {'york': (77197, 53)}
# Term_dict para current term es:
# {'zona': (77250, 53)}
# Term_dict para current term es:
# {'zone': (77303, 53)}
# Índice fusionado guardado en index_blocks_merge\postings.bin
# Diccionario de términos guardado en index_blocks_merge\term_dict.pkl
# Normas de documentos guardadas en index_blocks_merge\document_norms.pkl
#
# Resumen de tiempos:
# Tiempo para la creación Creación  y el ordenamiento de los bloques: 0.16 segundos
# Tiempo para la ejecución del merge: 0.04 segundos
# Tiempo total para la creación y el mergeo: 0.20 segundos
# Se procesaron en total:   40

# %%
# ----------Set Atributo--------
query = "this is my breath"
query = get_dfTex_Cols(path, 2, [1,2,3,6])
top_k = 20

result = s.retrieval(query, top_k)
respuesta = getResultados(result, s.dataset_path, s.disk_limit) # La respuesta es un array pd de [fila del dataframe, score]
#-----------End of query------------

# s.print_all_norms()
getResultadosDF(result, s.dataset_path, s.disk_limit)

# print( "Scores: ")
# print( respuestadf["score"])
# Out:
# Se cargo en total:  20  documentos
#                   track_id                                         track_name  \
# 2   00chLpzhgVjxs1zKC9UScL                                             Poison
# 1   004s3t0ONYlzxII9PLgU6z                                       I Feel Alive
# 6   00FROhC5g4iJdax5US8jRr                                        Satisfy You
# 7   00GfGwzlSB8DoA0cDP2Eit                                       Tender Lover
# 13  00i2HU7TEzzftShjRrDSEF                                            Changes
# 16  00LfFm08VWeZwB0Zlm24AT                                          Suga Suga
# 3   00cqd6ZsSkLZqGMlQCR0Zo  Baby It's Cold Outside (feat. Christina Aguilera)
# 17  00lNx0OcTJrS3MKHcB80HY                     You Don't Know Me - Radio Edit
# 5   00f9VGHfQhAHMCQ2bSjg3D                                            Soldier
# 11  00HIh9mVUQQAycsQiciWsh                                          Limestone
# 15  00ITtxUozN0vifE2uYvtqn             Let Me Entertain You - Remastered 2011
# 18  00NAQYOP4AmWR549nnYJZu                                            Secrets
# 8   00Gu3RMpDW2vO9PjlMVFDL                      Hide Away (feat. Envy Monroe)
# 14  00Ia46AgCNfnXjzgH8PIKH                              Latina (feat. Maluma)
# 4   00emjlCv9azBN0fzuuyLqy                                         Dumb Litty
# 10  00hdjyXt6MohKnCyDmhxOL                                     Una Vaina Loca
# 19  00nvL9u5K8jEJ6TSxGdtPK                                         Me Enamoré
# 9   00GxbkrW4m1Tac5xySEJ4M       Ti volevo dedicare (feat. J-AX & Boomdabash)
# 12  00i0O74dXdaKKdCrqHnfXm                                       La Mordidita
# 0   0017A6SJgTbfQVU2EtsPNo                                           Pangarap
#
#           track_artist                                             lyrics  \
# 2       Bell Biv DeVoe  NA Yeah, Spyderman and Freeze in full effect U...
# 1        Steady Rollin  The trees, are singing in the wind The sky blu...
# 6                Diddy  All I want is somebody who's gonna love me for...
# 7             Babyface  Feels good Everybody Tender lover Tender love ...
# 13                2Pac  I see no changes, wake up in the morning and I...
# 16           Baby Bash  So tight, so fly You got me lifted, you got me...
# 3          CeeLo Green  I really can't stay Baby it's cold outside I'v...
# 17           Jax Jones  Ooh, na-na, yeah Don't act like you know me, l...
# 5             James TW  Hold your breath, don't look down, keep trying...
# 11  Magic City Hippies  How many friends are you gonna set on fire? Ho...
# 15               Queen  Hey, it's a sellout! Hey! Let me welcome you, ...
# 18          The Weeknd  Everybody here wants you My love, my love And ...
# 8          Blasterjaxx  Don't run away, it's getting colder Our hearts...
# 14              Reykon  NA (Uh, ah, uh) Reykon, ey (Ah, oh) Maluma Mam...
# 4                 KARD  Get up out of my business You don't keep me fr...
# 10               Fuego  Fuego Uoh uoh uoh La musiica del futuroo Yeah!...
# 19         Jay Wheeler  NA Yeah-yeah, yeih "La Voz Favorita", baby, -y...
# 9           Rocco Hunt  Ho una cosa da dirti da tempo Ma  non ho mai t...
# 12        Ricky Martin  Ihhh-yo! Ihhh-ye! Sonó la campana y el fin de ...
# 0      Barbie's Cradle  Minsan pa Nang ako'y napalingon Hindi ko alam ...
#
#     track_popularity          track_album_id  \
# 2                  0  6oZ6brjB8x3GoeSYdwJdPc
# 1                 28  3z04Lb9Dsilqw68SHt6jLB
# 6                 52  2dHr0LpUe6CNV5lNsr8x0W
# 7                 36  51fAXJ5bMn7DRSunXQ6PMb
# 13                72  4Y9ISbppFbwk0r1XCLUi0I
# 16                 8  2bAkYizbM1rMbOUHpfAV9z
# 3                 41  3ssspRe42CXkhPxdc12xcp
# 17                14  4eYnvtB4sTtfGr0903YMn4
# 5                 70  3GNzXsFbzdwM0WKCZtgeNP
# 11                58  7mtoEwzZYBqG8JYItxcccG
# 15                41  2yuTRGIackbcReLUXOYBqU
# 18                71  2ODvWsOgouMbaA5xf0RkJe
# 8                 42  5pqG85igfoeWcCDIsSi9x7
# 14                74  0S3696V7LiaqAJ3DKChAdL
# 4                 65  7h5X3xhh3peIK9Y0qI5hbK
# 10                 1  01nV3KuocS1NJHTsJbPkTO
# 19                62  2Xz6s5xkP24hNqWCWHSsww
# 9                 78  57L1NgMlfxscOxHhmfLjqg
# 12                69  375cUd86z58eqXN2yW3Do9
# 0                 41  1srJQ0njEQgd8w4XSqI4JQ
#
#                             track_album_name track_album_release_date  \
# 2                                       Gold               2005-01-01
# 1                                Love & Loss               2017-11-21
# 6                                    Forever               1999-08-24
# 7                               Tender Lover               1989-07-07
# 13            The Best of 2Pac - Pt. 1: Thug               2007-01-01
# 16                        Tha Smokin' Nephew               2003-01-01
# 3                       CeeLo's Magic Moment               2012-10-29
# 17                         You Don't Know Me               2016-12-09
# 5                                   Chapters               2019-04-26
# 11                          Hippie Castle EP               2015-07-24
# 15                      Jazz (2011 Remaster)               1978-11-10
# 18                                   Starboy               2016-11-25
# 8              Hide Away (feat. Envy Monroe)               2019-06-21
# 14                     Latina (feat. Maluma)               2019-05-31
# 4       KARD 2nd Digital Single ‘Dumb Litty’               2019-09-22
# 10                            Una Vaina Loca               2011-11-02
# 19                                 Platónico               2019-11-28
# 9                                    Libertà               2019-08-30
# 12  A Quien Quiera Escuchar (Deluxe Edition)               2015-02-10
# 0                                       Trip               2001-01-01
#
#                                         playlist_name             playlist_id  \
# 2   Back in the day - R&B, New Jack Swing, Swingbe...  3a9y4eeCJRmG9p4YKfqYIx
# 1                                   Hard Rock Workout  3YouF0u7waJnolytf9JCXf
# 6   Swingbeat (old skool), New Jack Swing, R&B, Hi...  3krpccUV68nBGAQbvHEZDC
# 7                                      New Jack Swing  3ykXidKLz1eYPvuGoFlD1e
# 13             90s Gangsta Rap / Top Hip-hop Classics  0C2zyPdlkbWHrwVg9gqNdU
# 16                              90s/00s Hip Hop & RnB  0Ar0Ng9DlAWZtSPBvOQgOa
# 3                                      Christmas Soul  6FZYc2BvF7tColxO8PBShV
# 17                                      BALLARE - رقص  1CMvQ4Yr5DlYvYzI0Vc2UE
# 5                                  urban contemporary  4WiB26kw0INKwbzfb5M6Tv
# 11                                    Indie Poptimism  1pZWCY50kMUhshcESknir8
# 15                The Queen - La Discografia Completa  3E88dLx4fgFYY70gdGzdnB
# 18                                 Urban Contemporary  4Pbs84EQbuAblxlp6Chz0d
# 8                  Big Room EDM - by Spinnin' Records  7xWdFCrU5Gka6qp1ODrSdK
# 14                 LATIN POP 2020 🔥 Pop latino actual  2kKzN3kRYDzBctlaWs7CP2
# 4                                   K-Party Dance Mix  37i9dQZF1DX4RDXswvP6Mj
# 10                                     MIX LATIN POP°  6IS6XTdbS9qJZgfjNKgpB8
# 19                                   Latin Pop Rising  37i9dQZF1DX8womvTyUjrN
# 9   Musica Italiana 2020 - Playlist Pop & Hip-Hop ...  6kVFIQBhLT4003iw2WWEv1
# 12                        Fiesta Latina Mix 🎈🎉💃🏻🕺🏻☀️🏖  2kY6lVc5EcVfI5WNKmPQQG
# 0                                  Pinoy Classic Rock  37i9dQZF1DWYDQ8wBxd7xt
#
#     ... mode speechiness  acousticness  instrumentalness  liveness  valence  \
# 2   ...    0      0.2160       0.00432          0.007230    0.4890    0.650
# 1   ...    1      0.0442       0.01170          0.009940    0.3470    0.404
# 6   ...    1      0.1850       0.59100          0.000000    0.1450    0.695
# 7   ...    1      0.0445       0.22600          0.000422    0.0513    0.687
# 13  ...    1      0.0760       0.04040          0.000000    0.1400    0.316
# 16  ...    0      0.2680       0.68800          0.000008    0.0841    0.535
# 3   ...    0      0.0341       0.68900          0.000000    0.0664    0.405
# 17  ...    0      0.1380       0.16300          0.000000    0.1850    0.682
# 5   ...    1      0.0550       0.28000          0.000000    0.0975    0.305
# 11  ...    1      0.0383       0.28200          0.008490    0.0614    0.723
# 15  ...    0      0.1970       0.01640          0.001050    0.7370    0.592
# 18  ...    1      0.0533       0.01550          0.000010    0.4600    0.764
# 8   ...    1      0.0421       0.02490          0.000000    0.3610    0.134
# 14  ...    0      0.1290       0.07480          0.000000    0.3310    0.750
# 4   ...    1      0.0409       0.03700          0.000000    0.1380    0.240
# 10  ...    1      0.0361       0.11400          0.000080    0.0620    0.642
# 19  ...    1      0.0439       0.96800          0.001040    0.1180    0.456
# 9   ...    1      0.0661       0.01040          0.000000    0.1920    0.271
# 12  ...    1      0.0658       0.03440          0.000000    0.1830    0.946
# 0   ...    1      0.0236       0.27900          0.011700    0.0887    0.566
#
#       tempo  duration_ms  language     score
# 2   111.904       262467        en  1.000000
# 1   135.225       373512        en  0.069648
# 6    87.261       286441        en  0.060985
# 7   102.459       259267        en  0.057200
# 13  111.115       268960        en  0.055464
# 16   82.331       239027        en  0.052974
# 3   118.593       243067        en  0.045436
# 17  124.007       213947        en  0.043677
# 5   147.764       224720        en  0.029810
# 11   78.014       209165        en  0.029033
# 15  104.708       181693        en  0.025311
# 18  109.945       265600        en  0.022602
# 8   130.001       188000        en  0.020843
# 14  102.071       226739        es  0.014276
# 4   130.018       193160        en  0.012542
# 10  117.009       188213        es  0.008193
# 19  179.740       253830        es  0.008065
# 9   120.002       208133        it  0.003286
# 12  142.006       211680        es  0.002477
# 0    97.091       235440        tl  0.000000
#
# [20 rows x 26 columns]

# %%
# def verificar_termino(tf_file_dir, term):
#     with dbm.open(tf_file_dir, "r") as tf_db:  
#         try:
#             term_key = term.encode()
#             postings_list = pickle.loads(tf_db[term_key])
#             print(f"Postings list para '{term}': {postings_list}")
#         except KeyError:
#             print(f"El término '{term}' no se encuentra en el archivo DBM.")

# # verificar_termino(s.tf_file_dir, "6")
